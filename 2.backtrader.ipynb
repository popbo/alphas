# %%
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy
from datas import *

# %% [markdown]
# # 一、数据准备

# %% [markdown]
# ## 1.1 读取日度行情表
#
# 表内字段就是 Backtrader 默认情况下要求输入的 7 个字段： 'datetime' 、'open'、'high'、'low'、'close'、'volume'、'openinterest'，外加一个 'sec_code' 股票代码字段。

# %%
year = 2020
list_assets, df_assets = get_hs300_stocks(f'{year}-01-01')
df_org= get_all_date_data(f'{year}-01-01', f'{year+1}-01-01', list_assets)
df1 = df_org.rename(columns={
        "date": "datetime", 
        "asset": "sec_code"})
df1["openinterest"] = 0
daily_price=df1[['sec_code','datetime', "open", "close", "high", "low", "volume", 'openinterest']]
daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])

# 以 datetime 为 index，类型为 datetime 或 date 类型，Datafeeds 默认情况下是将 index 匹配给 datetime 字段；
daily_price = daily_price.set_index(['datetime'])
daily_price
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_hs300 error_code:0
# query_hs300  error_msg:success
# logout success!
# 300
# <ipython-input-3-a9745e8feb39>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])
#            sec_code   open  close   high    low  volume  openinterest
# datetime
# 2020-01-02   600000  12.47  12.47  12.64  12.45  516291             0
# 2020-01-03   600000  12.57  12.60  12.63  12.47  380188             0
# 2020-01-06   600000  12.52  12.46  12.65  12.42  410012             0
# 2020-01-07   600000  12.51  12.50  12.60  12.46  284215             0
# 2020-01-08   600000  12.41  12.32  12.45  12.25  352405             0
# ...             ...    ...    ...    ...    ...     ...           ...
# 2020-12-25   300498  18.69  18.33  18.70  18.30  233125             0
# 2020-12-28   300498  18.30  18.34  18.46  18.18  206703             0
# 2020-12-29   300498  18.34  18.14  18.37  17.93  203894             0
# 2020-12-30   300498  18.15  18.12  18.23  18.02  187996             0
# 2020-12-31   300498  18.13  18.23  18.40  18.06  226924             0
#
# [72773 rows x 7 columns]

# %% [markdown]
# ## 1.2 生成调仓信息表
#
# 表内数据说明：
#
# + trade_date： 调仓期（每月最后一个交易日）;
#
# + sec_code：持仓成分股；
#
# + weight：持仓权重。

# %%
from alphalens.utils import get_clean_factor_and_forward_returns
from alphalens.tears import create_full_tear_sheet

df_2 = df_org[['date', 'asset', "close"]]
df_2['date'] = pd.to_datetime(df_2['date'])
# print(df_all)

close = df_2.pivot(index='date', columns='asset', values='close')

alpha_num = 83
alpha_name = 'Alphas101'

# 读取已经计算好的因子
alpha = pd.read_csv('alphas/{}/{}/alpha{:03d}.csv'.format(alpha_name, year, alpha_num))

# 筛选出今年的数据，需与股票收盘日期区间一致
alpha = alpha[(alpha['date'] >= f'{year}-01-01') & (alpha['date'] <= f'{year+1}-01-01')]

# 因子矩阵转换为一维数据(alphalens需要的格式)
alpha = alpha.melt(id_vars=['date'], var_name='asset', value_name='factor' )

# date列转为日期格式
alpha['date'] = pd.to_datetime(alpha['date'])
alpha = alpha[['date', 'asset', 'factor']]

# 设置二级索引
alpha = alpha.set_index(['date', 'asset'], drop=True)
alpha.sort_index(inplace=True)


ret = get_clean_factor_and_forward_returns(alpha, close,quantiles=5)
ret = ret.reset_index()
ret = ret[ret['factor_quantile'] == 5]
# ret['week'] =  pd.to_datetime(ret['date']).dt.weekday
# ret = ret[ret['week'] == 4]
ret = ret[['date','asset']]
ret['weight'] = 1/60
trade_info = ret.rename(columns={
        "date": "trade_date", 
        "asset": "sec_code"})
trade_info
# Out:
# <ipython-input-4-65378a5c2792>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['date'] = pd.to_datetime(df_2['date'])
# Dropped 4.6% entries from factor data: 4.6% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
#       trade_date sec_code    weight
# 1     2020-01-02   000002  0.016667
# 3     2020-01-02   000069  0.016667
# 6     2020-01-02   000166  0.016667
# 8     2020-01-02   000338  0.016667
# 21    2020-01-02   000656  0.016667
# ...          ...      ...       ...
# 69539 2020-12-17   603259  0.016667
# 69541 2020-12-17   603288  0.016667
# 69542 2020-12-17   603501  0.016667
# 69544 2020-12-17   603833  0.016667
# 69545 2020-12-17   603899  0.016667
#
# [13958 rows x 3 columns]

# %% [markdown]
# # 二、 回测分析

# %% [markdown]
# ## 2.1 加载策略和数据

# %%
# 回测策略
class TestStrategy(bt.Strategy):
    params = (
        ('buy_stocks', None), # 传入各个调仓日的股票列表和相应的权重
    )
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print(f'{dt.isoformat()}, {txt}')

    def __init__(self):
         
        self.trade_dates = pd.to_datetime(self.p.buy_stocks['trade_date'].unique()).tolist()
        self.buy_stock = self.p.buy_stocks # 保留调仓信息
        self.order_list = []  # 记录以往订单，在调仓日要全部取消未成交的订单
        self.buy_stocks_pre = [] # 记录上一期持仓
    
    def next(self):
        # 获取当前的回测时间点
        dt = self.datas[0].datetime.date(0)
        # 打印当前时刻的总资产
        self.log('当前总资产 %.2f' %(self.broker.getvalue()))
        # 如果是调仓日，则进行调仓操作
        if dt in self.trade_dates:
            print(f"--------------{dt} 为调仓日----------")
            #取消之前所下的没成交也未到期的订单
            if len(self.order_list) > 0:
                print("--------------- 撤销未完成的订单 -----------------")
                for od in self.order_list:
                    # 如果订单未完成，则撤销订单
                    self.cancel(od) 
                 #重置订单列表
                self.order_list = [] 

            # 提取当前调仓日的持仓列表
            buy_stocks_data = self.buy_stock.query(f"trade_date=='{dt}'")
            long_list = buy_stocks_data['sec_code'].tolist()
            print('long_list', long_list)  # 打印持仓列表

            # 对现有持仓中，调仓后不再继续持有的股票进行卖出平仓
            sell_stock = [i for i in self.buy_stocks_pre if i not in long_list]
            print('sell_stock', sell_stock)
            if sell_stock:
                print("-----------对不再持有的股票进行平仓--------------")
                for stock in sell_stock:
                    data = self.getdatabyname(stock)
                    if self.getposition(data).size > 0 :
                        od = self.close(data=data)  
                        self.order_list.append(od) # 记录卖出订单

            # 买入此次调仓的股票：多退少补原则
            print("-----------买入此次调仓期的股票--------------")
            for stock in long_list:
                w = buy_stocks_data.query(f"sec_code=='{stock}'")['weight'].iloc[0] # 提取持仓权重
                data = self.getdatabyname(stock)
                order = self.order_target_percent(data=data, target=w*0.95) # 为减少可用资金不足的情况，留 5% 的现金做备用
                self.order_list.append(order)

            self.buy_stocks_pre = long_list  # 保存此次调仓的股票列表
        
    #订单日志    
    def notify_order(self, order):
        # 未被处理的订单
        if order.status in [order.Submitted, order.Accepted]:
            return
        # 已被处理的订单
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                    (order.ref,
                     order.executed.price,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.size,
                     order.data._name))
            else:  # Sell
                self.log('SELL EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                        (order.ref,
                         order.executed.price,
                         order.executed.value,
                         order.executed.comm,
                         order.executed.size,
                         order.data._name))

# 实例化大脑
cerebro_ = bt.Cerebro() 

# 按股票代码，依次循环传入数据
for stock in daily_price['sec_code'].unique():
    # 日期对齐
    data = pd.DataFrame(index=daily_price.index.unique())
    df = daily_price.query(f"sec_code=='{stock}'")[['open','high','low','close','volume','openinterest']]
    data_ = pd.merge(data, df, left_index=True, right_index=True, how='left')
    data_.loc[:,['volume','openinterest']] = data_.loc[:,['volume','openinterest']].fillna(0)
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(method='pad')
    # data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(0)
    datafeed = bt.feeds.PandasData(dataname=data_, fromdate=datetime.datetime(year,1,1), todate=datetime.datetime(year+1,1,1))
    cerebro_.adddata(datafeed, name=stock)
    print(f"{stock} Done !")
# Out:
# 600000 Done !
# 600004 Done !
# 600009 Done !
# 600010 Done !
# 600011 Done !
# 600015 Done !
# 600016 Done !
# 600018 Done !
# 600019 Done !
# 600023 Done !
# 600025 Done !
# 600027 Done !
# 600028 Done !
# 600029 Done !
# 600030 Done !
# 600031 Done !
# 600036 Done !
# 600038 Done !
# 600048 Done !
# 600050 Done !
# 600061 Done !
# 600066 Done !
# 600068 Done !
# 600085 Done !
# 600089 Done !
# 600100 Done !
# 600104 Done !
# 600109 Done !
# 600111 Done !
# 600115 Done !
# 600118 Done !
# 600153 Done !
# 600170 Done !
# 600176 Done !
# 600177 Done !
# 600183 Done !
# 600188 Done !
# 600196 Done !
# 600208 Done !
# 600219 Done !
# 600221 Done !
# 600233 Done !
# 600271 Done !
# 600276 Done !
# 600297 Done !
# 600299 Done !
# 600309 Done !
# 600332 Done !
# 600340 Done !
# 600346 Done !
# 600352 Done !
# 600362 Done !
# 600369 Done !
# 600372 Done !
# 600383 Done !
# 600390 Done !
# 600398 Done !
# 600406 Done !
# 600436 Done !
# 600438 Done !
# 600482 Done !
# 600487 Done !
# 600489 Done !
# 600498 Done !
# 600516 Done !
# 600519 Done !
# 600522 Done !
# 600535 Done !
# 600547 Done !
# 600566 Done !
# 600570 Done !
# 600583 Done !
# 600585 Done !
# 600588 Done !
# 600606 Done !
# 600637 Done !
# 600655 Done !
# 600660 Done !
# 600663 Done !
# 600674 Done !
# 600690 Done !
# 600703 Done !
# 600705 Done !
# 600733 Done !
# 600741 Done !
# 600760 Done !
# 600795 Done !
# 600809 Done !
# 600816 Done !
# 600837 Done !
# 002493 Done !
# 002508 Done !
# 002555 Done !
# 002558 Done !
# 002594 Done !
# 002601 Done !
# 002602 Done !
# 002607 Done !
# 002624 Done !
# 002673 Done !
# 002714 Done !
# 002736 Done !
# 002739 Done !
# 002773 Done !
# 002841 Done !
# 002916 Done !
# 002938 Done !
# 002939 Done !
# 002945 Done !
# 002958 Done !
# 300003 Done !
# 300015 Done !
# 300017 Done !
# 300024 Done !
# 300033 Done !
# 300059 Done !
# 300070 Done !
# 300122 Done !
# 300124 Done !
# 300136 Done !
# 300142 Done !
# 300144 Done !
# 300347 Done !
# 300408 Done !
# 300413 Done !
# 300433 Done !
# 300498 Done !

# %% [markdown]
# ## 2.2 添加分析器并执行回测

# %%
cerebro = deepcopy(cerebro_)  # 深度复制已经导入数据的 cerebro_，避免重复导入数据 
# 初始资金 100,000,000    
cerebro.broker.setcash(100000.0) 
# cerebro.broker.setcommission(commission=0.0015)
# 添加策略
cerebro.addstrategy(TestStrategy, buy_stocks=trade_info) # 通过修改参数 buy_stocks ，使用同一策略回测不同的持仓列表

# 添加分析指标
# 返回年初至年末的年度收益率
cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='_AnnualReturn')
# 计算最大回撤相关指标
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='_DrawDown')
# 计算年化收益
cerebro.addanalyzer(bt.analyzers.Returns, _name='_Returns', tann=252)
# 计算年化夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='_SharpeRatio', timeframe=bt.TimeFrame.Days, annualize=True, riskfreerate=0) # 计算夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio_A, _name='_SharpeRatio_A')
# 返回收益率时序
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')

# 启动回测
result = cerebro.run()
# Out:
# 2020-01-02, 当前总资产 100000.00
# 2020-01-03, 当前总资产 100000.00
# --------------2020-01-03 为调仓日----------
# long_list ['000002', '000063', '000568', '000625', '000651', '000656', '000723', '000895', '000938', '000963', '002007', '002008', '002027', '002230', '002241', '002456', '002475', '002555', '002594', '002773', '002945', '002958', '300003', '300015', '300033', '300142', '300408', '600029', '600061', '600111', '600115', '600183', '600188', '600276', '600309', '600352', '600519', '600570', '600585', '600690', '600741', '601108', '601111', '601155', '601162', '601166', '601198', '601318', '601336', '601377', '601555', '601601', '601628', '601669', '601788', '601800', '601878', '601881', '603259', '603899']
# sell_stock []
# -----------买入此次调仓期的股票--------------
# 2020-01-06, BUY EXECUTED, ref:58725, Price: 31.75, Cost: 1555.75, Comm 2.33, Size: 49.00, Stock: 000002
# 2020-01-06, BUY EXECUTED, ref:58726, Price: 36.05, Cost: 1550.15, Comm 2.33, Size: 43.00, Stock: 000063
# 2020-01-06, BUY EXECUTED, ref:58727, Price: 85.01, Cost: 1530.18, Comm 2.30, Size: 18.00, Stock: 000568
# 2020-01-06, BUY EXECUTED, ref:58728, Price: 10.44, Cost: 1566.00, Comm 2.35, Size: 150.00, Stock: 000625
# 2020-01-06, BUY EXECUTED, ref:58729, Price: 66.80, Cost: 1536.40, Comm 2.30, Size: 23.00, Stock: 000651
# 2020-01-06, BUY EXECUTED, ref:58777, Price: 34.74, Cost: 1563.30, Comm 2.34, Size: 45.00, Stock: 601628
# 2020-01-06, BUY EXECUTED, ref:58778, Price: 4.31, Cost: 1573.15, Comm 2.36, Size: 365.00, Stock: 601669
# 2020-01-06, BUY EXECUTED, ref:58779, Price: 13.28, Cost: 1567.04, Comm 2.35, Size: 118.00, Stock: 601788
# 2020-01-06, BUY EXECUTED, ref:58780, Price: 9.28, Cost: 1568.32, Comm 2.35, Size: 169.00, Stock: 601800
# 2020-01-06, BUY EXECUTED, ref:58781, Price: 10.88, Cost: 1555.84, Comm 2.33, Size: 143.00, Stock: 601878
# 2020-01-06, BUY EXECUTED, ref:58782, Price: 11.86, Cost: 1553.66, Comm 2.33, Size: 131.00, Stock: 601881
# 2020-01-06, BUY EXECUTED, ref:58783, Price: 88.06, Cost: 1497.02, Comm 2.25, Size: 17.00, Stock: 603259
# 2020-01-06, BUY EXECUTED, ref:58784, Price: 47.60, Cost: 1570.80, Comm 2.36, Size: 33.00, Stock: 603899
# 2020-01-06, 当前总资产 100228.55
# 2020-01-07, 当前总资产 101294.94
# 2020-01-08, 当前总资产 99390.62
# 2020-01-09, 当前总资产 101180.25
# 2020-01-10, 当前总资产 101309.38
# --------------2020-01-10 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000002', '000063', '000651', '000723', '000728', '000768', '000776', '000783', '002044', '002153', '002230', '002236', '002475', '002714', '002736', '002939', '300003', '300033', '300059', '300070', '300122', '300136', '300433', '300498', '600030', '600038', '600061', '600100', '600109', '600111', '600118', '600183', '600188', '600208', '600271', '600369', '600438', '600516', '600570', '600588', '600816', '600837', '600958', '600968', '600999', '601066', '601088', '601108', '601138', '601162', '601198', '601318', '601555', '601688', '601698', '601808', '601878', '601881', '601901', '603259']
# sell_stock ['000568', '000625', '000656', '000895', '000938', '000963', '002007', '002008', '002027', '002241', '002456', '002555', '002594', '002773', '002945', '002958', '300015', '300142', '300408', '600029', '600115', '600276', '600309', '600352', '600519', '600585', '600690', '600741', '601111', '601155', '601166', '601336', '601377', '601601', '601628', '601669', '601788', '601800', '603899']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2020-01-13, SELL EXECUTED, ref:58785, Price: 90.50, Cost: 1530.18, Comm 2.44, Size: -18.00, Stock: 000568
# 2020-01-13, SELL EXECUTED, ref:58786, Price: 11.41, Cost: 1566.00, Comm 2.57, Size: -150.00, Stock: 000625
# 2020-01-13, SELL EXECUTED, ref:58787, Price: 7.60, Cost: 1574.40, Comm 2.34, Size: -205.00, Stock: 000656
# 2020-01-13, SELL EXECUTED, ref:58788, Price: 31.44, Cost: 1550.12, Comm 2.45, Size: -52.00, Stock: 000895
# 2020-01-13, SELL EXECUTED, ref:58789, Price: 31.73, Cost: 1564.57, Comm 2.33, Size: -49.00, Stock: 000938
# 2020-01-13, SELL EXECUTED, ref:58790, Price: 25.01, Cost: 1562.88, Comm 2.40, Size: -64.00, Stock: 000963
# 2020-01-13, SELL EXECUTED, ref:58791, Price: 33.24, Cost: 1572.30, Comm 2.24, Size: -45.00, Stock: 002007
# 2020-01-13, SELL EXECUTED, ref:58792, Price: 43.00, Cost: 1561.80, Comm 2.45, Size: -38.00, Stock: 002008
# 2020-01-13, BUY EXECUTED, ref:58863, Price: 31.30, Cost: 1596.30, Comm 2.39, Size: 51.00, Stock: 601066
# 2020-01-13, BUY EXECUTED, ref:58864, Price: 18.16, Cost: 1598.08, Comm 2.40, Size: 88.00, Stock: 601088
# 2020-01-13, BUY EXECUTED, ref:58865, Price: 10.98, Cost: 76.86, Comm 0.12, Size: 7.00, Stock: 601108
# 2020-01-13, BUY EXECUTED, ref:58866, Price: 18.02, Cost: 1585.76, Comm 2.38, Size: 88.00, Stock: 601138
# 2020-01-13, BUY EXECUTED, ref:58867, Price: 6.88, Cost: 75.68, Comm 0.11, Size: 11.00, Stock: 601162
# 2020-01-13, BUY EXECUTED, ref:58868, Price: 12.53, Cost: 62.65, Comm 0.09, Size: 5.00, Stock: 601198
# 2020-01-13, BUY EXECUTED, ref:58869, Price: 9.52, Cost: 76.16, Comm 0.11, Size: 8.00, Stock: 601555
# 2020-01-13, BUY EXECUTED, ref:58870, Price: 20.08, Cost: 1586.32, Comm 2.38, Size: 79.00, Stock: 601688
# 2020-01-13, BUY EXECUTED, ref:58871, Price: 11.72, Cost: 1593.92, Comm 2.39, Size: 136.00, Stock: 601698
# 2020-01-13, BUY EXECUTED, ref:58872, Price: 18.27, Cost: 1607.76, Comm 2.41, Size: 88.00, Stock: 601808
# 2020-01-13, BUY EXECUTED, ref:58873, Price: 10.68, Cost: 53.40, Comm 0.08, Size: 5.00, Stock: 601878
# 2020-01-13, BUY EXECUTED, ref:58874, Price: 11.33, Cost: 90.64, Comm 0.14, Size: 8.00, Stock: 601881
# 2020-01-13, BUY EXECUTED, ref:58875, Price: 8.36, Cost: 1588.40, Comm 2.38, Size: 190.00, Stock: 601901
# 2020-01-13, 当前总资产 102908.18
# 2020-01-14, 当前总资产 102066.13
# 2020-01-15, 当前总资产 101796.71
# 2020-01-16, 当前总资产 101461.14
# 2020-01-17, 当前总资产 101873.00
# --------------2020-01-17 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000001', '000002', '000333', '000568', '000661', '000723', '000858', '000876', '002008', '002044', '002050', '002120', '002142', '002202', '002230', '002236', '002241', '002411', '002415', '002456', '002466', '002475', '002555', '002558', '002624', '002714', '002739', '002916', '002939', '300017', '300033', '300059', '300070', '300136', '300413', '300498', '600009', '600061', '600104', '600183', '600196', '600208', '600362', '600383', '600406', '600438', '600487', '600498', '600516', '600703', '600887', '600999', '601012', '601066', '601236', '601628', '601688', '601878', '601881', '603799']
# sell_stock ['000063', '000651', '000728', '000768', '000776', '000783', '002153', '002736', '300003', '300122', '300433', '600030', '600038', '600100', '600109', '600111', '600118', '600188', '600271', '600369', '600570', '600588', '600816', '600837', '600958', '600968', '601088', '601108', '601138', '601162', '601198', '601318', '601555', '601698', '601808', '601901', '603259']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 
# 2020-01-20, BUY EXECUTED, ref:58948, Price: 27.25, Cost: 1607.75, Comm 2.41, Size: 59.00, Stock: 600196
# 2020-01-20, BUY EXECUTED, ref:58949, Price: 3.88, Cost: 34.92, Comm 0.05, Size: 9.00, Stock: 600208
# 2020-01-20, BUY EXECUTED, ref:58950, Price: 16.28, Cost: 1611.72, Comm 2.42, Size: 99.00, Stock: 600362
# 2020-01-20, BUY EXECUTED, ref:58951, Price: 14.01, Cost: 1597.14, Comm 2.40, Size: 114.00, Stock: 600383
# 2020-01-20, BUY EXECUTED, ref:58952, Price: 18.57, Cost: 1615.59, Comm 2.42, Size: 87.00, Stock: 600406
# 2020-01-20, BUY EXECUTED, ref:58953, Price: 13.99, Cost: 69.95, Comm 0.10, Size: 5.00, Stock: 600438
# 2020-01-20, BUY EXECUTED, ref:58954, Price: 17.37, Cost: 1598.04, Comm 2.40, Size: 92.00, Stock: 600487
# 2020-01-20, BUY EXECUTED, ref:58955, Price: 27.38, Cost: 1588.04, Comm 2.38, Size: 58.00, Stock: 600498
# 2020-01-20, BUY EXECUTED, ref:58956, Price: 12.02, Cost: 36.06, Comm 0.05, Size: 3.00, Stock: 600516
# 2020-01-20, BUY EXECUTED, ref:58957, Price: 21.00, Cost: 1596.00, Comm 2.39, Size: 76.00, Stock: 600703
# 2020-01-20, BUY EXECUTED, ref:58958, Price: 32.83, Cost: 1608.67, Comm 2.41, Size: 49.00, Stock: 600887
# 2020-01-20, BUY EXECUTED, ref:58959, Price: 28.83, Cost: 1585.65, Comm 2.38, Size: 55.00, Stock: 601012
# 2020-01-20, BUY EXECUTED, ref:58960, Price: 18.63, Cost: 1583.55, Comm 2.38, Size: 85.00, Stock: 601236
# 2020-01-20, BUY EXECUTED, ref:58961, Price: 33.47, Cost: 1606.56, Comm 2.41, Size: 48.00, Stock: 601628
# 2020-01-20, BUY EXECUTED, ref:58962, Price: 19.77, Cost: 39.54, Comm 0.06, Size: 2.00, Stock: 601688
# 2020-01-20, BUY EXECUTED, ref:58963, Price: 11.43, Cost: 22.86, Comm 0.03, Size: 2.00, Stock: 601881
# 2020-01-20, BUY EXECUTED, ref:58964, Price: 44.91, Cost: 1571.85, Comm 2.36, Size: 35.00, Stock: 603799
# 2020-01-20, 当前总资产 103294.36
# 2020-01-21, 当前总资产 101545.54
# 2020-01-22, 当前总资产 102873.66
# 2020-01-23, 当前总资产 99358.71
# 2020-02-03, 当前总资产 91153.45
# 2020-02-04, 当前总资产 93480.47
# 2020-02-05, 当前总资产 94711.23
# 2020-02-06, 当前总资产 97166.08
# 2020-02-07, 当前总资产 97859.22
# --------------2020-02-07 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000413', '000415', '000596', '000630', '000963', '002007', '002044', '002120', '002230', '002252', '002294', '002411', '002422', '002468', '002475', '002493', '002594', '002607', '002773', '002945', '002958', '300003', '300024', '300122', '300142', '300347', '600015', '600023', '600085', '600118', '600196', '600221', '600299', '600332', '600482', '600489', '600535', '600547', '600566', '600637', '600663', '600674', '600867', '600998', '601006', '601066', '601169', '601236', '601288', '601328', '601398', '601607', '601808', '601828', '601898', '601988', '601998', '603259', '603260', '603799']
# sell_stock ['000001', '000002', '000333', '000568', '000661', '000723', '000858', '000876', '002008', '002050', '002142', '002202', '002236', '002241', '002415', '002456', '002466', '002555', '002558', '002624', '002714', '002739', '002916', '002939', '300017', '300033', '300059', '300070', '300136', '300413', '300498', '600009', '600061', '600104', '600183', '600208', '600362', '600383', '600406', '600438', '600487', '600498', '600516', '600703', '600887', '600999', '601012', '601628', '601688', '601878', '601881']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2020-02-10, SELL EXECUTED, ref:58965, Price: 14.51, Cost: 1610.14, Comm 2.13, Size: -98.00, Stock: 000001
# 2020-02-10, SELL EXECUTED, ref:58966, Price: 27.25, Cost: 1648.15, Comm 2.13, Size: -52.00, Stock: 000002
# 2020-02-10, SELL EXECUTED, ref:58967, Price: 52.30, Cost: 1580.80, Comm 2.04, Size: -26.00, Stock: 000333
# 2020-02-10, SELL EXECUTED, ref:58968, Price: 74.00, Cost: 1560.60, Comm 1.89, Size: -17.00, Stock: 000568
# 2020-02-10, SELL EXECUTED, ref:58969, Price: 471.61, Cost: 1498.32, Comm 2.12, Size: -3.00, Stock: 000661
# 2020-02-10, SELL EXECUTED, ref:58970, Price: 6.97, Cost: 1601.71, Comm 1.83, Size: -175.00, Stock: 000723
# 2020-02-10, SELL EXECUTED, ref:58971, Price: 119.50, Cost: 1546.05, Comm 1.97, Size: -11.00, Stock: 000858
# 2020-02-10, SELL EXECUTED, ref:58972, Price: 19.15, Cost: 1612.12, Comm 2.36, Size: -82.00, Stock: 000876
# 2020-02-10, SELL EXECUTED, ref:58973, Price: 38.54, Cost: 1586.93, Comm 2.14, Size: -37.00, Stock: 002008
# 2020-02-10, SELL EXECUTED, ref:58974, Price: 21.22, Cost: 1606.88, Comm 2.64, Size: -83.00, Stock: 002050
# 2020-02-10, SELL EXECUTED, ref:58975, Price: 25.27, Cost: 1609.11, Comm 2.16, Size: -57.00, Stock: 002142
# 2020-02-10, SELL EXECUTED, ref:58976, Price: 10.75, Cost: 1597.02, Comm 2.08, Size: -129.00, Stock: 002202
# 2020-02-10, SELL EXECUTED, ref:58977, Price: 20.26, Cost: 1629.51, Comm 2.34, Size: -77.00, Stock: 002236
# 2020-02-10, SELL EXECUTED, ref:58978, Price: 20.20, Cost: 1598.70, Comm 2.21, Size: -73.00, Stock: 002241
# 2020-02-10, SELL EXECUTED, ref:58979, Price: 35.02, Cost: 1602.00, Comm 2.36, Size: -45.00, Stock: 002415
# 2020-02-10, SELL EXECUTED, ref:58980, Price: 15.50, Cost: 1615.95, Comm 2.21, Size: -95.00, Stock: 002456
# 2020-02-10, SELL EXECUTED, ref:58981, Price: 27.32, Cost: 1610.00, Comm 2.05, Size: -50.00, Stock: 002466
# 2020-02-10, SELL EXECUTED, ref:58982, Price: 38.50, Cost: 1569.70, Comm 3.18, Size: -55.00, Stock: 002555
# 2020-02-10, SELL EXECUTED, ref:58983, Price: 18.62, Cost: 1587.60, Comm 2.35, Size: -84.00, Stock: 002558
# 2020-02-10, SELL EXECUTED, ref:58984, Price: 55.70, Cost: 1571.50, Comm 2.92, Size: -35.00, Stock: 002624
# 2020-02-10, SELL EXECUTED, ref:58985, Price: 92.48, Cost: 1630.08, Comm 2.50, Size: -18.00, Stock: 002714
# 2020-02-10, SELL EXECUTED, ref:58986, Price: 16.17, Cost: 1616.95, Comm 1.77, Size: -73.00, Stock: 002739
# 2020-02-10, SELL EXECUTED, ref:58987, Price: 174.12, Cost: 1516.59, Comm 2.35, Size: -9.00, Stock: 002916
# 2020-02-10, SELL EXECUTED, ref:58988, Price: 12.10, Cost: 1582.24, Comm 2.11, Size: -116.00, Stock: 002939
# 2020-02-10, SELL EXECUTED, ref:58989, Price: 8.80, Cost: 1607.18, Comm 2.15, Size: -163.00, Stock: 300017
# 2020-02-10, SELL EXECUTED, ref:58990, Price: 103.48, Cost: 1540.00, Comm 2.17, Size: -14.00, Stock: 300033
# 2020-02-10, SELL EXECUTED, ref:58991, Price: 14.56, Cost: 1614.39, Comm 2.23, Size: -102.00, Stock: 300059
# 2020-02-10, SELL EXECUTED, ref:58992, Price: 8.59, Cost: 1497.87, Comm 2.41, Size: -187.00, Stock: 300070
# 2020-02-10, SELL EXECUTED, ref:58993, Price: 39.83, Cost: 1561.00, Comm 2.09, Size: -35.00, Stock: 300136
# 2020-02-10, SELL EXECUTED, ref:58994, Price: 50.10, Cost: 1600.00, Comm 3.01, Size: -40.00, Stock: 300413
# 2020-02-10, SELL EXECUTED, ref:58995, Price: 30.61, Cost: 1621.89, Comm 2.07, Size: -45.00, Stock: 300498
# 2020-02-10, SELL EXECUTED, ref:58996, Price: 71.00, Cost: 1603.36, Comm 2.34, Size: -22.00, Stock: 600009
# 2020-02-10, SELL EXECUTED, ref:58997, Price: 13.00, Cost: 1649.01, Comm 2.22, Size: -114.00, Stock: 600061
# 2020-02-10, SELL EXECUTED, ref:58998, Price: 21.00, Cost: 1602.90, Comm 2.05, Size: -65.00, Stock: 600104
# 2020-02-10, SELL EXECUTED, ref:58999, Price: 22.94, Cost: 1583.90, Comm 2.41, Size: -70.00, Stock: 600183
# 2020-02-10, SELL EXECUTED, ref:59000, Price: 3.33, Cost: 1630.62, Comm 2.07, Size: -414.00, Stock: 600208
# 2020-02-10, SELL EXECUTED, ref:59001, Price: 13.87, Cost: 1611.72, Comm 2.06, Size: -99.00, Stock: 600362
# 2020-02-10, SELL EXECUTED, ref:59002, Price: 12.19, Cost: 1597.14, Comm 2.08, Size: -114.00, Stock: 600383
# 2020-02-10, SELL EXECUTED, ref:59003, Price: 17.53, Cost: 1615.59, Comm 2.29, Size: -87.00, Stock: 600406
# 2020-02-10, SELL EXECUTED, ref:59004, Price: 14.46, Cost: 1683.65, Comm 2.49, Size: -115.00, Stock: 600438
# 2020-02-10, SELL EXECUTED, ref:59005, Price: 15.10, Cost: 1598.04, Comm 2.08, Size: -92.00, Stock: 600487
# 2020-02-10, SELL EXECUTED, ref:59006, Price: 24.25, Cost: 1588.04, Comm 2.11, Size: -58.00, Stock: 600498
# 2020-02-10, SELL EXECUTED, ref:59007, Price: 9.72, Cost: 1634.26, Comm 1.95, Size: -134.00, Stock: 600516
# 2020-02-10, SELL EXECUTED, ref:59008, Price: 22.42, Cost: 1596.00, Comm 2.56, Size: -76.00, Stock: 600703
# 2020-02-10, SELL EXECUTED, ref:59009, Price: 30.35, Cost: 1608.67, Comm 2.23, Size: -49.00, Stock: 600887
# 2020-02-10, SELL EXECUTED, ref:59010, Price: 17.35, Cost: 1590.35, Comm 2.21, Size: -85.00, Stock: 600999
# 2020-02-10, SELL EXECUTED, ref:59011, Price: 32.55, Cost: 1585.65, Comm 2.69, Size: -55.00, Stock: 601012
# 2020-02-10, SELL EXECUTED, ref:59012, Price: 29.80, Cost: 1606.56, Comm 2.15, Size: -48.00, Stock: 601628
# 2020-02-10, SELL EXECUTED, ref:59013, Price: 17.78, Cost: 1625.86, Comm 2.16, Size: -81.00, Stock: 601688
# 2020-02-10, SELL EXECUTED, ref:59014, Price: 10.14, Cost: 1609.24, Comm 2.25, Size: -148.00, Stock: 601878
# 2020-02-10, SELL EXECUTED, ref:59015, Price: 10.10, Cost: 1667.16, Comm 2.14, Size: -141.00, Stock: 601881
# 2020-02-10, BUY EXECUTED, ref:59016, Price: 2.80, Cost: 1548.40, Comm 2.32, Size: 553.00, Stock: 000413
# 2020-02-10, BUY EXECUTED, ref:59017, Price: 3.17, Cost: 1543.79, Comm 2.32, Size: 487.00, Stock: 000415
# 2020-02-10, BUY EXECUTED, ref:59018, Price: 121.18, Cost: 1454.16, Comm 2.18, Size: 12.00, Stock: 000596
# 2020-02-10, BUY EXECUTED, ref:59019, Price: 1.99, Cost: 1548.22, Comm 2.32, Size: 778.00, Stock: 000630
# 2020-02-10, BUY EXECUTED, ref:59020, Price: 21.17, Cost: 1524.24, Comm 2.29, Size: 72.00, Stock: 000963
# 2020-02-10, BUY EXECUTED, ref:59021, Price: 42.12, Cost: 1558.44, Comm 2.34, Size: 37.00, Stock: 002007
# 2020-02-10, SELL EXECUTED, ref:59022, Price: 14.60, Cost: 44.81, Comm 0.07, Size: -3.00, Stock: 002044
# 2020-02-10, SELL EXECUTED, ref:59023, Price: 32.40, Cost: 152.60, Comm 0.24, Size: -5.00, Stock: 002120
# 2020-02-10, SELL EXECUTED, ref:59024, Price: 39.11, Cost: 171.50, Comm 0.29, Size: -5.00, Stock: 002230
# 2020-02-10, BUY EXECUTED, ref:59025, Price: 9.50, Cost: 1548.50, Comm 2.32, Size: 163.00, Stock: 002252
# 2020-02-10, BUY EXECUTED, ref:59026, Price: 18.35, Cost: 1523.05, Comm 2.28, Size: 83.00, Stock: 002294
# 2020-02-10, BUY EXECUTED, ref:59027, Price: 15.55, Cost: 15.55, Comm 0.02, Size: 1.00, Stock: 002411
# 2020-02-10, BUY EXECUTED, ref:59028, Price: 26.00, Cost: 1534.00, Comm 2.30, Size: 59.00, Stock: 002422
# 2020-02-10, BUY EXECUTED, ref:59029, Price: 19.60, Cost: 1568.00, Comm 2.35, Size: 80.00, Stock: 002468
# 2020-02-10, SELL EXECUTED, ref:59030, Price: 41.52, Cost: 74.00, Comm 0.12, Size: -2.00, Stock: 002475
# 2020-02-10, BUY EXECUTED, ref:59031, Price: 10.47, Cost: 1539.09, Comm 2.31, Size: 147.00, Stock: 002493
# 2020-02-10, BUY EXECUTED, ref:59032, Price: 59.20, Cost: 1539.20, Comm 2.31, Size: 26.00, Stock: 002594
# 2020-02-10, BUY EXECUTED, ref:59033, Price: 17.39, Cost: 1547.71, Comm 2.32, Size: 89.00, Stock: 002607
# 2020-02-10, BUY EXECUTED, ref:59034, Price: 37.48, Cost: 1536.68, Comm 2.31, Size: 41.00, Stock: 002773
# 2020-02-10, BUY EXECUTED, ref:59035, Price: 13.11, Cost: 1546.98, Comm 2.32, Size: 118.00, Stock: 002945
# 2020-02-10, BUY EXECUTED, ref:59036, Price: 5.35, Cost: 1535.45, Comm 2.30, Size: 287.00, Stock: 002958
# 2020-02-10, BUY EXECUTED, ref:59037, Price: 35.05, Cost: 1542.20, Comm 2.31, Size: 44.00, Stock: 300003
# 2020-02-10, BUY EXECUTED, ref:59038, Price: 16.03, Cost: 1538.88, Comm 2.31, Size: 96.00, Stock: 300024
# 2020-02-10, BUY EXECUTED, ref:59039, Price: 64.30, Cost: 1543.20, Comm 2.31, Size: 24.00, Stock: 300122
# 2020-02-10, BUY EXECUTED, ref:59040, Price: 29.10, Cost: 1571.40, Comm 2.36, Size: 54.00, Stock: 300142
# 2020-02-10, BUY EXECUTED, ref:59041, Price: 80.01, Cost: 1520.19, Comm 2.28, Size: 19.00, Stock: 300347
# 2020-02-10, BUY EXECUTED, ref:59042, Price: 7.09, Cost: 1538.53, Comm 2.31, Size: 217.00, Stock: 600015
# 2020-02-10, BUY EXECUTED, ref:59043, Price: 3.51, Cost: 1544.40, Comm 2.32, Size: 440.00, Stock: 600023
# 2020-02-10, BUY EXECUTED, ref:59044, Price: 29.00, Cost: 1537.00, Comm 2.31, Size: 53.00, Stock: 600085
# 2020-02-10, BUY EXECUTED, ref:59045, Price: 40.00, Cost: 1600.00, Comm 2.40, Size: 40.00, Stock: 600118
# 2020-02-10, SELL EXECUTED, ref:59046, Price: 27.64, Cost: 54.50, Comm 0.08, Size: -2.00, Stock: 600196
# 2020-02-10, BUY EXECUTED, ref:59047, Price: 1.47, Cost: 1537.62, Comm 2.31, Size: 1046.00, Stock: 600221
# 2020-02-10, BUY EXECUTED, ref:59048, Price: 10.17, Cost: 1545.84, Comm 2.32, Size: 152.00, Stock: 600299
# 2020-02-10, BUY EXECUTED, ref:59049, Price: 38.00, Cost: 1520.00, Comm 2.28, Size: 40.00, Stock: 600332
# 2020-02-10, BUY EXECUTED, ref:59050, Price: 17.11, Cost: 1539.90, Comm 2.31, Size: 90.00, Stock: 600482
# 2020-02-10, BUY EXECUTED, ref:59051, Price: 7.82, Cost: 1540.54, Comm 2.31, Size: 197.00, Stock: 600489
# 2020-02-10, BUY EXECUTED, ref:59052, Price: 16.55, Cost: 1539.15, Comm 2.31, Size: 93.00, Stock: 600535
# 2020-02-10, BUY EXECUTED, ref:59053, Price: 32.58, Cost: 1531.26, Comm 2.30, Size: 47.00, Stock: 600547
# 2020-02-10, BUY EXECUTED, ref:59054, Price: 26.58, Cost: 1515.06, Comm 2.27, Size: 57.00, Stock: 600566
# 2020-02-10, BUY EXECUTED, ref:59055, Price: 11.83, Cost: 1537.90, Comm 2.31, Size: 130.00, Stock: 600637
# 2020-02-10, BUY EXECUTED, ref:59056, Price: 11.60, Cost: 1542.80, Comm 2.31, Size: 133.00, Stock: 600663
# 2020-02-10, BUY EXECUTED, ref:59057, Price: 8.77, Cost: 1534.75, Comm 2.30, Size: 175.00, Stock: 600674
# 2020-02-10, BUY EXECUTED, ref:59058, Price: 12.40, Cost: 1550.00, Comm 2.33, Size: 125.00, Stock: 600867
# 2020-02-10, BUY EXECUTED, ref:59059, Price: 16.81, Cost: 1546.52, Comm 2.32, Size: 92.00, Stock: 600998
# 2020-02-10, BUY EXECUTED, ref:59060, Price: 7.30, Cost: 1533.00, Comm 2.30, Size: 210.00, Stock: 601006
# 2020-02-10, SELL EXECUTED, ref:59061, Price: 32.20, Cost: 93.90, Comm 0.14, Size: -3.00, Stock: 601066
# 2020-02-10, BUY EXECUTED, ref:59062, Price: 5.22, Cost: 1539.90, Comm 2.31, Size: 295.00, Stock: 601169
# 2020-02-10, BUY EXECUTED, ref:59063, Price: 16.44, Cost: 98.64, Comm 0.15, Size: 6.00, Stock: 601236
# 2020-02-10, BUY EXECUTED, ref:59064, Price: 3.38, Cost: 1537.90, Comm 2.31, Size: 455.00, Stock: 601288
# 2020-02-10, BUY EXECUTED, ref:59065, Price: 5.23, Cost: 1542.85, Comm 2.31, Size: 295.00, Stock: 601328
# 2020-02-10, BUY EXECUTED, ref:59066, Price: 5.41, Cost: 1536.44, Comm 2.30, Size: 284.00, Stock: 601398
# 2020-02-10, BUY EXECUTED, ref:59067, Price: 20.50, Cost: 1517.00, Comm 2.28, Size: 74.00, Stock: 601607
# 2020-02-10, BUY EXECUTED, ref:59068, Price: 16.36, Cost: 1537.84, Comm 2.31, Size: 94.00, Stock: 601808
# 2020-02-10, BUY EXECUTED, ref:59069, Price: 10.86, Cost: 1552.98, Comm 2.33, Size: 143.00, Stock: 601828
# 2020-02-10, BUY EXECUTED, ref:59070, Price: 4.27, Cost: 1537.20, Comm 2.31, Size: 360.00, Stock: 601898
# 2020-02-10, BUY EXECUTED, ref:59071, Price: 3.49, Cost: 1539.09, Comm 2.31, Size: 441.00, Stock: 601988
# 2020-02-10, BUY EXECUTED, ref:59072, Price: 5.54, Cost: 1534.58, Comm 2.30, Size: 277.00, Stock: 601998
# 2020-02-10, BUY EXECUTED, ref:59073, Price: 101.58, Cost: 1523.70, Comm 2.29, Size: 15.00, Stock: 603259
# 2020-02-10, BUY EXECUTED, ref:59074, Price: 25.76, Cost: 1545.60, Comm 2.32, Size: 60.00, Stock: 603260
# 2020-02-10, BUY EXECUTED, ref:59075, Price: 41.96, Cost: 41.96, Comm 0.06, Size: 1.00, Stock: 603799
# 2020-02-10, 当前总资产 96828.32
# 2020-02-11, 当前总资产 96504.90
# 2020-02-12, 当前总资产 97483.08
# 2020-02-13, 当前总资产 96613.10
# 2020-02-14, 当前总资产 96834.81
# --------------2020-02-14 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000063', '000100', '000338', '000723', '000938', '002001', '002007', '002050', '002153', '002230', '002236', '002252', '002271', '002352', '002410', '002411', '002415', '002422', '002460', '002475', '002594', '002624', '002841', '300003', '300015', '300017', '300070', '300122', '300136', '300347', '300408', '600089', '600111', '600196', '600276', '600346', '600406', '600487', '600547', '600570', '600583', '600588', '600637', '600690', '600703', '600733', '600809', '601012', '601066', '601360', '601607', '601698', '601933', '603019', '603160', '603259', '603260', '603501', '603799', '603986']
# sell_stock ['000413', '000415', '000596', '000630', '000963', '002044', '002120', '002294', '002468', '002493', '002607', '002773', '002945', '002958', '300024', '300142', '600015', '600023', '600085', '600118', '600221', '600299', '600332', '600482', '600489', '600535', '600566', '600663', '600674', '600867', '600998', '601006', '601169', '601236', '601288', '601328', '601398', '601808', '601828', '601898', '601988', '601998']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2020-02-17, SELL EXECUTED, ref:59076, Price: 2.88, Cost: 1548.40, Comm 2.39, Size: -553.00, Stock: 000413
# 2020-02-17, SELL EXECUTED, ref:59077, Price: 3.31, Cost: 1543.79, Comm 2.42, Size: -487.00, Stock: 000415
# 2020-02-17, SELL EXECUTED, ref:59078, Price: 121.70, Cost: 1454.16, Comm 2.19, Size: -12.00, Stock: 000596
# 2020-02-17, SELL EXECUTED, ref:59079, Price: 2.07, Cost: 1548.22, Comm 2.42, Size: -778.00, Stock: 000630
# 2020-02-17, SELL EXECUTED, ref:59080, Price: 20.50, Cost: 1524.24, Comm 2.21, Size: -72.00, Stock: 000963
# 2020-02-17, SELL EXECUTED, ref:59081, Price: 13.75, Cost: 1613.12, Comm 2.23, Size: -108.00, Stock: 002044
# 2020-02-17, SELL EXECUTED, ref:59082, Price: 32.23, Cost: 1464.96, Comm 2.32, Size: -48.00, Stock: 002120
# 2020-02-17, SELL EXECUTED, ref:59083, Price: 17.94, Cost: 1523.05, Comm 2.23, Size: -83.00, Stock: 002294
# 2020-02-17, SELL EXECUTED, ref:59084, Price: 19.75, Cost: 1568.00, Comm 2.37, Size: -80.00, Stock: 002468
# 2020-02-17, SELL EXECUTED, ref:59085, Price: 10.70, Cost: 1539.09, Comm 2.36, Size: -147.00, Stock: 002493
# 2020-02-17, SELL EXECUTED, ref:59086, Price: 17.50, Cost: 1547.71, Comm 2.34, Size: -89.00, Stock: 002607
# 2020-02-17, SELL EXECUTED, ref:59087, Price: 35.93, Cost: 1536.68, Comm 2.21, Size: -41.00, Stock: 002773
# 2020-02-17, SELL EXECUTED, ref:59088, Price: 13.40, Cost: 1546.98, Comm 2.37, Size: -118.00, Stock: 002945
# 2020-02-17, SELL EXECUTED, ref:59089, Price: 5.39, Cost: 1535.45, Comm 2.32, Size: -287.00, Stock: 002958
# 2020-02-17, SELL EXECUTED, ref:59090, Price: 15.55, Cost: 1538.88, Comm 2.24, Size: -96.00, Stock: 300024
# 2020-02-17, SELL EXECUTED, ref:59091, Price: 29.46, Cost: 1571.40, Comm 2.39, Size: -54.00, Stock: 300142
# 2020-02-17, SELL EXECUTED, ref:59092, Price: 7.09, Cost: 1538.53, Comm 2.31, Size: -217.00, Stock: 600015
# 2020-02-17, SELL EXECUTED, ref:59093, Price: 3.53, Cost: 1544.40, Comm 2.33, Size: -440.00, Stock: 600023
# 2020-02-17, SELL EXECUTED, ref:59094, Price: 27.75, Cost: 1537.00, Comm 2.21, Size: -53.00, Stock: 600085
# 2020-02-17, SELL EXECUTED, ref:59095, Price: 37.00, Cost: 1600.00, Comm 2.22, Size: -40.00, Stock: 600118
# 2020-02-17, SELL EXECUTED, ref:59096, Price: 1.51, Cost: 1537.62, Comm 2.37, Size: -1046.00, Stock: 600221
# 2020-02-17, SELL EXECUTED, ref:59097, Price: 10.80, Cost: 1545.84, Comm 2.46, Size: -152.00, Stock: 600299
# 2020-02-17, SELL EXECUTED, ref:59098, Price: 35.92, Cost: 1520.00, Comm 2.16, Size: -40.00, Stock: 600332
# 2020-02-17, SELL EXECUTED, ref:59099, Price: 17.50, Cost: 1539.90, Comm 2.36, Size: -90.00, Stock: 600482
# 2020-02-17, SELL EXECUTED, ref:59100, Price: 8.04, Cost: 1540.54, Comm 2.38, Size: -197.00, Stock: 600489
# 2020-02-17, SELL EXECUTED, ref:59101, Price: 15.78, Cost: 1539.15, Comm 2.20, Size: -93.00, Stock: 600535
# 2020-02-17, SELL EXECUTED, ref:59102, Price: 25.45, Cost: 1515.06, Comm 2.18, Size: -57.00, Stock: 600566
# 2020-02-17, SELL EXECUTED, ref:59103, Price: 11.82, Cost: 1542.80, Comm 2.36, Size: -133.00, Stock: 600663
# 2020-02-17, SELL EXECUTED, ref:59104, Price: 8.93, Cost: 1534.75, Comm 2.34, Size: -175.00, Stock: 600674
# 2020-02-17, SELL EXECUTED, ref:59105, Price: 11.58, Cost: 1550.00, Comm 2.17, Size: -125.00, Stock: 600867
# 2020-02-17, SELL EXECUTED, ref:59106, Price: 15.67, Cost: 1546.52, Comm 2.16, Size: -92.00, Stock: 600998
# 2020-02-17, SELL EXECUTED, ref:59107, Price: 7.29, Cost: 1533.00, Comm 2.30, Size: -210.00, Stock: 601006
# 2020-02-17, SELL EXECUTED, ref:59108, Price: 5.24, Cost: 1539.90, Comm 2.32, Size: -295.00, Stock: 601169
# 2020-02-17, SELL EXECUTED, ref:59109, Price: 18.18, Cost: 1682.19, Comm 2.48, Size: -91.00, Stock: 601236
# 2020-02-17, SELL EXECUTED, ref:59110, Price: 3.42, Cost: 1537.90, Comm 2.33, Size: -455.00, Stock: 601288
# 2020-02-17, SELL EXECUTED, ref:59111, Price: 5.27, Cost: 1542.85, Comm 2.33, Size: -295.00, Stock: 601328
# 2020-02-17, SELL EXECUTED, ref:59112, Price: 5.42, Cost: 1536.44, Comm 2.31, Size: -284.00, Stock: 601398
# 2020-02-17, SELL EXECUTED, ref:59113, Price: 18.15, Cost: 1537.84, Comm 2.56, Size: -94.00, Stock: 601808
# 2020-02-17, SELL EXECUTED, ref:59114, Price: 10.75, Cost: 1552.98, Comm 2.31, Size: -143.00, Stock: 601828
# 2020-02-17, SELL EXECUTED, ref:59115, Price: 4.38, Cost: 1537.20, Comm 2.37, Size: -360.00, Stock: 601898
# 2020-02-17, SELL EXECUTED, ref:59116, Price: 3.56, Cost: 1539.09, Comm 2.35, Size: -441.00, Stock: 601988
# 2020-12-07, BUY EXECUTED, ref:62829, Price: 7.04, Cost: 1851.52, Comm 2.78, Size: 263.00, Stock: 601319
# 2020-12-07, BUY EXECUTED, ref:62830, Price: 8.96, Cost: 1854.72, Comm 2.78, Size: 207.00, Stock: 601377
# 2020-12-07, BUY EXECUTED, ref:62831, Price: 10.18, Cost: 1852.76, Comm 2.78, Size: 182.00, Stock: 601577
# 2020-12-07, BUY EXECUTED, ref:62832, Price: 5.30, Cost: 1855.00, Comm 2.78, Size: 350.00, Stock: 601668
# 2020-12-07, BUY EXECUTED, ref:62833, Price: 4.13, Cost: 1854.37, Comm 2.78, Size: 449.00, Stock: 601669
# 2020-12-07, BUY EXECUTED, ref:62834, Price: 19.97, Cost: 1837.24, Comm 2.76, Size: 92.00, Stock: 601698
# 2020-12-07, BUY EXECUTED, ref:62835, Price: 9.14, Cost: 1837.14, Comm 2.76, Size: 201.00, Stock: 601901
# 2020-12-07, BUY EXECUTED, ref:62836, Price: 8.38, Cost: 1851.98, Comm 2.78, Size: 221.00, Stock: 601997
# 2020-12-07, BUY EXECUTED, ref:62837, Price: 5.27, Cost: 1855.04, Comm 2.78, Size: 352.00, Stock: 601998
# 2020-12-07, BUY EXECUTED, ref:62838, Price: 27.65, Cost: 1824.90, Comm 2.74, Size: 66.00, Stock: 603156
# 2020-12-07, BUY EXECUTED, ref:62839, Price: 166.00, Cost: 1826.00, Comm 2.74, Size: 11.00, Stock: 603160
# 2020-12-07, 当前总资产 115242.82
# 2020-12-08, 当前总资产 114947.65
# 2020-12-09, 当前总资产 113072.88
# 2020-12-10, 当前总资产 112406.13
# 2020-12-11, 当前总资产 111686.86
# --------------2020-12-11 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000333', '000661', '000723', '000728', '000876', '000938', '002007', '002008', '002050', '002241', '002352', '002466', '002475', '002601', '002739', '002938', '300003', '300122', '300124', '300136', '300142', '300408', '300433', '600030', '600036', '600111', '600183', '600188', '600271', '600276', '600309', '600346', '600362', '600436', '600438', '600570', '600588', '600733', '600958', '601012', '601066', '601108', '601166', '601211', '601318', '601555', '601601', '601688', '601727', '601788', '601888', '601899', '603019', '603160', '603259', '603288', '603501', '603799', '603986', '603993']
# sell_stock ['000002', '000069', '000100', '000625', '000627', '000725', '000776', '000786', '001979', '002311', '002410', '002456', '002594', '002736', '002773', '002958', '300498', '600004', '600015', '600029', '600066', '600089', '600104', '600109', '600115', '600383', '600498', '600660', '600741', '600809', '600837', '600919', '600928', '601111', '601117', '601138', '601162', '601216', '601236', '601238', '601319', '601377', '601577', '601668', '601669', '601698', '601901', '601997', '601998', '603156']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2020-12-14, SELL EXECUTED, ref:62840, Price: 28.60, Cost: 1833.05, Comm 2.62, Size: -61.00, Stock: 000002
# 2020-12-14, SELL EXECUTED, ref:62841, Price: 6.75, Cost: 1850.49, Comm 2.64, Size: -261.00, Stock: 000069
# 2020-12-14, SELL EXECUTED, ref:62842, Price: 6.73, Cost: 1860.18, Comm 2.60, Size: -258.00, Stock: 000100
# 2020-12-14, SELL EXECUTED, ref:62843, Price: 22.89, Cost: 1798.20, Comm 2.54, Size: -74.00, Stock: 000625
# 2020-12-14, BUY EXECUTED, ref:62938, Price: 205.81, Cost: 1646.48, Comm 2.47, Size: 8.00, Stock: 601888
# 2020-12-14, BUY EXECUTED, ref:62939, Price: 8.30, Cost: 1734.70, Comm 2.60, Size: 209.00, Stock: 601899
# 2020-12-14, BUY EXECUTED, ref:62940, Price: 31.98, Cost: 1758.90, Comm 2.64, Size: 55.00, Stock: 603019
# 2020-12-14, BUY EXECUTED, ref:62941, Price: 109.14, Cost: 1746.24, Comm 2.62, Size: 16.00, Stock: 603259
# 2020-12-14, BUY EXECUTED, ref:62942, Price: 189.19, Cost: 1702.71, Comm 2.55, Size: 9.00, Stock: 603288
# 2020-12-14, BUY EXECUTED, ref:62943, Price: 234.99, Cost: 1644.93, Comm 2.47, Size: 7.00, Stock: 603501
# 2020-12-14, BUY EXECUTED, ref:62944, Price: 55.48, Cost: 1719.88, Comm 2.58, Size: 31.00, Stock: 603799
# 2020-12-14, BUY EXECUTED, ref:62945, Price: 201.20, Cost: 1609.60, Comm 2.41, Size: 8.00, Stock: 603986
# 2020-12-14, BUY EXECUTED, ref:62946, Price: 4.40, Cost: 1804.00, Comm 2.71, Size: 410.00, Stock: 603993
# 2020-12-14, 当前总资产 111688.36
# 2020-12-15, 当前总资产 112525.97
# 2020-12-16, 当前总资产 112445.35
# 2020-12-17, 当前总资产 114285.54
# 2020-12-18, 当前总资产 114700.88
# 2020-12-21, 当前总资产 116560.85
# 2020-12-22, 当前总资产 113722.46
# 2020-12-23, 当前总资产 115193.67
# 2020-12-24, 当前总资产 114715.11
# 2020-12-25, 当前总资产 116547.28
# 2020-12-28, 当前总资产 116468.58
# 2020-12-29, 当前总资产 115304.05
# 2020-12-30, 当前总资产 117210.02
# 2020-12-31, 当前总资产 119270.62

# %% [markdown]
# ## 2.3 回测结果分析

# %%
strat = result[0]
# print("--------------- AnnualReturn -----------------")
# print(strat.analyzers._AnnualReturn.get_analysis())
# print("--------------- DrawDown -----------------")
# print(strat.analyzers._DrawDown.get_analysis())
# print("--------------- Returns -----------------")
# print(strat.analyzers._Returns.get_analysis())
# print("--------------- SharpeRatio -----------------")
# print(strat.analyzers._SharpeRatio.get_analysis())
# print("--------------- SharpeRatio_A -----------------")
# print(strat.analyzers._SharpeRatio_A.get_analysis())

# 绘制累计收益率
ret = pd.Series(strat.analyzers._TimeReturn.get_analysis())
(ret + 1).cumprod().plot(figsize=(12,6))

ret = [{
        '年度': year,
        '收益率': strat.analyzers._Returns.get_analysis()['rtot'],
        '日均收益率': strat.analyzers._Returns.get_analysis()['ravg'],
        '年化收益率': strat.analyzers._Returns.get_analysis()['rnorm'],
        '最大回撤(%)': strat.analyzers._DrawDown.get_analysis()['max']['drawdown']
        * (-1),
        '夏普比率': strat.analyzers._SharpeRatio.get_analysis()['sharperatio'],
    }]
pd.DataFrame(ret).sort_values(by='年化收益率', ascending=False)
# Out:
#      年度       收益率     日均收益率     年化收益率    最大回撤(%)      夏普比率
# 0  2020  0.176225  0.000725  0.200516 -14.850403  0.854941
