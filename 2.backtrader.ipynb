# %%
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy

# %% [markdown]
# # 一、数据准备

# %% [markdown]
# ## 1.1 读取日度行情表
#
# 表内字段就是 Backtrader 默认情况下要求输入的 7 个字段： 'datetime' 、'open'、'high'、'low'、'close'、'volume'、'openinterest'，外加一个 'sec_code' 股票代码字段。

# %%
import pandas as pd
from datas import *

year = 2019
list_assets, df_assets = get_hs300_stocks(f'{year}-01-01')
df_org= get_all_date_data(f'{year}-01-01', f'{year+1}-01-01', list_assets)
df1 = df_org.rename(columns={
        "date": "datetime", 
        "asset": "sec_code"})
df1["openinterest"] = 0
daily_price=df1[['sec_code','datetime', "open", "close", "high", "low", "volume", 'openinterest']]
daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])
daily_price
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_hs300 error_code:0
# query_hs300  error_msg:success
# logout success!
# 300
# <ipython-input-16-85d5e85e958d>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])
#       sec_code   datetime   open  close   high    low  volume  openinterest
# 0       600000 2019-01-02   9.74   9.70   9.79   9.58  237628             0
# 1       600000 2019-01-03   9.70   9.81   9.82   9.66  186543             0
# 2       600000 2019-01-04   9.73   9.96  10.00   9.70  271728             0
# 3       600000 2019-01-07  10.09   9.98  10.09   9.92  235974             0
# 4       600000 2019-01-08  10.03   9.96  10.03   9.91  151049             0
# ...        ...        ...    ...    ...    ...    ...     ...           ...
# 72881   300433 2019-12-25  14.20  14.19  14.38  14.09  353685             0
# 72882   300433 2019-12-26  14.19  14.11  14.36  13.96  383715             0
# 72883   300433 2019-12-27  14.13  13.64  14.38  13.64  523975             0
# 72884   300433 2019-12-30  13.52  13.79  13.99  13.12  484200             0
# 72885   300433 2019-12-31  13.80  13.82  13.96  13.57  317300             0
#
# [72886 rows x 8 columns]

# %%
# 以 datetime 为 index，类型为 datetime 或 date 类型，Datafeeds 默认情况下是将 index 匹配给 datetime 字段；
daily_price = daily_price.set_index(['datetime'])
daily_price
# Out:
#            sec_code   open  close   high    low  volume  openinterest
# datetime
# 2019-01-02   600000   9.74   9.70   9.79   9.58  237628             0
# 2019-01-03   600000   9.70   9.81   9.82   9.66  186543             0
# 2019-01-04   600000   9.73   9.96  10.00   9.70  271728             0
# 2019-01-07   600000  10.09   9.98  10.09   9.92  235974             0
# 2019-01-08   600000  10.03   9.96  10.03   9.91  151049             0
# ...             ...    ...    ...    ...    ...     ...           ...
# 2019-12-25   300433  14.20  14.19  14.38  14.09  353685             0
# 2019-12-26   300433  14.19  14.11  14.36  13.96  383715             0
# 2019-12-27   300433  14.13  13.64  14.38  13.64  523975             0
# 2019-12-30   300433  13.52  13.79  13.99  13.12  484200             0
# 2019-12-31   300433  13.80  13.82  13.96  13.57  317300             0
#
# [72886 rows x 7 columns]

# %% [markdown]
# ## 1.2 生成调仓信息表
#
# 表内数据说明：
#
# + trade_date： 调仓期（每月最后一个交易日）;
#
# + sec_code：持仓成分股；
#
# + weight：持仓权重。

# %%
from alphalens.utils import get_clean_factor_and_forward_returns
from alphalens.tears import create_full_tear_sheet

df_2 = df_org[['date', 'asset', "close"]]
df_2['date'] = pd.to_datetime(df_2['date'])
# print(df_all)

close = df_2.pivot(index='date', columns='asset', values='close')

alpha_num = 83
alpha_name = 'Alphas101'

# 读取已经计算好的因子
alpha = pd.read_csv('alphas/{}/{}/alpha{:03d}.csv'.format(alpha_name, year, alpha_num))

# 筛选出今年的数据，需与股票收盘日期区间一致
alpha = alpha[(alpha['date'] >= f'{year}-01-01') & (alpha['date'] <= f'{year+1}-01-01')]

# 因子矩阵转换为一维数据(alphalens需要的格式)
alpha = alpha.melt(id_vars=['date'], var_name='asset', value_name='factor' )

# date列转为日期格式
alpha['date'] = pd.to_datetime(alpha['date'])
alpha = alpha[['date', 'asset', 'factor']]

# 设置二级索引
alpha = alpha.set_index(['date', 'asset'], drop=True)
alpha.sort_index(inplace=True)


ret = get_clean_factor_and_forward_returns(alpha, close,quantiles=5)
ret = ret.reset_index()
ret = ret[ret['factor_quantile'] == 5]
ret = ret[['date','asset']]
ret['weight'] = 1/60
trade_info = ret.rename(columns={
        "date": "trade_date", 
        "asset": "sec_code"})
trade_info
# Out:
# <ipython-input-18-3029e40aae47>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['date'] = pd.to_datetime(df_2['date'])
# Dropped 5.0% entries from factor data: 5.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
#       trade_date sec_code    weight
# 2     2019-01-02   000063  0.016667
# 7     2019-01-02   000333  0.016667
# 15    2019-01-02   000503  0.016667
# 18    2019-01-02   000568  0.016667
# 22    2019-01-02   000651  0.016667
# ...          ...      ...       ...
# 69545 2019-12-17   601881  0.016667
# 69549 2019-12-17   601901  0.016667
# 69565 2019-12-17   603799  0.016667
# 69567 2019-12-17   603858  0.016667
# 69569 2019-12-17   603993  0.016667
#
# [13991 rows x 3 columns]

# %% [markdown]
# # 二、 选股回测
#
#  选股策略：定期按持仓权重调仓 。

# %%
# 回测策略
class TestStrategy(bt.Strategy):
    params = (
        ('buy_stocks', None), # 传入各个调仓日的股票列表和相应的权重
    )
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('{}, {}'.format(dt.isoformat(), txt))

    def __init__(self):
         # 读取调仓日期，即每月的最后一个交易日，回测时，会在这一天下单，然后在下一个交易日，以开盘价买入
        self.trade_dates = pd.to_datetime(self.p.buy_stocks['trade_date'].unique()).tolist()
        self.buy_stock = self.p.buy_stocks # 保留调仓信息
        self.order_list = []  # 记录以往订单，在调仓日要全部取消未成交的订单
        self.buy_stocks_pre = [] # 记录上一期持仓
    
    def next(self):
        # 获取当前的回测时间点
        dt = self.datas[0].datetime.date(0)
        # 打印当前时刻的总资产
        self.log('当前总资产 %.2f' %(self.broker.getvalue()))
        # 如果是调仓日，则进行调仓操作
        if dt in self.trade_dates:
            print("--------------{} 为调仓日----------".format(dt))
            #取消之前所下的没成交也未到期的订单
            if len(self.order_list) > 0:
                print("--------------- 撤销未完成的订单 -----------------")
                for od in self.order_list:
                    # 如果订单未完成，则撤销订单
                    self.cancel(od) 
                 #重置订单列表
                self.order_list = [] 
                
            # 提取当前调仓日的持仓列表
            buy_stocks_data = self.buy_stock.query(f"trade_date=='{dt}'")
            long_list = buy_stocks_data['sec_code'].tolist()
            print('long_list', long_list)  # 打印持仓列表
            
            # 对现有持仓中，调仓后不再继续持有的股票进行卖出平仓
            sell_stock = [i for i in self.buy_stocks_pre if i not in long_list]
            print('sell_stock', sell_stock)
            if len(sell_stock) > 0:
                print("-----------对不再持有的股票进行平仓--------------")
                for stock in sell_stock:
                    data = self.getdatabyname(stock)
                    if self.getposition(data).size > 0 :
                        od = self.close(data=data)  
                        self.order_list.append(od) # 记录卖出订单

            # 买入此次调仓的股票：多退少补原则
            print("-----------买入此次调仓期的股票--------------")
            for stock in long_list:
                w = buy_stocks_data.query(f"sec_code=='{stock}'")['weight'].iloc[0] # 提取持仓权重
                data = self.getdatabyname(stock)
                order = self.order_target_percent(data=data, target=w*0.95) # 为减少可用资金不足的情况，留 5% 的现金做备用
                self.order_list.append(order)
                
            self.buy_stocks_pre = long_list  # 保存此次调仓的股票列表
        
    #订单日志    
    def notify_order(self, order):
        # 未被处理的订单
        if order.status in [order.Submitted, order.Accepted]:
            return
        # 已被处理的订单
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                    (order.ref,
                     order.executed.price,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.size,
                     order.data._name))
            else:  # Sell
                self.log('SELL EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                        (order.ref,
                         order.executed.price,
                         order.executed.value,
                         order.executed.comm,
                         order.executed.size,
                         order.data._name))

# %%
# 实例化大脑
cerebro_ = bt.Cerebro() 

# 按股票代码，依次循环传入数据
for stock in daily_price['sec_code'].unique():
    # 日期对齐
    data = pd.DataFrame(index=daily_price.index.unique())
    df = daily_price.query(f"sec_code=='{stock}'")[['open','high','low','close','volume','openinterest']]
    data_ = pd.merge(data, df, left_index=True, right_index=True, how='left')
    data_.loc[:,['volume','openinterest']] = data_.loc[:,['volume','openinterest']].fillna(0)
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(method='pad')
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(0)
    datafeed = bt.feeds.PandasData(dataname=data_, fromdate=datetime.datetime(2019,1,2), todate=datetime.datetime(2021,1,28))
    cerebro_.adddata(datafeed, name=stock)
    print(f"{stock} Done !")
# Out:
# 600000 Done !
# 600004 Done !
# 600009 Done !
# 600010 Done !
# 600011 Done !
# 600015 Done !
# 600016 Done !
# 600018 Done !
# 600019 Done !
# 600023 Done !
# 600025 Done !
# 600027 Done !
# 600028 Done !
# 600029 Done !
# 600030 Done !
# 600031 Done !
# 600036 Done !
# 600038 Done !
# 600048 Done !
# 600050 Done !
# 600061 Done !
# 600066 Done !
# 600068 Done !
# 600085 Done !
# 600089 Done !
# 600100 Done !
# 600104 Done !
# 600109 Done !
# 600111 Done !
# 600115 Done !
# 600118 Done !
# 600153 Done !
# 600157 Done !
# 600170 Done !
# 600176 Done !
# 600177 Done !
# 600188 Done !
# 600196 Done !
# 600208 Done !
# 600219 Done !
# 600221 Done !
# 600233 Done !
# 600271 Done !
# 600276 Done !
# 600297 Done !
# 600309 Done !
# 600332 Done !
# 600339 Done !
# 600340 Done !
# 600346 Done !
# 600352 Done !
# 600362 Done !
# 600369 Done !
# 600372 Done !
# 600383 Done !
# 600390 Done !
# 600398 Done !
# 600406 Done !
# 600415 Done !
# 600436 Done !
# 600438 Done !
# 600482 Done !
# 600487 Done !
# 600489 Done !
# 600498 Done !
# 600516 Done !
# 600518 Done !
# 600519 Done !
# 600522 Done !
# 600535 Done !
# 600547 Done !
# 600549 Done !
# 600566 Done !
# 600570 Done !
# 600583 Done !
# 600585 Done !
# 600588 Done !
# 600606 Done !
# 600637 Done !
# 600660 Done !
# 600674 Done !
# 600688 Done !
# 600690 Done !
# 600703 Done !
# 600704 Done !
# 600705 Done !
# 600739 Done !
# 600741 Done !
# 600760 Done !
# 600795 Done !
# 600809 Done !
# 600816 Done !
# 600837 Done !
# 600867 Done !
# 600886 Done !
# 600887 Done !
# 600893 Done !
# 600900 Done !
# 600909 Done !
# 600919 Done !
# 600926 Done !
# 600958 Done !
# 600977 Done !
# 600998 Done !
# 600999 Done !
# 601006 Done !
# 601009 Done !
# 601012 Done !
# 601018 Done !
# 601021 Done !
# 601066 Done !
# 601088 Done !
# 601108 Done !
# 601111 Done !
# 601117 Done !
# 601138 Done !
# 601155 Done !
# 601166 Done !
# 601169 Done !
# 601186 Done !
# 601198 Done !
# 601211 Done !
# 601212 Done !
# 601216 Done !
# 601225 Done !
# 601228 Done !
# 601229 Done !
# 601238 Done !
# 601288 Done !
# 601318 Done !
# 601328 Done !
# 601333 Done !
# 601336 Done !
# 601360 Done !
# 601377 Done !
# 601390 Done !
# 601398 Done !
# 601555 Done !
# 601600 Done !
# 601601 Done !
# 601607 Done !
# 601611 Done !
# 601618 Done !
# 601628 Done !
# 601633 Done !
# 601668 Done !
# 601669 Done !
# 601688 Done !
# 601727 Done !
# 601766 Done !
# 601788 Done !
# 601800 Done !
# 601808 Done !
# 601818 Done !
# 601828 Done !
# 601838 Done !
# 601857 Done !
# 601877 Done !
# 601878 Done !
# 601881 Done !
# 601888 Done !
# 601898 Done !
# 601899 Done !
# 601901 Done !
# 601919 Done !
# 601933 Done !
# 601939 Done !
# 601985 Done !
# 601988 Done !
# 601989 Done !
# 601991 Done !
# 601992 Done !
# 601997 Done !
# 601998 Done !
# 603156 Done !
# 603160 Done !
# 603259 Done !
# 603260 Done !
# 603288 Done !
# 603799 Done !
# 603833 Done !
# 603858 Done !
# 603986 Done !
# 603993 Done !
# 000001 Done !
# 000002 Done !
# 000063 Done !
# 000069 Done !
# 000100 Done !
# 000157 Done !
# 000166 Done !
# 000333 Done !
# 000338 Done !
# 000402 Done !
# 000408 Done !
# 000413 Done !
# 000415 Done !
# 000423 Done !
# 000425 Done !
# 000503 Done !
# 000538 Done !
# 000553 Done !
# 000568 Done !
# 000625 Done !
# 000627 Done !
# 000630 Done !
# 000651 Done !
# 000661 Done !
# 000671 Done !
# 000703 Done !
# 000709 Done !
# 000725 Done !
# 000728 Done !
# 000768 Done !
# 000776 Done !
# 000783 Done !
# 000786 Done !
# 000792 Done !
# 000826 Done !
# 000839 Done !
# 000858 Done !
# 000876 Done !
# 000895 Done !
# 000898 Done !
# 000938 Done !
# 000959 Done !
# 000961 Done !
# 000963 Done !
# 000983 Done !
# 001965 Done !
# 001979 Done !
# 002001 Done !
# 002007 Done !
# 002008 Done !
# 002024 Done !
# 002027 Done !
# 002032 Done !
# 002044 Done !
# 002050 Done !
# 002065 Done !
# 002081 Done !
# 002085 Done !
# 002120 Done !
# 002142 Done !
# 002146 Done !
# 002153 Done !
# 002179 Done !
# 002202 Done !
# 002230 Done !
# 002236 Done !
# 002241 Done !
# 002252 Done !
# 002271 Done !
# 002294 Done !
# 002304 Done !
# 002310 Done !
# 002311 Done !
# 002352 Done !
# 002411 Done !
# 002415 Done !
# 002422 Done !
# 002450 Done !
# 002456 Done !
# 002460 Done !
# 002466 Done !
# 002468 Done !
# 002475 Done !
# 002493 Done !
# 002508 Done !
# 002555 Done !
# 002558 Done !
# 002572 Done !
# 002594 Done !
# 002601 Done !
# 002602 Done !
# 002624 Done !
# 002625 Done !
# 002673 Done !
# 002714 Done !
# 002736 Done !
# 002773 Done !
# 002797 Done !
# 002925 Done !
# 300003 Done !
# 300015 Done !
# 300017 Done !
# 300024 Done !
# 300033 Done !
# 300059 Done !
# 300070 Done !
# 300072 Done !
# 300122 Done !
# 300124 Done !
# 300136 Done !
# 300142 Done !
# 300144 Done !
# 300251 Done !
# 300296 Done !
# 300408 Done !
# 300433 Done !

# %% [markdown]
# # 三、添加分析器

# %%
cerebro = deepcopy(cerebro_)  # 深度复制已经导入数据的 cerebro_，避免重复导入数据 
# 初始资金 100,000,000    
cerebro.broker.setcash(100000.0) 
# 添加策略
cerebro.addstrategy(TestStrategy, buy_stocks=trade_info) # 通过修改参数 buy_stocks ，使用同一策略回测不同的持仓列表

# 添加分析指标
# 返回年初至年末的年度收益率
cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='_AnnualReturn')
# 计算最大回撤相关指标
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='_DrawDown')
# 计算年化收益
cerebro.addanalyzer(bt.analyzers.Returns, _name='_Returns', tann=252)
# 计算年化夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='_SharpeRatio', timeframe=bt.TimeFrame.Days, annualize=True, riskfreerate=0) # 计算夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio_A, _name='_SharpeRatio_A')
# 返回收益率时序
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')

# 启动回测
result = cerebro.run()
# Out:
# 2019-01-02, 当前总资产 100000.00
# --------------2019-01-02 为调仓日----------
# long_list ['000063', '000333', '000503', '000568', '000651', '000661', '000858', '000963', '001979', '002001', '002007', '002008', '002024', '002027', '002044', '002081', '002179', '002202', '002230', '002236', '002271', '002304', '002310', '002415', '002450', '002456', '002460', '002466', '002475', '002572', '002594', '300003', '300015', '300059', '300070', '300122', '300136', '300144', '300408', '300433', '600104', '600176', '600196', '600271', '600276', '600332', '600519', '600535', '600570', '600809', '600867', '600887', '601012', '601318', '601336', '601878', '601992', '603259', '603799', '603986']
# sell_stock []
# -----------买入此次调仓期的股票--------------
# 2019-01-03, BUY EXECUTED, ref:48415, Price: 19.59, Cost: 1567.20, Comm 0.00, Size: 80.00, Stock: 000063
# 2019-01-03, BUY EXECUTED, ref:48416, Price: 36.26, Cost: 1559.18, Comm 0.00, Size: 43.00, Stock: 000333
# 2019-01-03, BUY EXECUTED, ref:48417, Price: 15.57, Cost: 1588.14, Comm 0.00, Size: 102.00, Stock: 000503
# 2019-01-03, BUY EXECUTED, ref:48418, Price: 39.60, Cost: 1544.40, Comm 0.00, Size: 39.00, Stock: 000568
# 2019-01-03, BUY EXECUTED, ref:48419, Price: 35.80, Cost: 1575.20, Comm 0.00, Size: 44.00, Stock: 000651
# 2019-01-03, BUY EXECUTED, ref:48420, Price: 170.00, Cost: 1530.00, Comm 0.00, Size: 9.00, Stock: 000661
# 2019-01-03, BUY EXECUTED, ref:48421, Price: 50.04, Cost: 1551.24, Comm 0.00, Size: 31.00, Stock: 000858
# 2019-01-03, BUY EXECUTED, ref:48422, Price: 23.70, Cost: 1564.20, Comm 0.00, Size: 66.00, Stock: 000963
# 2019-01-03, BUY EXECUTED, ref:48423, Price: 16.75, Cost: 1574.50, Comm 0.00, Size: 94.00, Stock: 001979
# 2019-01-03, BUY EXECUTED, ref:48424, Price: 14.40, Cost: 1584.00, Comm 0.00, Size: 110.00, Stock: 002001
# 2019-01-03, BUY EXECUTED, ref:48425, Price: 29.82, Cost: 1550.64, Comm 0.00, Size: 52.00, Stock: 002007
# 2019-01-03, BUY EXECUTED, ref:48426, Price: 29.00, Cost: 1566.00, Comm 0.00, Size: 54.00, Stock: 002008
# 2019-01-03, BUY EXECUTED, ref:48427, Price: 10.02, Cost: 1573.14, Comm 0.00, Size: 157.00, Stock: 002024
# 2019-01-03, BUY EXECUTED, ref:48428, Price: 4.97, Cost: 1565.55, Comm 0.00, Size: 315.00, Stock: 002027
# 2019-01-03, BUY EXECUTED, ref:48429, Price: 13.86, Cost: 1524.60, Comm 0.00, Size: 110.00, Stock: 002044
# 2019-01-03, BUY EXECUTED, ref:48430, Price: 7.95, Cost: 1590.00, Comm 0.00, Size: 200.00, Stock: 002081
# 2019-01-03, BUY EXECUTED, ref:48431, Price: 34.00, Cost: 1564.00, Comm 0.00, Size: 46.00, Stock: 002179
# 2019-01-03, BUY EXECUTED, ref:48432, Price: 9.70, Cost: 1581.10, Comm 0.00, Size: 163.00, Stock: 002202
# 2019-01-03, BUY EXECUTED, ref:48433, Price: 24.98, Cost: 1573.74, Comm 0.00, Size: 63.00, Stock: 002230
# 2019-01-03, BUY EXECUTED, ref:48434, Price: 11.21, Cost: 1580.61, Comm 0.00, Size: 141.00, Stock: 002236
# 2019-01-03, BUY EXECUTED, ref:48435, Price: 13.05, Cost: 1579.05, Comm 0.00, Size: 121.00, Stock: 002271
# 2019-01-03, BUY EXECUTED, ref:48436, Price: 91.00, Cost: 1547.00, Comm 0.00, Size: 17.00, Stock: 002304
# 2019-01-03, BUY EXECUTED, ref:48437, Price: 6.95, Cost: 1584.60, Comm 0.00, Size: 228.00, Stock: 002310
# 2019-01-03, BUY EXECUTED, ref:48438, Price: 25.53, Cost: 1557.33, Comm 0.00, Size: 61.00, Stock: 002415
# 2019-01-03, BUY EXECUTED, ref:48439, Price: 7.19, Cost: 1567.42, Comm 0.00, Size: 218.00, Stock: 002450
# 2019-01-03, BUY EXECUTED, ref:48440, Price: 9.10, Cost: 1565.20, Comm 0.00, Size: 172.00, Stock: 002456
# 2019-01-03, BUY EXECUTED, ref:48441, Price: 21.70, Cost: 1562.40, Comm 0.00, Size: 72.00, Stock: 002460
# 2019-01-03, BUY EXECUTED, ref:48442, Price: 28.70, Cost: 1549.80, Comm 0.00, Size: 54.00, Stock: 002466
# 2019-01-03, BUY EXECUTED, ref:48443, Price: 13.80, Cost: 1531.80, Comm 0.00, Size: 111.00, Stock: 002475
# 2019-01-03, BUY EXECUTED, ref:48444, Price: 16.30, Cost: 1581.10, Comm 0.00, Size: 97.00, Stock: 002572
# 2019-01-03, BUY EXECUTED, ref:48445, Price: 49.26, Cost: 1576.32, Comm 0.00, Size: 32.00, Stock: 002594
# 2019-01-03, BUY EXECUTED, ref:48446, Price: 19.17, Cost: 1591.11, Comm 0.00, Size: 83.00, Stock: 300003
# 2019-01-03, BUY EXECUTED, ref:48447, Price: 24.62, Cost: 1575.68, Comm 0.00, Size: 64.00, Stock: 300015
# 2019-01-03, BUY EXECUTED, ref:48448, Price: 11.85, Cost: 1576.05, Comm 0.00, Size: 133.00, Stock: 300059
# 2019-01-03, BUY EXECUTED, ref:48449, Price: 7.70, Cost: 1593.90, Comm 0.00, Size: 207.00, Stock: 300070
# 2019-01-03, BUY EXECUTED, ref:48450, Price: 36.18, Cost: 1555.74, Comm 0.00, Size: 43.00, Stock: 300122
# 2019-01-03, BUY EXECUTED, ref:48451, Price: 21.40, Cost: 1540.80, Comm 0.00, Size: 72.00, Stock: 300136
# 2019-01-03, BUY EXECUTED, ref:48452, Price: 19.41, Cost: 1572.21, Comm 0.00, Size: 81.00, Stock: 300144
# 2019-01-03, BUY EXECUTED, ref:48453, Price: 16.02, Cost: 1553.94, Comm 0.00, Size: 97.00, Stock: 300408
# 2019-01-03, BUY EXECUTED, ref:48454, Price: 6.35, Cost: 1568.45, Comm 0.00, Size: 247.00, Stock: 300433
# 2019-01-03, BUY EXECUTED, ref:48455, Price: 25.25, Cost: 1565.50, Comm 0.00, Size: 62.00, Stock: 600104
# 2019-01-03, BUY EXECUTED, ref:48456, Price: 9.53, Cost: 1591.51, Comm 0.00, Size: 167.00, Stock: 600176
# 2019-01-03, BUY EXECUTED, ref:48457, Price: 21.55, Cost: 1573.15, Comm 0.00, Size: 73.00, Stock: 600196
# 2019-01-03, BUY EXECUTED, ref:48458, Price: 23.00, Cost: 1564.00, Comm 0.00, Size: 68.00, Stock: 600271
# 2019-01-03, BUY EXECUTED, ref:48459, Price: 52.23, Cost: 1514.67, Comm 0.00, Size: 29.00, Stock: 600276
# 2019-01-03, BUY EXECUTED, ref:48460, Price: 34.16, Cost: 1571.36, Comm 0.00, Size: 46.00, Stock: 600332
# 2019-01-03, BUY EXECUTED, ref:48461, Price: 599.97, Cost: 1199.94, Comm 0.00, Size: 2.00, Stock: 600519
# 2019-01-03, BUY EXECUTED, ref:48462, Price: 17.90, Cost: 1575.20, Comm 0.00, Size: 88.00, Stock: 600535
# 2019-01-03, BUY EXECUTED, ref:48463, Price: 50.03, Cost: 1550.93, Comm 0.00, Size: 31.00, Stock: 600570
# 2019-01-03, BUY EXECUTED, ref:48464, Price: 34.05, Cost: 1566.30, Comm 0.00, Size: 46.00, Stock: 600809
# 2019-01-03, BUY EXECUTED, ref:48465, Price: 13.90, Cost: 1584.60, Comm 0.00, Size: 114.00, Stock: 600867
# 2019-01-03, BUY EXECUTED, ref:48466, Price: 22.51, Cost: 1575.70, Comm 0.00, Size: 70.00, Stock: 600887
# 2019-01-03, BUY EXECUTED, ref:48467, Price: 17.40, Cost: 1583.40, Comm 0.00, Size: 91.00, Stock: 601012
# 2019-01-03, BUY EXECUTED, ref:48468, Price: 55.15, Cost: 1544.20, Comm 0.00, Size: 28.00, Stock: 601318
# 2019-01-03, BUY EXECUTED, ref:48469, Price: 41.20, Cost: 1565.60, Comm 0.00, Size: 38.00, Stock: 601336
# 2019-01-03, BUY EXECUTED, ref:48470, Price: 7.21, Cost: 1586.20, Comm 0.00, Size: 220.00, Stock: 601878
# 2019-01-03, BUY EXECUTED, ref:48471, Price: 3.36, Cost: 1582.56, Comm 0.00, Size: 471.00, Stock: 601992
# 2019-01-03, BUY EXECUTED, ref:48472, Price: 72.00, Cost: 1584.00, Comm 0.00, Size: 22.00, Stock: 603259
# 2019-01-03, BUY EXECUTED, ref:48473, Price: 29.25, Cost: 1579.50, Comm 0.00, Size: 54.00, Stock: 603799
# 2019-01-03, BUY EXECUTED, ref:48474, Price: 59.79, Cost: 1554.54, Comm 0.00, Size: 26.00, Stock: 603986
# 2019-01-03, 当前总资产 98681.51
# --------------2019-01-03 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000063', '000333', '000503', '000568', '000661', '000728', '000776', '000786', '000792', '000963', '002008', '002032', '002179', '002202', '002236', '002252', '002271', '002450', '002456', '002475', '002555', '002594', '002673', '002714', '300003', '300059', '300122', '300124', '300136', '300296', '300408', '300433', '600031', '600104', '600118', '600271', '600309', '600332', '600352', '600436', '600438', '600487', '600498', '600516', '600519', '600522', '600570', '600585', '600588', '600760', '600809', '600867', '600887', '601108', '601318', '601688', '601877', '601878', '601888', '603986']
# sell_stock ['000651', '000858', '001979', '002001', '002007', '002024', '002027', '002044', '002081', '002230', '002304', '002310', '002415', '002460', '002466', '002572', '300015', '300070', '300144', '600176', '600196', '600276', '600535', '601012', '601336', '601992', '603259', '603799']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-04, SELL EXECUTED, ref:48475, Price: 35.72, Cost: 1575.20, Comm 0.00, Size: -44.00, Stock: 000651
# 2019-01-04, SELL EXECUTED, ref:48476, Price: 48.23, Cost: 1551.24, Comm 0.00, Size: -31.00, Stock: 000858
# 2019-01-04, SELL EXECUTED, ref:48477, Price: 16.85, Cost: 1574.50, Comm 0.00, Size: -94.00, Stock: 001979
# 2019-01-04, SELL EXECUTED, ref:48478, Price: 13.93, Cost: 1584.00, Comm 0.00, Size: -110.00, Stock: 002001
# 2019-01-04, SELL EXECUTED, ref:48479, Price: 30.11, Cost: 1550.64, Comm 0.00, Size: -52.00, Stock: 002007
# 2019-01-04, SELL EXECUTED, ref:48480, Price: 10.00, Cost: 1573.14, Comm 0.00, Size: -157.00, Stock: 002024
# 2019-01-04, SELL EXECUTED, ref:48481, Price: 5.03, Cost: 1565.55, Comm 0.00, Size: -315.00, Stock: 002027
# 2019-01-04, SELL EXECUTED, ref:48482, Price: 13.76, Cost: 1524.60, Comm 0.00, Size: -110.00, Stock: 002044
# 2019-01-04, SELL EXECUTED, ref:48483, Price: 7.82, Cost: 1590.00, Comm 0.00, Size: -200.00, Stock: 002081
# 2019-01-04, SELL EXECUTED, ref:48484, Price: 25.16, Cost: 1573.74, Comm 0.00, Size: -63.00, Stock: 002230
# 2019-01-04, SELL EXECUTED, ref:48485, Price: 88.00, Cost: 1547.00, Comm 0.00, Size: -17.00, Stock: 002304
# 2019-01-04, SELL EXECUTED, ref:48486, Price: 6.75, Cost: 1584.60, Comm 0.00, Size: -228.00, Stock: 002310
# 2019-01-04, SELL EXECUTED, ref:48487, Price: 25.15, Cost: 1557.33, Comm 0.00, Size: -61.00, Stock: 002415
# 2019-01-04, SELL EXECUTED, ref:48488, Price: 21.74, Cost: 1562.40, Comm 0.00, Size: -72.00, Stock: 002460
# 2019-01-04, SELL EXECUTED, ref:48489, Price: 28.80, Cost: 1549.80, Comm 0.00, Size: -54.00, Stock: 002466
# 2019-01-04, SELL EXECUTED, ref:48490, Price: 15.81, Cost: 1581.10, Comm 0.00, Size: -97.00, Stock: 002572
# 2019-01-04, SELL EXECUTED, ref:48491, Price: 24.54, Cost: 1575.68, Comm 0.00, Size: -64.00, Stock: 300015
# 2019-01-04, SELL EXECUTED, ref:48492, Price: 7.61, Cost: 1593.90, Comm 0.00, Size: -207.00, Stock: 300070
# 2019-01-04, SELL EXECUTED, ref:48493, Price: 18.80, Cost: 1572.21, Comm 0.00, Size: -81.00, Stock: 300144
# 2019-01-04, SELL EXECUTED, ref:48494, Price: 9.40, Cost: 1591.51, Comm 0.00, Size: -167.00, Stock: 600176
# 2019-01-04, SELL EXECUTED, ref:48495, Price: 20.80, Cost: 1573.15, Comm 0.00, Size: -73.00, Stock: 600196
# 2019-01-04, SELL EXECUTED, ref:48496, Price: 50.30, Cost: 1514.67, Comm 0.00, Size: -29.00, Stock: 600276
# 2019-01-04, SELL EXECUTED, ref:48497, Price: 17.01, Cost: 1575.20, Comm 0.00, Size: -88.00, Stock: 600535
# 2019-01-04, SELL EXECUTED, ref:48498, Price: 17.50, Cost: 1583.40, Comm 0.00, Size: -91.00, Stock: 601012
# 2019-01-04, SELL EXECUTED, ref:48499, Price: 41.17, Cost: 1565.60, Comm 0.00, Size: -38.00, Stock: 601336
# 2019-01-04, SELL EXECUTED, ref:48500, Price: 3.23, Cost: 1582.56, Comm 0.00, Size: -471.00, Stock: 601992
# 2019-01-04, SELL EXECUTED, ref:48501, Price: 70.80, Cost: 1584.00, Comm 0.00, Size: -22.00, Stock: 603259
# 2019-01-04, SELL EXECUTED, ref:48502, Price: 28.73, Cost: 1579.50, Comm 0.00, Size: -54.00, Stock: 603799
# 2019-01-04, BUY EXECUTED, ref:48503, Price: 18.51, Cost: 55.53, Comm 0.00, Size: 3.00, Stock: 000063
# 2019-01-04, BUY EXECUTED, ref:48504, Price: 14.95, Cost: 14.95, Comm 0.00, Size: 1.00, Stock: 000503
# 2019-01-04, BUY EXECUTED, ref:48505, Price: 37.81, Cost: 37.81, Comm 0.00, Size: 1.00, Stock: 000568
# 2019-01-04, BUY EXECUTED, ref:48506, Price: 7.15, Cost: 1551.55, Comm 0.00, Size: 217.00, Stock: 000728
# 2019-01-04, BUY EXECUTED, ref:48507, Price: 12.20, Cost: 1537.20, Comm 0.00, Size: 126.00, Stock: 000776
# 2019-01-04, BUY EXECUTED, ref:48508, Price: 13.48, Cost: 1550.20, Comm 0.00, Size: 115.00, Stock: 000786
# 2019-01-04, BUY EXECUTED, ref:48509, Price: 6.61, Cost: 1533.52, Comm 0.00, Size: 232.00, Stock: 000792
# 2019-01-04, BUY EXECUTED, ref:48510, Price: 23.19, Cost: 23.19, Comm 0.00, Size: 1.00, Stock: 000963
# 2019-01-04, BUY EXECUTED, ref:48511, Price: 26.80, Cost: 53.60, Comm 0.00, Size: 2.00, Stock: 002008
# 2019-01-04, BUY EXECUTED, ref:48512, Price: 48.17, Cost: 1541.44, Comm 0.00, Size: 32.00, Stock: 002032
# 2019-01-04, BUY EXECUTED, ref:48513, Price: 9.20, Cost: 36.80, Comm 0.00, Size: 4.00, Stock: 002202
# 2019-01-04, BUY EXECUTED, ref:48514, Price: 7.08, Cost: 1529.28, Comm 0.00, Size: 216.00, Stock: 002252
# 2019-01-04, BUY EXECUTED, ref:48515, Price: 12.30, Cost: 49.20, Comm 0.00, Size: 4.00, Stock: 002271
# 2019-01-04, BUY EXECUTED, ref:48516, Price: 6.81, Cost: 40.86, Comm 0.00, Size: 6.00, Stock: 002450
# 2019-01-04, BUY EXECUTED, ref:48517, Price: 8.47, Cost: 59.29, Comm 0.00, Size: 7.00, Stock: 002456
# 2019-01-04, BUY EXECUTED, ref:48518, Price: 13.15, Cost: 65.75, Comm 0.00, Size: 5.00, Stock: 002475
# 2019-01-04, BUY EXECUTED, ref:48519, Price: 9.05, Cost: 1565.65, Comm 0.00, Size: 173.00, Stock: 002555
# 2019-01-04, BUY EXECUTED, ref:48520, Price: 7.73, Cost: 1538.27, Comm 0.00, Size: 199.00, Stock: 002673
# 2019-01-04, BUY EXECUTED, ref:48521, Price: 28.45, Cost: 1536.30, Comm 0.00, Size: 54.00, Stock: 002714
# 2019-01-04, SELL EXECUTED, ref:48522, Price: 11.82, Cost: 23.70, Comm 0.00, Size: -2.00, Stock: 300059
# 2019-01-04, BUY EXECUTED, ref:48523, Price: 20.00, Cost: 1560.00, Comm 0.00, Size: 78.00, Stock: 300124
# 2019-01-04, BUY EXECUTED, ref:48524, Price: 19.00, Cost: 114.00, Comm 0.00, Size: 6.00, Stock: 300136
# 2019-01-04, BUY EXECUTED, ref:48525, Price: 6.97, Cost: 1540.37, Comm 0.00, Size: 221.00, Stock: 300296
# 2019-01-04, BUY EXECUTED, ref:48526, Price: 14.90, Cost: 104.30, Comm 0.00, Size: 7.00, Stock: 300408
# 2019-01-04, BUY EXECUTED, ref:48527, Price: 7.87, Cost: 1550.39, Comm 0.00, Size: 197.00, Stock: 600031
# 2019-01-04, BUY EXECUTED, ref:48528, Price: 24.51, Cost: 24.51, Comm 0.00, Size: 1.00, Stock: 600104
# 2019-01-04, BUY EXECUTED, ref:48529, Price: 18.30, Cost: 1537.20, Comm 0.00, Size: 84.00, Stock: 600118
# 2019-01-04, BUY EXECUTED, ref:48530, Price: 27.13, Cost: 1519.28, Comm 0.00, Size: 56.00, Stock: 600309
# 2019-01-04, BUY EXECUTED, ref:48531, Price: 8.83, Cost: 1545.25, Comm 0.00, Size: 175.00, Stock: 600352
# 2019-01-04, BUY EXECUTED, ref:48532, Price: 80.50, Cost: 1529.50, Comm 0.00, Size: 19.00, Stock: 600436
# 2019-01-04, BUY EXECUTED, ref:48533, Price: 7.81, Cost: 1530.76, Comm 0.00, Size: 196.00, Stock: 600438
# 2019-01-04, BUY EXECUTED, ref:48534, Price: 16.15, Cost: 1518.10, Comm 0.00, Size: 94.00, Stock: 600487
# 2019-01-04, BUY EXECUTED, ref:48535, Price: 27.18, Cost: 1522.08, Comm 0.00, Size: 56.00, Stock: 600498
# 2019-01-04, BUY EXECUTED, ref:48536, Price: 16.50, Cost: 1534.50, Comm 0.00, Size: 93.00, Stock: 600516
# 2019-01-04, BUY EXECUTED, ref:48537, Price: 7.85, Cost: 1538.60, Comm 0.00, Size: 196.00, Stock: 600522
# 2019-01-04, BUY EXECUTED, ref:48538, Price: 27.77, Cost: 1527.35, Comm 0.00, Size: 55.00, Stock: 600585
# 2019-01-04, BUY EXECUTED, ref:48539, Price: 22.00, Cost: 1518.00, Comm 0.00, Size: 69.00, Stock: 600588
# 2019-01-04, BUY EXECUTED, ref:48540, Price: 28.51, Cost: 1539.54, Comm 0.00, Size: 54.00, Stock: 600760
# 2019-01-04, BUY EXECUTED, ref:48541, Price: 32.64, Cost: 32.64, Comm 0.00, Size: 1.00, Stock: 600809
# 2019-01-04, BUY EXECUTED, ref:48542, Price: 11.90, Cost: 142.80, Comm 0.00, Size: 12.00, Stock: 600867
# 2019-01-04, BUY EXECUTED, ref:48543, Price: 7.22, Cost: 1537.86, Comm 0.00, Size: 213.00, Stock: 601108
# 2019-01-04, BUY EXECUTED, ref:48544, Price: 16.43, Cost: 1544.42, Comm 0.00, Size: 94.00, Stock: 601688
# 2019-01-04, BUY EXECUTED, ref:48545, Price: 22.12, Cost: 1526.28, Comm 0.00, Size: 69.00, Stock: 601877
# 2019-01-04, SELL EXECUTED, ref:48546, Price: 7.19, Cost: 36.05, Comm 0.00, Size: -5.00, Stock: 601878
# 2019-01-04, BUY EXECUTED, ref:48547, Price: 56.05, Cost: 1513.35, Comm 0.00, Size: 27.00, Stock: 601888
# 2019-01-04, 当前总资产 101822.80
# --------------2019-01-04 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000166', '000408', '000425', '000553', '000627', '000630', '000709', '000839', '000959', '001965', '002120', '002241', '002352', '002468', '002493', '002558', '002602', '002624', '002925', '300024', '600068', '600157', '600170', '600177', '600219', '600221', '600233', '600297', '600362', '600415', '600489', '600518', '600547', '600674', '600688', '600760', '600886', '600900', '600919', '600926', '600998', '601018', '601117', '601212', '601216', '601228', '601238', '601333', '601360', '601600', '601633', '601727', '601888', '601898', '601919', '601985', '601989', '601991', '603156', '603833']
# sell_stock ['000063', '000333', '000503', '000568', '000661', '000728', '000776', '000786', '000792', '000963', '002008', '002032', '002179', '002202', '002236', '002252', '002271', '002450', '002456', '002475', '002555', '002594', '002673', '002714', '300003', '300059', '300122', '300124', '300136', '300296', '300408', '300433', '600031', '600104', '600118', '600271', '600309', '600332', '600352', '600436', '600438', '600487', '600498', '600516', '600519', '600522', '600570', '600585', '600588', '600809', '600867', '600887', '601108', '601318', '601688', '601877', '601878', '603986']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-07, SELL EXECUTED, ref:48548, Price: 19.45, Cost: 1622.73, Comm 0.00, Size: -83.00, Stock: 000063
# 2019-01-07, SELL EXECUTED, ref:48549, Price: 37.66, Cost: 1559.18, Comm 0.00, Size: -43.00, Stock: 000333
# 2019-01-07, SELL EXECUTED, ref:48550, Price: 15.93, Cost: 1603.09, Comm 0.00, Size: -103.00, Stock: 000503
# 2019-01-07, SELL EXECUTED, ref:48551, Price: 39.13, Cost: 1582.21, Comm 0.00, Size: -40.00, Stock: 000568
# 2019-01-07, SELL EXECUTED, ref:48552, Price: 173.32, Cost: 1530.00, Comm 0.00, Size: -9.00, Stock: 000661
# 2019-01-07, SELL EXECUTED, ref:48553, Price: 7.79, Cost: 1551.55, Comm 0.00, Size: -217.00, Stock: 000728
# 2019-01-07, SELL EXECUTED, ref:48554, Price: 13.25, Cost: 1537.20, Comm 0.00, Size: -126.00, Stock: 000776
# 2019-01-07, SELL EXECUTED, ref:48555, Price: 14.13, Cost: 1550.20, Comm 0.00, Size: -115.00, Stock: 000786
# 2019-01-07, SELL EXECUTED, ref:48556, Price: 6.81, Cost: 1533.52, Comm 0.00, Size: -232.00, Stock: 000792
# 2019-01-07, SELL EXECUTED, ref:48557, Price: 25.55, Cost: 1587.39, Comm 0.00, Size: -67.00, Stock: 000963
# 2019-01-07, SELL EXECUTED, ref:48558, Price: 28.16, Cost: 1619.60, Comm 0.00, Size: -56.00, Stock: 002008
# 2019-01-07, SELL EXECUTED, ref:48559, Price: 50.99, Cost: 1541.44, Comm 0.00, Size: -32.00, Stock: 002032
# 2019-01-07, SELL EXECUTED, ref:48560, Price: 34.80, Cost: 1564.00, Comm 0.00, Size: -46.00, Stock: 002179
# 2019-01-07, SELL EXECUTED, ref:48561, Price: 9.96, Cost: 1617.90, Comm 0.00, Size: -167.00, Stock: 002202
# 2019-01-07, SELL EXECUTED, ref:48562, Price: 11.69, Cost: 1580.61, Comm 0.00, Size: -141.00, Stock: 002236
# 2019-01-07, SELL EXECUTED, ref:48563, Price: 7.69, Cost: 1529.28, Comm 0.00, Size: -216.00, Stock: 002252
# 2019-01-07, SELL EXECUTED, ref:48564, Price: 13.26, Cost: 1628.25, Comm 0.00, Size: -125.00, Stock: 002271
# 2019-01-07, SELL EXECUTED, ref:48565, Price: 7.01, Cost: 1608.28, Comm 0.00, Size: -224.00, Stock: 002450
# 2019-01-07, SELL EXECUTED, ref:48566, Price: 8.99, Cost: 1624.49, Comm 0.00, Size: -179.00, Stock: 002456
# 2019-01-07, SELL EXECUTED, ref:48567, Price: 13.25, Cost: 1597.55, Comm 0.00, Size: -116.00, Stock: 002475
# 2019-01-07, SELL EXECUTED, ref:48568, Price: 9.57, Cost: 1565.65, Comm 0.00, Size: -173.00, Stock: 002555
# 2019-01-07, SELL EXECUTED, ref:48569, Price: 50.85, Cost: 1576.32, Comm 0.00, Size: -32.00, Stock: 002594
# 2019-01-07, SELL EXECUTED, ref:48570, Price: 8.39, Cost: 1538.27, Comm 0.00, Size: -199.00, Stock: 002673
# 2019-01-07, SELL EXECUTED, ref:48571, Price: 29.79, Cost: 1536.30, Comm 0.00, Size: -54.00, Stock: 002714
# 2019-01-07, SELL EXECUTED, ref:48572, Price: 19.45, Cost: 1591.11, Comm 0.00, Size: -83.00, Stock: 300003
# 2019-01-07, SELL EXECUTED, ref:48573, Price: 12.70, Cost: 1552.35, Comm 0.00, Size: -131.00, Stock: 300059
# 2019-01-07, SELL EXECUTED, ref:48574, Price: 37.95, Cost: 1555.74, Comm 0.00, Size: -43.00, Stock: 300122
# 2019-01-07, SELL EXECUTED, ref:48575, Price: 20.65, Cost: 1560.00, Comm 0.00, Size: -78.00, Stock: 300124
# 2019-01-07, SELL EXECUTED, ref:48576, Price: 20.13, Cost: 1654.80, Comm 0.00, Size: -78.00, Stock: 300136
# 2019-01-07, SELL EXECUTED, ref:48577, Price: 7.30, Cost: 1540.37, Comm 0.00, Size: -221.00, Stock: 300296
# 2019-01-07, SELL EXECUTED, ref:48578, Price: 15.36, Cost: 1658.24, Comm 0.00, Size: -104.00, Stock: 300408
# 2019-01-07, SELL EXECUTED, ref:48579, Price: 6.46, Cost: 1568.45, Comm 0.00, Size: -247.00, Stock: 300433
# 2019-01-07, SELL EXECUTED, ref:48580, Price: 8.12, Cost: 1550.39, Comm 0.00, Size: -197.00, Stock: 600031
# 2019-01-07, SELL EXECUTED, ref:48581, Price: 24.80, Cost: 1590.01, Comm 0.00, Size: -63.00, Stock: 600104
# 2019-01-07, SELL EXECUTED, ref:48582, Price: 18.59, Cost: 1537.20, Comm 0.00, Size: -84.00, Stock: 600118
# 2019-01-07, SELL EXECUTED, ref:48583, Price: 24.95, Cost: 1564.00, Comm 0.00, Size: -68.00, Stock: 600271
# 2019-01-07, SELL EXECUTED, ref:48584, Price: 28.79, Cost: 1519.28, Comm 0.00, Size: -56.00, Stock: 600309
# 2019-01-07, SELL EXECUTED, ref:48585, Price: 34.30, Cost: 1571.36, Comm 0.00, Size: -46.00, Stock: 600332
# 2019-01-07, SELL EXECUTED, ref:48586, Price: 9.09, Cost: 1545.25, Comm 0.00, Size: -175.00, Stock: 600352
# 2019-01-07, SELL EXECUTED, ref:48587, Price: 83.85, Cost: 1529.50, Comm 0.00, Size: -19.00, Stock: 600436
# 2019-01-07, SELL EXECUTED, ref:48588, Price: 8.18, Cost: 1530.76, Comm 0.00, Size: -196.00, Stock: 600438
# 2019-01-07, SELL EXECUTED, ref:48589, Price: 17.00, Cost: 1518.10, Comm 0.00, Size: -94.00, Stock: 600487
# 2019-01-07, SELL EXECUTED, ref:48590, Price: 27.96, Cost: 1522.08, Comm 0.00, Size: -56.00, Stock: 600498
# 2019-01-07, SELL EXECUTED, ref:48591, Price: 17.19, Cost: 1534.50, Comm 0.00, Size: -93.00, Stock: 600516
# 2019-01-07, SELL EXECUTED, ref:48592, Price: 608.00, Cost: 1199.94, Comm 0.00, Size: -2.00, Stock: 600519
# 2019-01-07, SELL EXECUTED, ref:48593, Price: 8.24, Cost: 1538.60, Comm 0.00, Size: -196.00, Stock: 600522
# 2019-01-07, SELL EXECUTED, ref:48594, Price: 53.80, Cost: 1550.93, Comm 0.00, Size: -31.00, Stock: 600570
# 2019-01-07, SELL EXECUTED, ref:48595, Price: 28.70, Cost: 1527.35, Comm 0.00, Size: -55.00, Stock: 600585
# 2019-01-07, SELL EXECUTED, ref:48596, Price: 23.65, Cost: 1518.00, Comm 0.00, Size: -69.00, Stock: 600588
# 2019-01-07, SELL EXECUTED, ref:48597, Price: 34.11, Cost: 1598.94, Comm 0.00, Size: -47.00, Stock: 600809
# 2019-01-07, SELL EXECUTED, ref:48598, Price: 12.55, Cost: 1727.40, Comm 0.00, Size: -126.00, Stock: 600867
# 2019-01-07, SELL EXECUTED, ref:48599, Price: 22.74, Cost: 1575.70, Comm 0.00, Size: -70.00, Stock: 600887
# 2019-01-07, SELL EXECUTED, ref:48600, Price: 7.99, Cost: 1537.86, Comm 0.00, Size: -213.00, Stock: 601108
# 2019-01-07, SELL EXECUTED, ref:48601, Price: 57.09, Cost: 1544.20, Comm 0.00, Size: -28.00, Stock: 601318
# 2019-01-07, SELL EXECUTED, ref:48602, Price: 17.77, Cost: 1544.42, Comm 0.00, Size: -94.00, Stock: 601688
# 2019-01-07, SELL EXECUTED, ref:48603, Price: 22.46, Cost: 1526.28, Comm 0.00, Size: -69.00, Stock: 601877
# 2019-01-07, SELL EXECUTED, ref:48604, Price: 8.02, Cost: 1550.15, Comm 0.00, Size: -215.00, Stock: 601878
# 2019-01-07, SELL EXECUTED, ref:48605, Price: 61.20, Cost: 1554.54, Comm 0.00, Size: -26.00, Stock: 603986
# 2019-01-07, BUY EXECUTED, ref:48606, Price: 4.40, Cost: 1601.60, Comm 0.00, Size: 364.00, Stock: 000166
# 2019-01-07, BUY EXECUTED, ref:48607, Price: 11.21, Cost: 1614.24, Comm 0.00, Size: 144.00, Stock: 000408
# 2019-01-07, BUY EXECUTED, ref:48608, Price: 3.27, Cost: 1621.92, Comm 0.00, Size: 496.00, Stock: 000425
# 2019-01-07, BUY EXECUTED, ref:48609, Price: 9.57, Cost: 1655.61, Comm 0.00, Size: 173.00, Stock: 000553
# 2019-01-07, BUY EXECUTED, ref:48610, Price: 5.75, Cost: 1627.25, Comm 0.00, Size: 283.00, Stock: 000627
# 2019-01-07, BUY EXECUTED, ref:48611, Price: 2.01, Cost: 1620.06, Comm 0.00, Size: 806.00, Stock: 000630
# 2019-01-07, BUY EXECUTED, ref:48612, Price: 2.91, Cost: 1615.05, Comm 0.00, Size: 555.00, Stock: 000709
# 2019-01-07, BUY EXECUTED, ref:48613, Price: 3.58, Cost: 1618.16, Comm 0.00, Size: 452.00, Stock: 000839
# 2019-01-07, BUY EXECUTED, ref:48614, Price: 3.86, Cost: 1613.48, Comm 0.00, Size: 418.00, Stock: 000959
# 2019-01-07, BUY EXECUTED, ref:48615, Price: 8.10, Cost: 1611.90, Comm 0.00, Size: 199.00, Stock: 001965
# 2019-01-07, BUY EXECUTED, ref:48616, Price: 30.06, Cost: 1593.18, Comm 0.00, Size: 53.00, Stock: 002120
# 2019-01-07, BUY EXECUTED, ref:48617, Price: 6.95, Cost: 1619.35, Comm 0.00, Size: 233.00, Stock: 002241
# 2019-01-07, BUY EXECUTED, ref:48618, Price: 32.88, Cost: 1578.24, Comm 0.00, Size: 48.00, Stock: 002352
# 2019-01-07, BUY EXECUTED, ref:48619, Price: 16.41, Cost: 1608.18, Comm 0.00, Size: 98.00, Stock: 002468
# 2019-01-07, BUY EXECUTED, ref:48620, Price: 10.32, Cost: 1620.24, Comm 0.00, Size: 157.00, Stock: 002493
# 2019-01-07, BUY EXECUTED, ref:48621, Price: 19.55, Cost: 1603.10, Comm 0.00, Size: 82.00, Stock: 002558
# 2019-01-07, BUY EXECUTED, ref:48622, Price: 20.18, Cost: 1594.22, Comm 0.00, Size: 79.00, Stock: 002602
# 2019-01-07, BUY EXECUTED, ref:48623, Price: 26.28, Cost: 1576.80, Comm 0.00, Size: 60.00, Stock: 002624
# 2019-01-07, BUY EXECUTED, ref:48624, Price: 42.77, Cost: 1625.26, Comm 0.00, Size: 38.00, Stock: 002925
# 2019-01-07, BUY EXECUTED, ref:48625, Price: 13.80, Cost: 1614.60, Comm 0.00, Size: 117.00, Stock: 300024
# 2019-01-07, BUY EXECUTED, ref:48626, Price: 6.40, Cost: 1612.80, Comm 0.00, Size: 252.00, Stock: 600068
# 2019-01-07, BUY EXECUTED, ref:48627, Price: 1.33, Cost: 1623.93, Comm 0.00, Size: 1221.00, Stock: 600157
# 2019-01-07, BUY EXECUTED, ref:48628, Price: 3.14, Cost: 1620.24, Comm 0.00, Size: 516.00, Stock: 600170
# 2019-01-07, BUY EXECUTED, ref:48629, Price: 7.34, Cost: 1622.14, Comm 0.00, Size: 221.00, Stock: 600177
# 2019-01-07, BUY EXECUTED, ref:48630, Price: 2.16, Cost: 1617.84, Comm 0.00, Size: 749.00, Stock: 600219
# 2019-01-07, BUY EXECUTED, ref:48631, Price: 1.91, Cost: 1612.04, Comm 0.00, Size: 844.00, Stock: 600221
# 2019-01-07, BUY EXECUTED, ref:48632, Price: 10.06, Cost: 1619.66, Comm 0.00, Size: 161.00, Stock: 600233
# 2019-01-07, BUY EXECUTED, ref:48633, Price: 4.18, Cost: 1617.66, Comm 0.00, Size: 387.00, Stock: 600297
# 2019-01-07, BUY EXECUTED, ref:48634, Price: 13.28, Cost: 1620.16, Comm 0.00, Size: 122.00, Stock: 600362
# 2019-01-07, BUY EXECUTED, ref:48635, Price: 3.68, Cost: 1637.60, Comm 0.00, Size: 445.00, Stock: 600415
# 2019-01-07, BUY EXECUTED, ref:48636, Price: 8.50, Cost: 1572.50, Comm 0.00, Size: 185.00, Stock: 600489
# 2019-01-07, BUY EXECUTED, ref:48637, Price: 7.07, Cost: 1590.75, Comm 0.00, Size: 225.00, Stock: 600518
# 2019-01-07, BUY EXECUTED, ref:48638, Price: 30.40, Cost: 1550.40, Comm 0.00, Size: 51.00, Stock: 600547
# 2019-01-07, BUY EXECUTED, ref:48639, Price: 8.38, Cost: 1608.96, Comm 0.00, Size: 192.00, Stock: 600674
# 2019-01-07, BUY EXECUTED, ref:48640, Price: 5.16, Cost: 1620.24, Comm 0.00, Size: 314.00, Stock: 600688
# 2019-01-07, BUY EXECUTED, ref:48641, Price: 29.65, Cost: 29.65, Comm 0.00, Size: 1.00, Stock: 600760
# 2019-01-07, BUY EXECUTED, ref:48642, Price: 7.82, Cost: 1610.92, Comm 0.00, Size: 206.00, Stock: 600886
# 2019-01-07, BUY EXECUTED, ref:48643, Price: 15.39, Cost: 1615.95, Comm 0.00, Size: 105.00, Stock: 600900
# 2019-01-07, BUY EXECUTED, ref:48644, Price: 6.10, Cost: 1610.40, Comm 0.00, Size: 264.00, Stock: 600919
# 2019-01-07, BUY EXECUTED, ref:48645, Price: 7.59, Cost: 1609.08, Comm 0.00, Size: 212.00, Stock: 600926
# 2019-01-07, BUY EXECUTED, ref:48646, Price: 14.62, Cost: 1608.20, Comm 0.00, Size: 110.00, Stock: 600998
# 2019-01-07, BUY EXECUTED, ref:48647, Price: 3.42, Cost: 1621.08, Comm 0.00, Size: 474.00, Stock: 601018
# 2019-01-07, BUY EXECUTED, ref:48648, Price: 5.49, Cost: 1619.55, Comm 0.00, Size: 295.00, Stock: 601117
# 2019-01-07, BUY EXECUTED, ref:48649, Price: 3.06, Cost: 1591.20, Comm 0.00, Size: 520.00, Stock: 601212
# 2019-01-07, BUY EXECUTED, ref:48650, Price: 2.70, Cost: 1628.10, Comm 0.00, Size: 603.00, Stock: 601216
# 2019-01-07, BUY EXECUTED, ref:48651, Price: 4.03, Cost: 1612.00, Comm 0.00, Size: 400.00, Stock: 601228
# 2019-01-07, BUY EXECUTED, ref:48652, Price: 10.39, Cost: 1610.45, Comm 0.00, Size: 155.00, Stock: 601238
# 2019-01-07, BUY EXECUTED, ref:48653, Price: 3.28, Cost: 1617.04, Comm 0.00, Size: 493.00, Stock: 601333
# 2019-01-07, BUY EXECUTED, ref:48654, Price: 20.70, Cost: 1614.60, Comm 0.00, Size: 78.00, Stock: 601360
# 2019-01-07, BUY EXECUTED, ref:48655, Price: 3.59, Cost: 1619.09, Comm 0.00, Size: 451.00, Stock: 601600
# 2019-01-07, BUY EXECUTED, ref:48656, Price: 5.68, Cost: 1618.80, Comm 0.00, Size: 285.00, Stock: 601633
# 2019-01-07, BUY EXECUTED, ref:48657, Price: 5.10, Cost: 1611.60, Comm 0.00, Size: 316.00, Stock: 601727
# 2019-01-07, BUY EXECUTED, ref:48658, Price: 57.38, Cost: 57.38, Comm 0.00, Size: 1.00, Stock: 601888
# 2019-01-07, BUY EXECUTED, ref:48659, Price: 4.75, Cost: 1615.00, Comm 0.00, Size: 340.00, Stock: 601898
# 2019-01-07, BUY EXECUTED, ref:48660, Price: 4.29, Cost: 1608.75, Comm 0.00, Size: 375.00, Stock: 601919
# 2019-01-07, BUY EXECUTED, ref:48661, Price: 5.34, Cost: 1612.68, Comm 0.00, Size: 302.00, Stock: 601985
# 2019-01-07, BUY EXECUTED, ref:48662, Price: 4.52, Cost: 1613.64, Comm 0.00, Size: 357.00, Stock: 601989
# 2019-01-07, BUY EXECUTED, ref:48663, Price: 3.20, Cost: 1619.20, Comm 0.00, Size: 506.00, Stock: 601991
# 2019-01-07, BUY EXECUTED, ref:48664, Price: 42.26, Cost: 1605.88, Comm 0.00, Size: 38.00, Stock: 603156
# 2019-01-07, BUY EXECUTED, ref:48665, Price: 77.68, Cost: 1553.60, Comm 0.00, Size: 20.00, Stock: 603833
# 2019-01-07, 当前总资产 103369.91
# --------------2019-01-07 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000002', '000166', '000333', '000783', '000858', '000963', '001979', '002027', '002032', '002146', '002252', '002271', '002304', '002468', '002555', '002572', '002673', '002736', '002797', '300003', '300033', '300296', '600027', '600048', '600061', '600104', '600109', '600170', '600271', '600340', '600369', '600383', '600519', '600690', '600739', '600809', '600837', '600900', '600909', '600958', '600999', '601066', '601108', '601155', '601186', '601198', '601211', '601229', '601318', '601328', '601390', '601601', '601628', '601668', '601688', '601766', '601788', '601800', '601818', '601881']
# sell_stock ['000408', '000425', '000553', '000627', '000630', '000709', '000839', '000959', '001965', '002120', '002241', '002352', '002493', '002558', '002602', '002624', '002925', '300024', '600068', '600157', '600177', '600219', '600221', '600233', '600297', '600362', '600415', '600489', '600518', '600547', '600674', '600688', '600760', '600886', '600919', '600926', '600998', '601018', '601117', '601212', '601216', '601228', '601238', '601333', '601360', '601600', '601633', '601727', '601888', '601898', '601919', '601985', '601989', '601991', '603156', '603833']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-08, SELL EXECUTED, ref:48666, Price: 11.23, Cost: 1614.24, Comm 0.00, Size: -144.00, Stock: 000408
# 2019-01-08, SELL EXECUTED, ref:48667, Price: 3.27, Cost: 1621.92, Comm 0.00, Size: -496.00, Stock: 000425
# 2019-01-08, SELL EXECUTED, ref:48668, Price: 9.28, Cost: 1655.61, Comm 0.00, Size: -173.00, Stock: 000553
# 2019-01-08, SELL EXECUTED, ref:48669, Price: 5.68, Cost: 1627.25, Comm 0.00, Size: -283.00, Stock: 000627
# 2019-01-08, SELL EXECUTED, ref:48670, Price: 2.02, Cost: 1620.06, Comm 0.00, Size: -806.00, Stock: 000630
# 2019-01-08, SELL EXECUTED, ref:48671, Price: 2.93, Cost: 1615.05, Comm 0.00, Size: -555.00, Stock: 000709
# 2019-01-08, SELL EXECUTED, ref:48672, Price: 3.68, Cost: 1618.16, Comm 0.00, Size: -452.00, Stock: 000839
# 2019-01-08, SELL EXECUTED, ref:48673, Price: 3.88, Cost: 1613.48, Comm 0.00, Size: -418.00, Stock: 000959
# 2019-01-08, SELL EXECUTED, ref:48674, Price: 8.16, Cost: 1611.90, Comm 0.00, Size: -199.00, Stock: 001965
# 2019-01-08, SELL EXECUTED, ref:48675, Price: 29.85, Cost: 1593.18, Comm 0.00, Size: -53.00, Stock: 002120
# 2019-01-08, SELL EXECUTED, ref:48676, Price: 7.03, Cost: 1619.35, Comm 0.00, Size: -233.00, Stock: 002241
# 2019-01-08, SELL EXECUTED, ref:48677, Price: 32.80, Cost: 1578.24, Comm 0.00, Size: -48.00, Stock: 002352
# 2019-01-08, SELL EXECUTED, ref:48678, Price: 10.24, Cost: 1620.24, Comm 0.00, Size: -157.00, Stock: 002493
# 2019-01-08, SELL EXECUTED, ref:48679, Price: 19.87, Cost: 1603.10, Comm 0.00, Size: -82.00, Stock: 002558
# 2019-01-08, SELL EXECUTED, ref:48680, Price: 20.10, Cost: 1594.22, Comm 0.00, Size: -79.00, Stock: 002602
# 2019-01-08, SELL EXECUTED, ref:48681, Price: 26.49, Cost: 1576.80, Comm 0.00, Size: -60.00, Stock: 002624
# 2019-01-08, SELL EXECUTED, ref:48682, Price: 44.59, Cost: 1625.26, Comm 0.00, Size: -38.00, Stock: 002925
# 2019-01-08, SELL EXECUTED, ref:48683, Price: 13.85, Cost: 1614.60, Comm 0.00, Size: -117.00, Stock: 300024
# 2019-01-08, SELL EXECUTED, ref:48684, Price: 6.46, Cost: 1612.80, Comm 0.00, Size: -252.00, Stock: 600068
# 2019-01-08, SELL EXECUTED, ref:48685, Price: 1.49, Cost: 1623.93, Comm 0.00, Size: -1221.00, Stock: 600157
# 2019-01-08, SELL EXECUTED, ref:48686, Price: 7.29, Cost: 1622.14, Comm 0.00, Size: -221.00, Stock: 600177
# 2019-01-08, SELL EXECUTED, ref:48687, Price: 2.18, Cost: 1617.84, Comm 0.00, Size: -749.00, Stock: 600219
# 2019-01-08, SELL EXECUTED, ref:48688, Price: 1.91, Cost: 1612.04, Comm 0.00, Size: -844.00, Stock: 600221
# 2019-01-08, SELL EXECUTED, ref:48689, Price: 10.06, Cost: 1619.66, Comm 0.00, Size: -161.00, Stock: 600233
# 2019-01-08, SELL EXECUTED, ref:48690, Price: 4.17, Cost: 1617.66, Comm 0.00, Size: -387.00, Stock: 600297
# 2019-01-08, SELL EXECUTED, ref:48691, Price: 13.50, Cost: 1620.16, Comm 0.00, Size: -122.00, Stock: 600362
# 2019-01-08, SELL EXECUTED, ref:48692, Price: 3.85, Cost: 1637.60, Comm 0.00, Size: -445.00, Stock: 600415
# 2019-01-08, SELL EXECUTED, ref:48693, Price: 8.52, Cost: 1572.50, Comm 0.00, Size: -185.00, Stock: 600489
# 2019-01-08, SELL EXECUTED, ref:48694, Price: 7.20, Cost: 1590.75, Comm 0.00, Size: -225.00, Stock: 600518
# 2019-01-08, SELL EXECUTED, ref:48695, Price: 30.62, Cost: 1550.40, Comm 0.00, Size: -51.00, Stock: 600547
# 2019-01-08, SELL EXECUTED, ref:48696, Price: 8.39, Cost: 1608.96, Comm 0.00, Size: -192.00, Stock: 600674
# 2019-01-08, SELL EXECUTED, ref:48697, Price: 5.18, Cost: 1620.24, Comm 0.00, Size: -314.00, Stock: 600688
# 2019-01-08, SELL EXECUTED, ref:48698, Price: 30.49, Cost: 1569.19, Comm 0.00, Size: -55.00, Stock: 600760
# 2019-01-08, SELL EXECUTED, ref:48699, Price: 7.84, Cost: 1610.92, Comm 0.00, Size: -206.00, Stock: 600886
# 2019-01-08, SELL EXECUTED, ref:48700, Price: 6.06, Cost: 1610.40, Comm 0.00, Size: -264.00, Stock: 600919
# 2019-01-08, SELL EXECUTED, ref:48701, Price: 7.51, Cost: 1609.08, Comm 0.00, Size: -212.00, Stock: 600926
# 2019-01-08, SELL EXECUTED, ref:48702, Price: 14.70, Cost: 1608.20, Comm 0.00, Size: -110.00, Stock: 600998
# 2019-01-08, SELL EXECUTED, ref:48703, Price: 3.44, Cost: 1621.08, Comm 0.00, Size: -474.00, Stock: 601018
# 2019-01-08, SELL EXECUTED, ref:48704, Price: 5.47, Cost: 1619.55, Comm 0.00, Size: -295.00, Stock: 601117
# 2019-01-08, SELL EXECUTED, ref:48705, Price: 3.15, Cost: 1591.20, Comm 0.00, Size: -520.00, Stock: 601212
# 2019-01-08, SELL EXECUTED, ref:48706, Price: 2.69, Cost: 1628.10, Comm 0.00, Size: -603.00, Stock: 601216
# 2019-01-08, SELL EXECUTED, ref:48707, Price: 4.05, Cost: 1612.00, Comm 0.00, Size: -400.00, Stock: 601228
# 2019-01-08, SELL EXECUTED, ref:48708, Price: 10.42, Cost: 1610.45, Comm 0.00, Size: -155.00, Stock: 601238
# 2019-01-08, SELL EXECUTED, ref:48709, Price: 3.37, Cost: 1617.04, Comm 0.00, Size: -493.00, Stock: 601333
# 2019-01-08, SELL EXECUTED, ref:48710, Price: 20.79, Cost: 1614.60, Comm 0.00, Size: -78.00, Stock: 601360
# 2019-01-08, SELL EXECUTED, ref:48711, Price: 3.61, Cost: 1619.09, Comm 0.00, Size: -451.00, Stock: 601600
# 2019-01-08, SELL EXECUTED, ref:48712, Price: 5.73, Cost: 1618.80, Comm 0.00, Size: -285.00, Stock: 601633
# 2019-01-08, SELL EXECUTED, ref:48713, Price: 5.15, Cost: 1611.60, Comm 0.00, Size: -316.00, Stock: 601727
# 2019-01-08, SELL EXECUTED, ref:48714, Price: 57.82, Cost: 1570.73, Comm 0.00, Size: -28.00, Stock: 601888
# 2019-01-08, SELL EXECUTED, ref:48715, Price: 4.79, Cost: 1615.00, Comm 0.00, Size: -340.00, Stock: 601898
# 2019-01-08, SELL EXECUTED, ref:48716, Price: 4.35, Cost: 1608.75, Comm 0.00, Size: -375.00, Stock: 601919
# 2019-01-08, SELL EXECUTED, ref:48717, Price: 5.42, Cost: 1612.68, Comm 0.00, Size: -302.00, Stock: 601985
# 2019-01-08, SELL EXECUTED, ref:48718, Price: 4.60, Cost: 1613.64, Comm 0.00, Size: -357.00, Stock: 601989
# 2019-01-08, SELL EXECUTED, ref:48719, Price: 3.20, Cost: 1619.20, Comm 0.00, Size: -506.00, Stock: 601991
# 2019-01-08, SELL EXECUTED, ref:48720, Price: 42.40, Cost: 1605.88, Comm 0.00, Size: -38.00, Stock: 603156
# 2019-01-08, SELL EXECUTED, ref:48721, Price: 80.50, Cost: 1553.60, Comm 0.00, Size: -20.00, Stock: 603833
# 2019-01-08, BUY EXECUTED, ref:48722, Price: 25.05, Cost: 1628.25, Comm 0.00, Size: 65.00, Stock: 000002
# 2019-01-08, BUY EXECUTED, ref:48723, Price: 4.37, Cost: 39.33, Comm 0.00, Size: 9.00, Stock: 000166
# 2019-01-08, BUY EXECUTED, ref:48724, Price: 37.05, Cost: 1630.20, Comm 0.00, Size: 44.00, Stock: 000333
# 2019-01-08, BUY EXECUTED, ref:48725, Price: 5.70, Cost: 1635.90, Comm 0.00, Size: 287.00, Stock: 000783
# 2019-01-08, BUY EXECUTED, ref:48726, Price: 49.48, Cost: 1632.84, Comm 0.00, Size: 33.00, Stock: 000858
# 2019-01-08, BUY EXECUTED, ref:48727, Price: 25.45, Cost: 1628.80, Comm 0.00, Size: 64.00, Stock: 000963
# 2019-01-08, BUY EXECUTED, ref:48728, Price: 17.72, Cost: 1630.24, Comm 0.00, Size: 92.00, Stock: 001979
# 2019-01-08, BUY EXECUTED, ref:48729, Price: 5.31, Cost: 1635.48, Comm 0.00, Size: 308.00, Stock: 002027
# 2019-01-08, BUY EXECUTED, ref:48730, Price: 50.75, Cost: 1624.00, Comm 0.00, Size: 32.00, Stock: 002032
# 2019-01-08, BUY EXECUTED, ref:48731, Price: 8.01, Cost: 1642.05, Comm 0.00, Size: 205.00, Stock: 002146
# 2019-01-08, BUY EXECUTED, ref:48732, Price: 7.75, Cost: 1627.50, Comm 0.00, Size: 210.00, Stock: 002252
# 2019-01-08, BUY EXECUTED, ref:48733, Price: 13.39, Cost: 1633.58, Comm 0.00, Size: 122.00, Stock: 002271
# 2019-01-08, BUY EXECUTED, ref:48734, Price: 89.50, Cost: 1611.00, Comm 0.00, Size: 18.00, Stock: 002304
# 2019-01-08, BUY EXECUTED, ref:48735, Price: 16.50, Cost: 16.50, Comm 0.00, Size: 1.00, Stock: 002468
# 2019-01-08, BUY EXECUTED, ref:48736, Price: 9.75, Cost: 1628.25, Comm 0.00, Size: 167.00, Stock: 002555
# 2019-01-08, BUY EXECUTED, ref:48737, Price: 16.69, Cost: 1635.62, Comm 0.00, Size: 98.00, Stock: 002572
# 2019-01-08, BUY EXECUTED, ref:48738, Price: 8.34, Cost: 1634.64, Comm 0.00, Size: 196.00, Stock: 002673
# 2019-01-08, BUY EXECUTED, ref:48739, Price: 8.99, Cost: 1618.20, Comm 0.00, Size: 180.00, Stock: 002736
# 2019-01-08, BUY EXECUTED, ref:48740, Price: 6.18, Cost: 1612.98, Comm 0.00, Size: 261.00, Stock: 002797
# 2019-01-08, BUY EXECUTED, ref:48741, Price: 19.15, Cost: 1627.75, Comm 0.00, Size: 85.00, Stock: 300003
# 2019-01-08, BUY EXECUTED, ref:48742, Price: 41.92, Cost: 1592.96, Comm 0.00, Size: 38.00, Stock: 300033
# 2019-01-08, BUY EXECUTED, ref:48743, Price: 7.26, Cost: 1626.24, Comm 0.00, Size: 224.00, Stock: 300296
# 2019-01-08, BUY EXECUTED, ref:48744, Price: 4.55, Cost: 1628.90, Comm 0.00, Size: 358.00, Stock: 600027
# 2019-01-08, BUY EXECUTED, ref:48745, Price: 12.18, Cost: 1632.12, Comm 0.00, Size: 134.00, Stock: 600048
# 2019-01-08, BUY EXECUTED, ref:48746, Price: 9.88, Cost: 1620.32, Comm 0.00, Size: 164.00, Stock: 600061
# 2019-01-08, BUY EXECUTED, ref:48747, Price: 24.59, Cost: 1622.94, Comm 0.00, Size: 66.00, Stock: 600104
# 2019-01-08, BUY EXECUTED, ref:48748, Price: 7.80, Cost: 1622.40, Comm 0.00, Size: 208.00, Stock: 600109
# 2019-01-08, BUY EXECUTED, ref:48749, Price: 3.13, Cost: 9.39, Comm 0.00, Size: 3.00, Stock: 600170
# 2019-01-08, BUY EXECUTED, ref:48750, Price: 24.73, Cost: 1607.45, Comm 0.00, Size: 65.00, Stock: 600271
# 2019-01-08, BUY EXECUTED, ref:48751, Price: 26.30, Cost: 1604.30, Comm 0.00, Size: 61.00, Stock: 600340
# 2019-01-08, BUY EXECUTED, ref:48752, Price: 4.05, Cost: 1624.05, Comm 0.00, Size: 401.00, Stock: 600369
# 2019-01-08, BUY EXECUTED, ref:48753, Price: 9.87, Cost: 1628.55, Comm 0.00, Size: 165.00, Stock: 600383
# 2019-01-08, BUY EXECUTED, ref:48754, Price: 605.50, Cost: 1211.00, Comm 0.00, Size: 2.00, Stock: 600519
# 2019-01-08, BUY EXECUTED, ref:48755, Price: 13.41, Cost: 1622.61, Comm 0.00, Size: 121.00, Stock: 600690
# 2019-01-08, BUY EXECUTED, ref:48756, Price: 10.73, Cost: 1630.96, Comm 0.00, Size: 152.00, Stock: 600739
# 2019-01-08, BUY EXECUTED, ref:48757, Price: 33.60, Cost: 1612.80, Comm 0.00, Size: 48.00, Stock: 600809
# 2019-01-08, BUY EXECUTED, ref:48758, Price: 9.57, Cost: 1626.90, Comm 0.00, Size: 170.00, Stock: 600837
# 2019-01-08, BUY EXECUTED, ref:48759, Price: 15.20, Cost: 30.40, Comm 0.00, Size: 2.00, Stock: 600900
# 2019-01-08, BUY EXECUTED, ref:48760, Price: 5.16, Cost: 1625.40, Comm 0.00, Size: 315.00, Stock: 600909
# 2019-01-08, BUY EXECUTED, ref:48761, Price: 8.62, Cost: 1620.56, Comm 0.00, Size: 188.00, Stock: 600958
# 2019-01-08, BUY EXECUTED, ref:48762, Price: 14.09, Cost: 1620.35, Comm 0.00, Size: 115.00, Stock: 600999
# 2019-01-08, BUY EXECUTED, ref:48763, Price: 10.22, Cost: 1635.20, Comm 0.00, Size: 160.00, Stock: 601066
# 2019-01-08, BUY EXECUTED, ref:48764, Price: 7.88, Cost: 1623.28, Comm 0.00, Size: 206.00, Stock: 601108
# 2019-01-08, BUY EXECUTED, ref:48765, Price: 25.16, Cost: 1610.24, Comm 0.00, Size: 64.00, Stock: 601155
# 2019-01-08, BUY EXECUTED, ref:48766, Price: 11.15, Cost: 1627.90, Comm 0.00, Size: 146.00, Stock: 601186
# 2019-01-08, BUY EXECUTED, ref:48767, Price: 10.26, Cost: 1621.08, Comm 0.00, Size: 158.00, Stock: 601198
# 2019-01-08, BUY EXECUTED, ref:48768, Price: 16.72, Cost: 1621.84, Comm 0.00, Size: 97.00, Stock: 601211
# 2019-01-08, BUY EXECUTED, ref:48769, Price: 11.24, Cost: 1629.80, Comm 0.00, Size: 145.00, Stock: 601229
# 2019-01-08, BUY EXECUTED, ref:48770, Price: 56.05, Cost: 1625.45, Comm 0.00, Size: 29.00, Stock: 601318
# 2019-01-08, BUY EXECUTED, ref:48771, Price: 5.84, Cost: 1635.20, Comm 0.00, Size: 280.00, Stock: 601328
# 2019-01-08, BUY EXECUTED, ref:48772, Price: 7.04, Cost: 1633.28, Comm 0.00, Size: 232.00, Stock: 601390
# 2019-01-08, BUY EXECUTED, ref:48773, Price: 28.44, Cost: 1621.08, Comm 0.00, Size: 57.00, Stock: 601601
# 2019-01-08, BUY EXECUTED, ref:48774, Price: 20.24, Cost: 1619.20, Comm 0.00, Size: 80.00, Stock: 601628
# 2019-01-08, BUY EXECUTED, ref:48775, Price: 5.72, Cost: 1630.20, Comm 0.00, Size: 285.00, Stock: 601668
# 2019-01-08, BUY EXECUTED, ref:48776, Price: 17.70, Cost: 1628.40, Comm 0.00, Size: 92.00, Stock: 601688
# 2019-01-08, BUY EXECUTED, ref:48777, Price: 9.19, Cost: 1626.63, Comm 0.00, Size: 177.00, Stock: 601766
# 2019-01-08, BUY EXECUTED, ref:48778, Price: 9.68, Cost: 1626.24, Comm 0.00, Size: 168.00, Stock: 601788
# 2019-01-08, BUY EXECUTED, ref:48779, Price: 11.35, Cost: 1623.05, Comm 0.00, Size: 143.00, Stock: 601800
# 2019-01-08, BUY EXECUTED, ref:48780, Price: 3.85, Cost: 1640.10, Comm 0.00, Size: 426.00, Stock: 601818
# 2019-01-08, BUY EXECUTED, ref:48781, Price: 7.51, Cost: 1622.16, Comm 0.00, Size: 216.00, Stock: 601881
# 2019-01-08, 当前总资产 103367.19
# --------------2019-01-08 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000001', '000063', '000625', '000776', '000839', '000858', '000963', '002008', '002065', '002153', '002230', '002236', '002252', '002271', '002415', '002450', '002466', '002624', '002673', '002736', '300003', '300015', '300033', '300059', '300072', '300122', '300136', '300296', '600036', '600089', '600111', '600118', '600176', '600188', '600340', '600406', '600436', '600487', '600489', '600498', '600518', '600519', '600522', '600547', '600549', '600570', '600588', '600690', '600739', '600837', '600999', '601198', '601211', '601336', '601377', '601601', '601989', '603799', '603986', '603993']
# sell_stock ['000002', '000166', '000333', '000783', '001979', '002027', '002032', '002146', '002304', '002468', '002555', '002572', '002797', '600027', '600048', '600061', '600104', '600109', '600170', '600271', '600369', '600383', '600809', '600900', '600909', '600958', '601066', '601108', '601155', '601186', '601229', '601318', '601328', '601390', '601628', '601668', '601688', '601766', '601788', '601800', '601818', '601881']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-09, SELL EXECUTED, ref:48782, Price: 25.40, Cost: 1628.25, Comm 0.00, Size: -65.00, Stock: 000002
# 2019-01-09, SELL EXECUTED, ref:48783, Price: 4.39, Cost: 1640.93, Comm 0.00, Size: -373.00, Stock: 000166
# 2019-01-09, SELL EXECUTED, ref:48784, Price: 38.25, Cost: 1630.20, Comm 0.00, Size: -44.00, Stock: 000333
# 2019-01-09, SELL EXECUTED, ref:48785, Price: 5.71, Cost: 1635.90, Comm 0.00, Size: -287.00, Stock: 000783
# 2019-01-09, SELL EXECUTED, ref:48786, Price: 17.90, Cost: 1630.24, Comm 0.00, Size: -92.00, Stock: 001979
# 2019-01-09, SELL EXECUTED, ref:48787, Price: 5.51, Cost: 1635.48, Comm 0.00, Size: -308.00, Stock: 002027
# 2019-01-09, SELL EXECUTED, ref:48788, Price: 51.10, Cost: 1624.00, Comm 0.00, Size: -32.00, Stock: 002032
# 2019-01-09, SELL EXECUTED, ref:48789, Price: 7.89, Cost: 1642.05, Comm 0.00, Size: -205.00, Stock: 002146
# 2019-01-09, SELL EXECUTED, ref:48790, Price: 92.20, Cost: 1611.00, Comm 0.00, Size: -18.00, Stock: 002304
# 2019-01-09, SELL EXECUTED, ref:48791, Price: 16.24, Cost: 1624.68, Comm 0.00, Size: -99.00, Stock: 002468
# 2019-01-09, SELL EXECUTED, ref:48792, Price: 9.60, Cost: 1628.25, Comm 0.00, Size: -167.00, Stock: 002555
# 2019-01-09, SELL EXECUTED, ref:48793, Price: 16.68, Cost: 1635.62, Comm 0.00, Size: -98.00, Stock: 002572
# 2019-01-09, SELL EXECUTED, ref:48794, Price: 6.32, Cost: 1612.98, Comm 0.00, Size: -261.00, Stock: 002797
# 2019-01-09, SELL EXECUTED, ref:48795, Price: 4.62, Cost: 1628.90, Comm 0.00, Size: -358.00, Stock: 600027
# 2019-01-09, SELL EXECUTED, ref:48796, Price: 12.04, Cost: 1632.12, Comm 0.00, Size: -134.00, Stock: 600048
# 2019-01-09, SELL EXECUTED, ref:48797, Price: 9.87, Cost: 1620.32, Comm 0.00, Size: -164.00, Stock: 600061
# 2019-01-09, SELL EXECUTED, ref:48798, Price: 24.99, Cost: 1622.94, Comm 0.00, Size: -66.00, Stock: 600104
# 2019-01-09, SELL EXECUTED, ref:48799, Price: 7.91, Cost: 1622.40, Comm 0.00, Size: -208.00, Stock: 600109
# 2019-01-09, SELL EXECUTED, ref:48800, Price: 3.14, Cost: 1629.63, Comm 0.00, Size: -519.00, Stock: 600170
# 2019-01-09, SELL EXECUTED, ref:48801, Price: 24.75, Cost: 1607.45, Comm 0.00, Size: -65.00, Stock: 600271
# 2019-01-09, SELL EXECUTED, ref:48802, Price: 4.30, Cost: 1624.05, Comm 0.00, Size: -401.00, Stock: 600369
# 2019-01-09, SELL EXECUTED, ref:48803, Price: 9.75, Cost: 1628.55, Comm 0.00, Size: -165.00, Stock: 600383
# 2019-01-09, SELL EXECUTED, ref:48804, Price: 34.00, Cost: 1612.80, Comm 0.00, Size: -48.00, Stock: 600809
# 2019-01-09, SELL EXECUTED, ref:48805, Price: 15.65, Cost: 1646.35, Comm 0.00, Size: -107.00, Stock: 600900
# 2019-01-09, SELL EXECUTED, ref:48806, Price: 5.17, Cost: 1625.40, Comm 0.00, Size: -315.00, Stock: 600909
# 2019-01-09, SELL EXECUTED, ref:48807, Price: 8.67, Cost: 1620.56, Comm 0.00, Size: -188.00, Stock: 600958
# 2019-01-09, SELL EXECUTED, ref:48808, Price: 10.57, Cost: 1635.20, Comm 0.00, Size: -160.00, Stock: 601066
# 2019-01-09, SELL EXECUTED, ref:48809, Price: 7.90, Cost: 1623.28, Comm 0.00, Size: -206.00, Stock: 601108
# 2019-01-09, SELL EXECUTED, ref:48810, Price: 25.20, Cost: 1610.24, Comm 0.00, Size: -64.00, Stock: 601155
# 2019-01-09, SELL EXECUTED, ref:48811, Price: 11.23, Cost: 1627.90, Comm 0.00, Size: -146.00, Stock: 601186
# 2019-01-09, SELL EXECUTED, ref:48812, Price: 11.32, Cost: 1629.80, Comm 0.00, Size: -145.00, Stock: 601229
# 2019-01-09, SELL EXECUTED, ref:48813, Price: 56.20, Cost: 1625.45, Comm 0.00, Size: -29.00, Stock: 601318
# 2019-01-09, SELL EXECUTED, ref:48814, Price: 5.90, Cost: 1635.20, Comm 0.00, Size: -280.00, Stock: 601328
# 2019-01-09, SELL EXECUTED, ref:48815, Price: 7.10, Cost: 1633.28, Comm 0.00, Size: -232.00, Stock: 601390
# 2019-01-09, SELL EXECUTED, ref:48816, Price: 20.20, Cost: 1619.20, Comm 0.00, Size: -80.00, Stock: 601628
# ...
# 2019-12-17, BUY EXECUTED, ref:71237, Price: 8.86, Cost: 26.58, Comm 0.00, Size: 3.00, Stock: 600886
# 2019-12-17, BUY EXECUTED, ref:71238, Price: 7.19, Cost: 21.57, Comm 0.00, Size: 3.00, Stock: 600919
# 2019-12-17, BUY EXECUTED, ref:71239, Price: 3.75, Cost: 2310.00, Comm 0.00, Size: 616.00, Stock: 601018
# 2019-12-17, BUY EXECUTED, ref:71240, Price: 5.61, Cost: 2300.10, Comm 0.00, Size: 410.00, Stock: 601169
# 2019-12-17, BUY EXECUTED, ref:71241, Price: 3.88, Cost: 2293.08, Comm 0.00, Size: 591.00, Stock: 601228
# 2019-12-17, BUY EXECUTED, ref:71242, Price: 3.65, Cost: 2306.80, Comm 0.00, Size: 632.00, Stock: 601288
# 2019-12-17, BUY EXECUTED, ref:71243, Price: 5.54, Cost: 2299.10, Comm 0.00, Size: 415.00, Stock: 601328
# 2019-12-17, BUY EXECUTED, ref:71244, Price: 3.04, Cost: 2298.24, Comm 0.00, Size: 756.00, Stock: 601333
# 2019-12-17, BUY EXECUTED, ref:71245, Price: 5.79, Cost: 2304.42, Comm 0.00, Size: 398.00, Stock: 601398
# 2019-12-17, BUY EXECUTED, ref:71246, Price: 7.03, Cost: 2298.81, Comm 0.00, Size: 327.00, Stock: 601766
# 2019-12-17, BUY EXECUTED, ref:71247, Price: 10.99, Cost: 2296.91, Comm 0.00, Size: 209.00, Stock: 601828
# 2019-12-17, BUY EXECUTED, ref:71248, Price: 8.66, Cost: 2294.90, Comm 0.00, Size: 265.00, Stock: 601838
# 2019-12-17, BUY EXECUTED, ref:71249, Price: 26.41, Cost: 26.41, Comm 0.00, Size: 1.00, Stock: 601877
# 2019-12-17, BUY EXECUTED, ref:71250, Price: 85.58, Cost: 85.58, Comm 0.00, Size: 1.00, Stock: 601888
# 2019-12-17, BUY EXECUTED, ref:71251, Price: 4.82, Cost: 2294.32, Comm 0.00, Size: 476.00, Stock: 601898
# 2019-12-17, BUY EXECUTED, ref:71252, Price: 7.15, Cost: 2295.15, Comm 0.00, Size: 321.00, Stock: 601939
# 2019-12-17, BUY EXECUTED, ref:71253, Price: 3.65, Cost: 2299.50, Comm 0.00, Size: 630.00, Stock: 601988
# 2019-12-17, BUY EXECUTED, ref:71254, Price: 2.42, Cost: 2299.00, Comm 0.00, Size: 950.00, Stock: 601991
# 2019-12-17, BUY EXECUTED, ref:71255, Price: 9.53, Cost: 9.53, Comm 0.00, Size: 1.00, Stock: 601997
# 2019-12-17, BUY EXECUTED, ref:71256, Price: 6.12, Cost: 2295.00, Comm 0.00, Size: 375.00, Stock: 601998
# 2019-12-17, BUY EXECUTED, ref:71257, Price: 28.77, Cost: 2330.37, Comm 0.00, Size: 81.00, Stock: 603260
# 2019-12-17, BUY EXECUTED, ref:71258, Price: 99.00, Cost: 99.00, Comm 0.00, Size: 1.00, Stock: 603833
# 2019-12-17, 当前总资产 146979.91
# --------------2019-12-17 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000069', '000423', '000503', '000671', '000768', '000783', '000786', '000961', '002027', '002044', '002050', '002456', '002555', '002602', '002624', '002673', '002714', '002736', '002773', '002797', '300017', '300033', '300059', '300122', '300124', '300408', '300433', '600009', '600010', '600030', '600048', '600068', '600100', '600109', '600271', '600383', '600438', '600535', '600570', '600690', '600760', '600837', '600926', '600999', '601066', '601108', '601138', '601198', '601228', '601288', '601377', '601555', '601601', '601688', '601878', '601881', '601901', '603799', '603858', '603993']
# sell_stock ['000425', '000538', '000553', '000630', '000661', '000792', '000898', '000959', '001965', '002024', '002032', '002085', '002142', '002294', '002310', '002311', '002493', '002558', '002601', '300024', '600015', '600016', '600018', '600028', '600176', '600177', '600221', '600297', '600436', '600519', '600549', '600660', '600674', '600886', '600919', '601018', '601169', '601328', '601333', '601398', '601766', '601828', '601838', '601857', '601877', '601888', '601898', '601939', '601988', '601991', '601997', '601998', '603156', '603260', '603833']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-12-18, SELL EXECUTED, ref:71259, Price: 5.02, Cost: 2307.36, Comm 0.00, Size: -456.00, Stock: 000425
# 2019-12-18, SELL EXECUTED, ref:71260, Price: 87.39, Cost: 2272.92, Comm 0.00, Size: -26.00, Stock: 000538
# 2019-12-18, SELL EXECUTED, ref:71261, Price: 9.76, Cost: 2296.70, Comm 0.00, Size: -238.00, Stock: 000553
# 2019-12-18, SELL EXECUTED, ref:71262, Price: 2.22, Cost: 2299.00, Comm 0.00, Size: -1045.00, Stock: 000630
# 2019-12-18, SELL EXECUTED, ref:71263, Price: 441.95, Cost: 2269.50, Comm 0.00, Size: -5.00, Stock: 000661
# 2019-12-18, SELL EXECUTED, ref:71264, Price: 7.84, Cost: 2270.70, Comm 0.00, Size: -290.00, Stock: 000792
# 2019-12-18, SELL EXECUTED, ref:71265, Price: 3.22, Cost: 2321.62, Comm 0.00, Size: -721.00, Stock: 000898
# 2019-12-18, SELL EXECUTED, ref:71266, Price: 3.54, Cost: 2299.50, Comm 0.00, Size: -657.00, Stock: 000959
# 2019-12-18, SELL EXECUTED, ref:71267, Price: 8.70, Cost: 2294.57, Comm 0.00, Size: -269.00, Stock: 001965
# 2019-12-18, SELL EXECUTED, ref:71268, Price: 10.20, Cost: 2293.68, Comm 0.00, Size: -228.00, Stock: 002024
# 2019-12-18, SELL EXECUTED, ref:71269, Price: 75.75, Cost: 2264.70, Comm 0.00, Size: -30.00, Stock: 002032
# 2019-12-18, SELL EXECUTED, ref:71270, Price: 7.09, Cost: 2292.27, Comm 0.00, Size: -327.00, Stock: 002085
# 2019-12-18, SELL EXECUTED, ref:71271, Price: 27.88, Cost: 2283.33, Comm 0.00, Size: -83.00, Stock: 002142
# 2019-12-18, SELL EXECUTED, ref:71272, Price: 18.80, Cost: 2294.00, Comm 0.00, Size: -124.00, Stock: 002294
# 2019-12-18, SELL EXECUTED, ref:71273, Price: 4.91, Cost: 2308.68, Comm 0.00, Size: -477.00, Stock: 002310
# 2019-12-18, SELL EXECUTED, ref:71274, Price: 32.70, Cost: 2288.08, Comm 0.00, Size: -74.00, Stock: 002311
# 2019-12-18, SELL EXECUTED, ref:71275, Price: 12.50, Cost: 2332.76, Comm 0.00, Size: -184.00, Stock: 002493
# 2019-12-18, SELL EXECUTED, ref:71276, Price: 17.98, Cost: 2284.59, Comm 0.00, Size: -129.00, Stock: 002558
# 2019-12-18, SELL EXECUTED, ref:71277, Price: 13.59, Cost: 2264.24, Comm 0.00, Size: -174.00, Stock: 002601
# 2019-12-18, SELL EXECUTED, ref:71278, Price: 14.59, Cost: 2300.40, Comm 0.00, Size: -162.00, Stock: 300024
# 2019-12-18, SELL EXECUTED, ref:71279, Price: 7.63, Cost: 2293.60, Comm 0.00, Size: -305.00, Stock: 600015
# 2019-12-18, SELL EXECUTED, ref:71280, Price: 6.31, Cost: 2303.68, Comm 0.00, Size: -368.00, Stock: 600016
# 2019-12-18, SELL EXECUTED, ref:71281, Price: 5.93, Cost: 2302.85, Comm 0.00, Size: -395.00, Stock: 600018
# 2019-12-18, SELL EXECUTED, ref:71282, Price: 5.08, Cost: 2304.18, Comm 0.00, Size: -459.00, Stock: 600028
# 2019-12-18, SELL EXECUTED, ref:71283, Price: 10.36, Cost: 2299.24, Comm 0.00, Size: -229.00, Stock: 600176
# 2019-12-18, SELL EXECUTED, ref:71284, Price: 6.96, Cost: 2294.12, Comm 0.00, Size: -332.00, Stock: 600177
# 2019-12-18, SELL EXECUTED, ref:71285, Price: 1.71, Cost: 2299.92, Comm 0.00, Size: -1369.00, Stock: 600221
# 2019-12-18, SELL EXECUTED, ref:71286, Price: 3.40, Cost: 2298.10, Comm 0.00, Size: -686.00, Stock: 600297
# 2019-12-18, SELL EXECUTED, ref:71287, Price: 103.77, Cost: 2260.94, Comm 0.00, Size: -22.00, Stock: 600436
# 2019-12-18, SELL EXECUTED, ref:71288, Price: 1174.00, Cost: 2299.40, Comm 0.00, Size: -2.00, Stock: 600519
# 2019-12-18, SELL EXECUTED, ref:71289, Price: 12.63, Cost: 2297.10, Comm 0.00, Size: -186.00, Stock: 600549
# 2019-12-18, SELL EXECUTED, ref:71290, Price: 23.15, Cost: 2293.83, Comm 0.00, Size: -99.00, Stock: 600660
# 2019-12-18, SELL EXECUTED, ref:71291, Price: 9.82, Cost: 2298.30, Comm 0.00, Size: -235.00, Stock: 600674
# 2019-12-18, SELL EXECUTED, ref:71292, Price: 8.83, Cost: 2299.86, Comm 0.00, Size: -259.00, Stock: 600886
# 2019-12-18, SELL EXECUTED, ref:71293, Price: 7.23, Cost: 2297.63, Comm 0.00, Size: -320.00, Stock: 600919
# 2019-12-18, SELL EXECUTED, ref:71294, Price: 3.85, Cost: 2310.00, Comm 0.00, Size: -616.00, Stock: 601018
# 2019-12-18, SELL EXECUTED, ref:71295, Price: 5.68, Cost: 2300.10, Comm 0.00, Size: -410.00, Stock: 601169
# 2019-12-18, SELL EXECUTED, ref:71296, Price: 5.60, Cost: 2299.10, Comm 0.00, Size: -415.00, Stock: 601328
# 2019-12-18, SELL EXECUTED, ref:71297, Price: 3.07, Cost: 2298.24, Comm 0.00, Size: -756.00, Stock: 601333
# 2019-12-18, SELL EXECUTED, ref:71298, Price: 5.83, Cost: 2304.42, Comm 0.00, Size: -398.00, Stock: 601398
# 2019-12-18, SELL EXECUTED, ref:71299, Price: 7.16, Cost: 2298.81, Comm 0.00, Size: -327.00, Stock: 601766
# 2019-12-18, SELL EXECUTED, ref:71300, Price: 11.04, Cost: 2296.91, Comm 0.00, Size: -209.00, Stock: 601828
# 2019-12-18, SELL EXECUTED, ref:71301, Price: 8.83, Cost: 2294.90, Comm 0.00, Size: -265.00, Stock: 601838
# 2019-12-18, SELL EXECUTED, ref:71302, Price: 5.85, Cost: 2278.29, Comm 0.00, Size: -399.00, Stock: 601857
# 2019-12-18, SELL EXECUTED, ref:71303, Price: 26.34, Cost: 2306.27, Comm 0.00, Size: -87.00, Stock: 601877
# 2019-12-18, SELL EXECUTED, ref:71304, Price: 85.59, Cost: 2348.33, Comm 0.00, Size: -26.00, Stock: 601888
# 2019-12-18, SELL EXECUTED, ref:71305, Price: 4.87, Cost: 2294.32, Comm 0.00, Size: -476.00, Stock: 601898
# 2019-12-18, SELL EXECUTED, ref:71306, Price: 7.20, Cost: 2295.15, Comm 0.00, Size: -321.00, Stock: 601939
# 2019-12-18, SELL EXECUTED, ref:71307, Price: 3.69, Cost: 2299.50, Comm 0.00, Size: -630.00, Stock: 601988
# 2019-12-18, SELL EXECUTED, ref:71308, Price: 2.46, Cost: 2299.00, Comm 0.00, Size: -950.00, Stock: 601991
# 2019-12-18, SELL EXECUTED, ref:71309, Price: 9.66, Cost: 2282.42, Comm 0.00, Size: -240.00, Stock: 601997
# 2019-12-18, SELL EXECUTED, ref:71310, Price: 6.20, Cost: 2295.00, Comm 0.00, Size: -375.00, Stock: 601998
# 2019-12-18, SELL EXECUTED, ref:71311, Price: 28.30, Cost: 2273.86, Comm 0.00, Size: -82.00, Stock: 603156
# 2019-12-18, SELL EXECUTED, ref:71312, Price: 29.79, Cost: 2330.37, Comm 0.00, Size: -81.00, Stock: 603260
# 2019-12-18, SELL EXECUTED, ref:71313, Price: 105.18, Cost: 2342.78, Comm 0.00, Size: -23.00, Stock: 603833
# 2019-12-18, BUY EXECUTED, ref:71314, Price: 7.46, Cost: 2320.06, Comm 0.00, Size: 311.00, Stock: 000069
# 2019-12-18, BUY EXECUTED, ref:71315, Price: 35.12, Cost: 35.12, Comm 0.00, Size: 1.00, Stock: 000423
# 2019-12-18, BUY EXECUTED, ref:71316, Price: 16.96, Cost: 2340.48, Comm 0.00, Size: 138.00, Stock: 000503
# 2019-12-18, BUY EXECUTED, ref:71317, Price: 7.91, Cost: 2325.54, Comm 0.00, Size: 294.00, Stock: 000671
# 2019-12-18, BUY EXECUTED, ref:71318, Price: 16.65, Cost: 2331.00, Comm 0.00, Size: 140.00, Stock: 000768
# 2019-12-18, BUY EXECUTED, ref:71319, Price: 6.73, Cost: 2308.39, Comm 0.00, Size: 343.00, Stock: 000783
# 2019-12-18, BUY EXECUTED, ref:71320, Price: 23.08, Cost: 2308.00, Comm 0.00, Size: 100.00, Stock: 000786
# 2019-12-18, BUY EXECUTED, ref:71321, Price: 9.76, Cost: 2332.64, Comm 0.00, Size: 239.00, Stock: 000961
# 2019-12-18, BUY EXECUTED, ref:71322, Price: 5.88, Cost: 29.40, Comm 0.00, Size: 5.00, Stock: 002027
# 2019-12-18, BUY EXECUTED, ref:71323, Price: 15.41, Cost: 2311.50, Comm 0.00, Size: 150.00, Stock: 002044
# 2019-12-18, BUY EXECUTED, ref:71324, Price: 16.39, Cost: 2310.99, Comm 0.00, Size: 141.00, Stock: 002050
# 2019-12-18, BUY EXECUTED, ref:71325, Price: 16.98, Cost: 2326.26, Comm 0.00, Size: 137.00, Stock: 002456
# 2019-12-18, BUY EXECUTED, ref:71326, Price: 24.71, Cost: 2298.03, Comm 0.00, Size: 93.00, Stock: 002555
# 2019-12-18, BUY EXECUTED, ref:71327, Price: 10.32, Cost: 2342.64, Comm 0.00, Size: 227.00, Stock: 002602
# 2019-12-18, BUY EXECUTED, ref:71328, Price: 39.96, Cost: 2317.68, Comm 0.00, Size: 58.00, Stock: 002624
# 2019-12-18, BUY EXECUTED, ref:71329, Price: 9.35, Cost: 2318.80, Comm 0.00, Size: 248.00, Stock: 002673
# 2019-12-18, BUY EXECUTED, ref:71330, Price: 83.12, Cost: 2244.24, Comm 0.00, Size: 27.00, Stock: 002714
# 2019-12-18, BUY EXECUTED, ref:71331, Price: 12.20, Cost: 2305.80, Comm 0.00, Size: 189.00, Stock: 002736
# 2019-12-18, BUY EXECUTED, ref:71332, Price: 38.91, Cost: 2334.60, Comm 0.00, Size: 60.00, Stock: 002773
# 2019-12-18, BUY EXECUTED, ref:71333, Price: 8.52, Cost: 2308.92, Comm 0.00, Size: 271.00, Stock: 002797
# 2019-12-18, BUY EXECUTED, ref:71334, Price: 9.61, Cost: 2316.01, Comm 0.00, Size: 241.00, Stock: 300017
# 2019-12-18, BUY EXECUTED, ref:71335, Price: 114.00, Cost: 2280.00, Comm 0.00, Size: 20.00, Stock: 300033
# 2019-12-18, BUY EXECUTED, ref:71336, Price: 15.67, Cost: 2303.49, Comm 0.00, Size: 147.00, Stock: 300059
# 2019-12-18, BUY EXECUTED, ref:71337, Price: 49.19, Cost: 2311.93, Comm 0.00, Size: 47.00, Stock: 300122
# 2019-12-18, BUY EXECUTED, ref:71338, Price: 29.40, Cost: 2322.60, Comm 0.00, Size: 79.00, Stock: 300124
# 2019-12-18, BUY EXECUTED, ref:71339, Price: 22.25, Cost: 2336.25, Comm 0.00, Size: 105.00, Stock: 300408
# 2019-12-18, BUY EXECUTED, ref:71340, Price: 14.60, Cost: 2306.80, Comm 0.00, Size: 158.00, Stock: 300433
# 2019-12-18, BUY EXECUTED, ref:71341, Price: 1.33, Cost: 2344.79, Comm 0.00, Size: 1763.00, Stock: 600010
# 2019-12-18, BUY EXECUTED, ref:71342, Price: 23.84, Cost: 2312.48, Comm 0.00, Size: 97.00, Stock: 600030
# 2019-12-18, BUY EXECUTED, ref:71343, Price: 15.95, Cost: 2312.75, Comm 0.00, Size: 145.00, Stock: 600048
# 2019-12-18, BUY EXECUTED, ref:71344, Price: 6.31, Cost: 2322.08, Comm 0.00, Size: 368.00, Stock: 600068
# 2019-12-18, BUY EXECUTED, ref:71345, Price: 9.00, Cost: 2322.00, Comm 0.00, Size: 258.00, Stock: 600100
# 2019-12-18, BUY EXECUTED, ref:71346, Price: 9.02, Cost: 2309.12, Comm 0.00, Size: 256.00, Stock: 600109
# 2019-12-18, BUY EXECUTED, ref:71347, Price: 22.60, Cost: 2327.80, Comm 0.00, Size: 103.00, Stock: 600271
# 2019-12-18, BUY EXECUTED, ref:71348, Price: 13.26, Cost: 2320.50, Comm 0.00, Size: 175.00, Stock: 600383
# 2019-12-18, BUY EXECUTED, ref:71349, Price: 13.51, Cost: 2323.72, Comm 0.00, Size: 172.00, Stock: 600438
# 2019-12-18, BUY EXECUTED, ref:71350, Price: 15.36, Cost: 2319.36, Comm 0.00, Size: 151.00, Stock: 600535
# 2019-12-18, BUY EXECUTED, ref:71351, Price: 80.12, Cost: 2243.36, Comm 0.00, Size: 28.00, Stock: 600570
# 2019-12-18, BUY EXECUTED, ref:71352, Price: 18.64, Cost: 2311.36, Comm 0.00, Size: 124.00, Stock: 600690
# 2019-12-18, BUY EXECUTED, ref:71353, Price: 32.50, Cost: 2340.00, Comm 0.00, Size: 72.00, Stock: 600760
# 2019-12-18, BUY EXECUTED, ref:71354, Price: 15.09, Cost: 2308.77, Comm 0.00, Size: 153.00, Stock: 600837
# 2019-12-18, BUY EXECUTED, ref:71355, Price: 9.20, Cost: 2309.20, Comm 0.00, Size: 251.00, Stock: 600926
# 2019-12-18, BUY EXECUTED, ref:71356, Price: 17.78, Cost: 2311.40, Comm 0.00, Size: 130.00, Stock: 600999
# 2019-12-18, BUY EXECUTED, ref:71357, Price: 27.46, Cost: 2306.64, Comm 0.00, Size: 84.00, Stock: 601066
# 2019-12-18, BUY EXECUTED, ref:71358, Price: 10.49, Cost: 2318.29, Comm 0.00, Size: 221.00, Stock: 601108
# 2019-12-18, BUY EXECUTED, ref:71359, Price: 18.99, Cost: 2316.78, Comm 0.00, Size: 122.00, Stock: 601138
# 2019-12-18, BUY EXECUTED, ref:71360, Price: 11.79, Cost: 2322.63, Comm 0.00, Size: 197.00, Stock: 601198
# 2019-12-18, BUY EXECUTED, ref:71361, Price: 3.90, Cost: 15.60, Comm 0.00, Size: 4.00, Stock: 601228
# 2019-12-18, BUY EXECUTED, ref:71362, Price: 3.66, Cost: 10.98, Comm 0.00, Size: 3.00, Stock: 601288
# 2019-12-18, BUY EXECUTED, ref:71363, Price: 6.80, Cost: 2318.80, Comm 0.00, Size: 341.00, Stock: 601377
# 2019-12-18, BUY EXECUTED, ref:71364, Price: 9.40, Cost: 2312.40, Comm 0.00, Size: 246.00, Stock: 601555
# 2019-12-18, BUY EXECUTED, ref:71365, Price: 37.68, Cost: 2336.16, Comm 0.00, Size: 62.00, Stock: 601601
# 2019-12-18, BUY EXECUTED, ref:71366, Price: 19.59, Cost: 2311.62, Comm 0.00, Size: 118.00, Stock: 601688
# 2019-12-18, BUY EXECUTED, ref:71367, Price: 9.60, Cost: 2284.80, Comm 0.00, Size: 238.00, Stock: 601878
# 2019-12-18, BUY EXECUTED, ref:71368, Price: 11.39, Cost: 2323.56, Comm 0.00, Size: 204.00, Stock: 601881
# 2019-12-18, BUY EXECUTED, ref:71369, Price: 7.09, Cost: 2311.34, Comm 0.00, Size: 326.00, Stock: 601901
# 2019-12-18, BUY EXECUTED, ref:71370, Price: 31.80, Cost: 2289.60, Comm 0.00, Size: 72.00, Stock: 603799
# 2019-12-18, BUY EXECUTED, ref:71371, Price: 20.50, Cost: 2316.50, Comm 0.00, Size: 113.00, Stock: 603858
# 2019-12-18, BUY EXECUTED, ref:71372, Price: 3.81, Cost: 2320.29, Comm 0.00, Size: 609.00, Stock: 603993
# 2019-12-18, 当前总资产 148052.47
# 2019-12-19, 当前总资产 147538.65
# 2019-12-20, 当前总资产 147618.68
# 2019-12-23, 当前总资产 145233.85
# 2019-12-24, 当前总资产 147368.56
# 2019-12-25, 当前总资产 148024.49
# 2019-12-26, 当前总资产 150159.32
# 2019-12-27, 当前总资产 148230.69
# 2019-12-30, 当前总资产 151669.46
# 2019-12-31, 当前总资产 151931.35

# %%
strat = result[0]
print("--------------- AnnualReturn -----------------")
print(strat.analyzers._AnnualReturn.get_analysis())
print("--------------- DrawDown -----------------")
print(strat.analyzers._DrawDown.get_analysis())
print("--------------- Returns -----------------")
print(strat.analyzers._Returns.get_analysis())
print("--------------- SharpeRatio -----------------")
print(strat.analyzers._SharpeRatio.get_analysis())
print("--------------- SharpeRatio_A -----------------")
print(strat.analyzers._SharpeRatio_A.get_analysis())
# Out:
# --------------- AnnualReturn -----------------
# OrderedDict([(2019, 0.5193134999999969)])
# --------------- DrawDown -----------------
# AutoOrderedDict([('len', 0), ('drawdown', 0.0), ('moneydown', 0.0), ('max', AutoOrderedDict([('len', 178), ('drawdown', 15.254067850427479), ('moneydown', 22598.44999999991)]))])
# --------------- Returns -----------------
# OrderedDict([('rtot', 0.418258588099137), ('ravg', 0.0017141745413899057), ('rnorm', 0.5402919623997569), ('rnorm100', 54.02919623997568)])
# --------------- SharpeRatio -----------------
# OrderedDict([('sharperatio', 2.0046179518213916)])
# --------------- SharpeRatio_A -----------------
# OrderedDict([('sharperatio', None)])

# %%
# 绘制累计收益率
ret = pd.Series(strat.analyzers._TimeReturn.get_analysis())
(ret + 1).cumprod().plot(figsize=(12,6))

# %%
def get_my_analyzer(result):
    analyzer = {}

    # 提取年化收益
    analyzer['年化收益率'] = result.analyzers._Returns.get_analysis()['rnorm']
    analyzer['年化收益率（%）'] = result.analyzers._Returns.get_analysis()['rnorm100']
    # 提取最大回撤
    analyzer['最大回撤（%）'] = result.analyzers._DrawDown.get_analysis()['max']['drawdown'] * (-1)
    # 提取夏普比率
    analyzer['夏普比率'] = result.analyzers._SharpeRatio.get_analysis()['sharperatio']
    
    return analyzer

ret = []
# for i in result:
ret.append(get_my_analyzer(result[0]))
    
pd.DataFrame(ret).sort_values(by='年化收益率', ascending=False)
# Out:
#       年化收益率   年化收益率（%）    最大回撤（%）      夏普比率
# 0  0.540292  54.029196 -15.254068  2.004618
