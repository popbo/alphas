# %%
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy

# %% [markdown]
# # 一、数据准备

# %% [markdown]
# ## 1.1 读取日度行情表
#
# 表内字段就是 Backtrader 默认情况下要求输入的 7 个字段： 'datetime' 、'open'、'high'、'low'、'close'、'volume'、'openinterest'，外加一个 'sec_code' 股票代码字段。

# %%
import pandas as pd
from datas import *

year = 2019
list_assets, df_assets = get_hs300_stocks(f'{year}-01-01')
df_org= get_all_date_data(f'{year}-01-01', f'{year+1}-01-01', list_assets)
df1 = df_org.rename(columns={
        "date": "datetime", 
        "asset": "sec_code"})
df1["openinterest"] = 0
daily_price=df1[['sec_code','datetime', "open", "close", "high", "low", "volume", 'openinterest']]
daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])
daily_price
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_hs300 error_code:0
# query_hs300  error_msg:success
# logout success!
# 300
# <ipython-input-6-85d5e85e958d>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])
#       sec_code   datetime   open  close   high    low  volume  openinterest
# 0       600000 2019-01-02   9.74   9.70   9.79   9.58  237628             0
# 1       600000 2019-01-03   9.70   9.81   9.82   9.66  186543             0
# 2       600000 2019-01-04   9.73   9.96  10.00   9.70  271728             0
# 3       600000 2019-01-07  10.09   9.98  10.09   9.92  235974             0
# 4       600000 2019-01-08  10.03   9.96  10.03   9.91  151049             0
# ...        ...        ...    ...    ...    ...    ...     ...           ...
# 72881   300433 2019-12-25  14.20  14.19  14.38  14.09  353685             0
# 72882   300433 2019-12-26  14.19  14.11  14.36  13.96  383715             0
# 72883   300433 2019-12-27  14.13  13.64  14.38  13.64  523975             0
# 72884   300433 2019-12-30  13.52  13.79  13.99  13.12  484200             0
# 72885   300433 2019-12-31  13.80  13.82  13.96  13.57  317300             0
#
# [72886 rows x 8 columns]

# %%
# 以 datetime 为 index，类型为 datetime 或 date 类型，Datafeeds 默认情况下是将 index 匹配给 datetime 字段；
daily_price = daily_price.set_index(['datetime'])
daily_price
# Out:
#            sec_code   open  close   high    low  volume  openinterest
# datetime
# 2019-01-02   600000   9.74   9.70   9.79   9.58  237628             0
# 2019-01-03   600000   9.70   9.81   9.82   9.66  186543             0
# 2019-01-04   600000   9.73   9.96  10.00   9.70  271728             0
# 2019-01-07   600000  10.09   9.98  10.09   9.92  235974             0
# 2019-01-08   600000  10.03   9.96  10.03   9.91  151049             0
# ...             ...    ...    ...    ...    ...     ...           ...
# 2019-12-25   300433  14.20  14.19  14.38  14.09  353685             0
# 2019-12-26   300433  14.19  14.11  14.36  13.96  383715             0
# 2019-12-27   300433  14.13  13.64  14.38  13.64  523975             0
# 2019-12-30   300433  13.52  13.79  13.99  13.12  484200             0
# 2019-12-31   300433  13.80  13.82  13.96  13.57  317300             0
#
# [72886 rows x 7 columns]

# %% [markdown]
# ## 1.2 生成调仓信息表
#
# 表内数据说明：
#
# + trade_date： 调仓期（每月最后一个交易日）;
#
# + sec_code：持仓成分股；
#
# + weight：持仓权重。

# %%
from alphalens.utils import get_clean_factor_and_forward_returns
from alphalens.tears import create_full_tear_sheet

df_2 = df_org[['date', 'asset', "close"]]
df_2['date'] = pd.to_datetime(df_2['date'])
# print(df_all)

close = df_2.pivot(index='date', columns='asset', values='close')

alpha_num = 83
alpha_name = 'Alphas101'

# 读取已经计算好的因子
alpha = pd.read_csv('alphas/{}/{}/alpha{:03d}.csv'.format(alpha_name, year, alpha_num))

# 筛选出今年的数据，需与股票收盘日期区间一致
alpha = alpha[(alpha['date'] >= f'{year}-01-01') & (alpha['date'] <= f'{year+1}-01-01')]

# 因子矩阵转换为一维数据(alphalens需要的格式)
alpha = alpha.melt(id_vars=['date'], var_name='asset', value_name='factor' )

# date列转为日期格式
alpha['date'] = pd.to_datetime(alpha['date'])
alpha = alpha[['date', 'asset', 'factor']]

# 设置二级索引
alpha = alpha.set_index(['date', 'asset'], drop=True)
alpha.sort_index(inplace=True)


ret = get_clean_factor_and_forward_returns(alpha, close,quantiles=5)
ret = ret.reset_index()
ret = ret[ret['factor_quantile'] == 5]
ret = ret[['date','asset']]
ret['weight'] = 1/60
trade_info = ret.rename(columns={
        "date": "trade_date", 
        "asset": "sec_code"})
trade_info
# Out:
# <ipython-input-8-3029e40aae47>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['date'] = pd.to_datetime(df_2['date'])
# Dropped 5.0% entries from factor data: 5.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
#       trade_date sec_code    weight
# 2     2019-01-02   000063  0.016667
# 7     2019-01-02   000333  0.016667
# 15    2019-01-02   000503  0.016667
# 18    2019-01-02   000568  0.016667
# 22    2019-01-02   000651  0.016667
# ...          ...      ...       ...
# 69545 2019-12-17   601881  0.016667
# 69549 2019-12-17   601901  0.016667
# 69565 2019-12-17   603799  0.016667
# 69567 2019-12-17   603858  0.016667
# 69569 2019-12-17   603993  0.016667
#
# [13991 rows x 3 columns]

# %% [markdown]
# # 二、 选股回测
#
#  选股策略：定期按持仓权重调仓 。

# %%
# 回测策略
class TestStrategy(bt.Strategy):
    params = (
        ('buy_stocks', None), # 传入各个调仓日的股票列表和相应的权重
    )
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('{}, {}'.format(dt.isoformat(), txt))

    def __init__(self):
         # 读取调仓日期，即每月的最后一个交易日，回测时，会在这一天下单，然后在下一个交易日，以开盘价买入
        self.trade_dates = pd.to_datetime(self.p.buy_stocks['trade_date'].unique()).tolist()
        self.buy_stock = self.p.buy_stocks # 保留调仓信息
        self.order_list = []  # 记录以往订单，在调仓日要全部取消未成交的订单
        self.buy_stocks_pre = [] # 记录上一期持仓
    
    def next(self):
        # 获取当前的回测时间点
        dt = self.datas[0].datetime.date(0)
        # 打印当前时刻的总资产
        self.log('当前总资产 %.2f' %(self.broker.getvalue()))
        # 如果是调仓日，则进行调仓操作
        if dt in self.trade_dates:
            print("--------------{} 为调仓日----------".format(dt))
            #取消之前所下的没成交也未到期的订单
            if len(self.order_list) > 0:
                print("--------------- 撤销未完成的订单 -----------------")
                for od in self.order_list:
                    # 如果订单未完成，则撤销订单
                    self.cancel(od) 
                 #重置订单列表
                self.order_list = [] 
                
            # 提取当前调仓日的持仓列表
            buy_stocks_data = self.buy_stock.query(f"trade_date=='{dt}'")
            long_list = buy_stocks_data['sec_code'].tolist()
            print('long_list', long_list)  # 打印持仓列表
            
            # 对现有持仓中，调仓后不再继续持有的股票进行卖出平仓
            sell_stock = [i for i in self.buy_stocks_pre if i not in long_list]
            print('sell_stock', sell_stock)
            if len(sell_stock) > 0:
                print("-----------对不再持有的股票进行平仓--------------")
                for stock in sell_stock:
                    data = self.getdatabyname(stock)
                    if self.getposition(data).size > 0 :
                        od = self.close(data=data)  
                        self.order_list.append(od) # 记录卖出订单

            # 买入此次调仓的股票：多退少补原则
            print("-----------买入此次调仓期的股票--------------")
            for stock in long_list:
                w = buy_stocks_data.query(f"sec_code=='{stock}'")['weight'].iloc[0] # 提取持仓权重
                data = self.getdatabyname(stock)
                order = self.order_target_percent(data=data, target=w*0.95) # 为减少可用资金不足的情况，留 5% 的现金做备用
                self.order_list.append(order)
                
            self.buy_stocks_pre = long_list  # 保存此次调仓的股票列表
        
    #订单日志    
    def notify_order(self, order):
        # 未被处理的订单
        if order.status in [order.Submitted, order.Accepted]:
            return
        # 已被处理的订单
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                    (order.ref,
                     order.executed.price,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.size,
                     order.data._name))
            else:  # Sell
                self.log('SELL EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                        (order.ref,
                         order.executed.price,
                         order.executed.value,
                         order.executed.comm,
                         order.executed.size,
                         order.data._name))

# %%
# 实例化大脑
cerebro_ = bt.Cerebro() 

# 按股票代码，依次循环传入数据
for stock in daily_price['sec_code'].unique():
    # 日期对齐
    data = pd.DataFrame(index=daily_price.index.unique())
    df = daily_price.query(f"sec_code=='{stock}'")[['open','high','low','close','volume','openinterest']]
    data_ = pd.merge(data, df, left_index=True, right_index=True, how='left')
    data_.loc[:,['volume','openinterest']] = data_.loc[:,['volume','openinterest']].fillna(0)
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(method='pad')
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(0)
    datafeed = bt.feeds.PandasData(dataname=data_, fromdate=datetime.datetime(2019,1,2), todate=datetime.datetime(2021,1,28))
    cerebro_.adddata(datafeed, name=stock)
    print(f"{stock} Done !")
# Out:
# 600000 Done !
# 600004 Done !
# 600009 Done !
# 600010 Done !
# 600011 Done !
# 600015 Done !
# 600016 Done !
# 600018 Done !
# 600019 Done !
# 600023 Done !
# 600025 Done !
# 600027 Done !
# 600028 Done !
# 600029 Done !
# 600030 Done !
# 600031 Done !
# 600036 Done !
# 600038 Done !
# 600048 Done !
# 600050 Done !
# 600061 Done !
# 600066 Done !
# 600068 Done !
# 600085 Done !
# 600089 Done !
# 600100 Done !
# 600104 Done !
# 600109 Done !
# 600111 Done !
# 600115 Done !
# 600118 Done !
# 600153 Done !
# 600157 Done !
# 600170 Done !
# 600176 Done !
# 600177 Done !
# 600188 Done !
# 000709 Done !
# 000725 Done !
# 000728 Done !
# 000768 Done !
# 000776 Done !
# 000783 Done !
# 000786 Done !
# 000792 Done !
# 000826 Done !
# 000839 Done !
# 000858 Done !
# 000876 Done !
# 000895 Done !
# 000898 Done !
# 000938 Done !
# 000959 Done !
# 000961 Done !
# 000963 Done !
# 000983 Done !
# 001965 Done !
# 001979 Done !
# 002001 Done !
# 002007 Done !
# 002008 Done !
# 002024 Done !
# 002027 Done !
# 002032 Done !
# 002044 Done !
# 002050 Done !
# 002065 Done !
# 002081 Done !
# 002085 Done !
# 002120 Done !
# 002142 Done !
# 002146 Done !
# 002153 Done !
# 002179 Done !
# 002202 Done !
# 002230 Done !
# 002236 Done !
# 002241 Done !
# 002252 Done !
# 002271 Done !
# 002294 Done !
# 002304 Done !
# 002310 Done !
# 002311 Done !
# 002352 Done !
# 002411 Done !
# 002415 Done !
# 002422 Done !
# 002450 Done !
# 002456 Done !
# 002460 Done !
# 002466 Done !
# 002468 Done !
# 002475 Done !
# 002493 Done !
# 002508 Done !
# 002555 Done !
# 002558 Done !
# 002572 Done !
# 002594 Done !
# 002601 Done !
# 002602 Done !
# 002624 Done !
# 002625 Done !
# 002673 Done !
# 002714 Done !
# 002736 Done !
# 002773 Done !
# 002797 Done !
# 002925 Done !
# 300003 Done !
# 300015 Done !
# 300017 Done !
# 300024 Done !
# 300033 Done !
# 300059 Done !
# 300070 Done !
# 300072 Done !
# 300122 Done !
# 300124 Done !
# 300136 Done !
# 300142 Done !
# 300144 Done !
# 300251 Done !
# 300296 Done !
# 300408 Done !
# 300433 Done !

# %% [markdown]
# # 三、添加分析器

# %%
cerebro = deepcopy(cerebro_)  # 深度复制已经导入数据的 cerebro_，避免重复导入数据 
# 初始资金 100,000,000    
cerebro.broker.setcash(100000000.0) 
# 添加策略
cerebro.addstrategy(TestStrategy, buy_stocks=trade_info) # 通过修改参数 buy_stocks ，使用同一策略回测不同的持仓列表

# 添加分析指标
# 返回年初至年末的年度收益率
cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='_AnnualReturn')
# 计算最大回撤相关指标
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='_DrawDown')
# 计算年化收益
cerebro.addanalyzer(bt.analyzers.Returns, _name='_Returns', tann=252)
# 计算年化夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='_SharpeRatio', timeframe=bt.TimeFrame.Days, annualize=True, riskfreerate=0) # 计算夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio_A, _name='_SharpeRatio_A')
# 返回收益率时序
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')

# 启动回测
result = cerebro.run()
# Out:
# 2019-01-02, 当前总资产 100000000.00
# --------------2019-01-02 为调仓日----------
# long_list ['000063', '000333', '000503', '000568', '000651', '000661', '000858', '000963', '001979', '002001', '002007', '002008', '002024', '002027', '002044', '002081', '002179', '002202', '002230', '002236', '002271', '002304', '002310', '002415', '002450', '002456', '002460', '002466', '002475', '002572', '002594', '300003', '300015', '300059', '300070', '300122', '300136', '300144', '300408', '300433', '600104', '600176', '600196', '600271', '600276', '600332', '600519', '600535', '600570', '600809', '600867', '600887', '601012', '601318', '601336', '601878', '601992', '603259', '603799', '603986']
# sell_stock []
# -----------买入此次调仓期的股票--------------
# 2019-01-03, BUY EXECUTED, ref:1, Price: 19.59, Cost: 1585751.73, Comm 0.00, Size: 80947.00, Stock: 000063
# 2019-01-03, BUY EXECUTED, ref:2, Price: 36.26, Cost: 1575497.00, Comm 0.00, Size: 43450.00, Stock: 000333
# 2019-01-03, BUY EXECUTED, ref:3, Price: 15.57, Cost: 1590475.50, Comm 0.00, Size: 102150.00, Stock: 000503
# 2019-01-03, BUY EXECUTED, ref:4, Price: 39.60, Cost: 1583326.80, Comm 0.00, Size: 39983.00, Stock: 000568
# 2019-01-03, BUY EXECUTED, ref:5, Price: 35.80, Cost: 1583326.60, Comm 0.00, Size: 44227.00, Stock: 000651
# 2019-01-03, BUY EXECUTED, ref:6, Price: 170.00, Cost: 1582360.00, Comm 0.00, Size: 9308.00, Stock: 000661
# 2019-01-03, BUY EXECUTED, ref:7, Price: 50.04, Cost: 1586468.16, Comm 0.00, Size: 31704.00, Stock: 000858
# 2019-01-03, BUY EXECUTED, ref:8, Price: 23.70, Cost: 1576002.60, Comm 0.00, Size: 66498.00, Stock: 000963
# 2019-01-03, BUY EXECUTED, ref:9, Price: 16.75, Cost: 1575806.50, Comm 0.00, Size: 94078.00, Stock: 001979
# 2019-01-03, BUY EXECUTED, ref:10, Price: 14.40, Cost: 1584432.00, Comm 0.00, Size: 110030.00, Stock: 002001
# 2019-01-03, BUY EXECUTED, ref:11, Price: 29.82, Cost: 1579625.04, Comm 0.00, Size: 52972.00, Stock: 002007
# 2019-01-03, BUY EXECUTED, ref:12, Price: 29.00, Cost: 1566580.00, Comm 0.00, Size: 54020.00, Stock: 002008
# 2019-01-03, BUY EXECUTED, ref:13, Price: 10.02, Cost: 1581747.18, Comm 0.00, Size: 157859.00, Stock: 002024
# 2019-01-03, BUY EXECUTED, ref:14, Price: 4.97, Cost: 1567562.85, Comm 0.00, Size: 315405.00, Stock: 002027
# 2019-01-03, BUY EXECUTED, ref:15, Price: 13.86, Cost: 1536755.22, Comm 0.00, Size: 110877.00, Stock: 002044
# 2019-01-03, BUY EXECUTED, ref:16, Price: 7.95, Cost: 1593346.95, Comm 0.00, Size: 200421.00, Stock: 002081
# 2019-01-03, BUY EXECUTED, ref:17, Price: 34.00, Cost: 1586576.00, Comm 0.00, Size: 46664.00, Stock: 002179
# 2019-01-03, BUY EXECUTED, ref:18, Price: 9.70, Cost: 1589888.20, Comm 0.00, Size: 163906.00, Stock: 002202
# 2019-01-03, BUY EXECUTED, ref:19, Price: 24.98, Cost: 1579535.36, Comm 0.00, Size: 63232.00, Stock: 002230
# 2019-01-03, BUY EXECUTED, ref:20, Price: 11.21, Cost: 1583322.82, Comm 0.00, Size: 141242.00, Stock: 002236
# 2019-01-03, BUY EXECUTED, ref:21, Price: 13.05, Cost: 1583330.40, Comm 0.00, Size: 121328.00, Stock: 002271
# 2019-01-03, BUY EXECUTED, ref:22, Price: 91.00, Cost: 1581580.00, Comm 0.00, Size: 17380.00, Stock: 002304
# 2019-01-03, BUY EXECUTED, ref:46, Price: 34.16, Cost: 1578226.16, Comm 0.00, Size: 46201.00, Stock: 600332
# 2019-01-03, BUY EXECUTED, ref:47, Price: 599.97, Cost: 1585720.71, Comm 0.00, Size: 2643.00, Stock: 600519
# 2019-01-03, BUY EXECUTED, ref:48, Price: 17.90, Cost: 1585098.70, Comm 0.00, Size: 88553.00, Stock: 600535
# 2019-01-03, BUY EXECUTED, ref:49, Price: 50.03, Cost: 1567640.02, Comm 0.00, Size: 31334.00, Stock: 600570
# 2019-01-03, BUY EXECUTED, ref:50, Price: 34.05, Cost: 1576378.80, Comm 0.00, Size: 46296.00, Stock: 600809
# 2019-01-03, BUY EXECUTED, ref:51, Price: 13.90, Cost: 1598277.60, Comm 0.00, Size: 114984.00, Stock: 600867
# 2019-01-03, BUY EXECUTED, ref:52, Price: 22.51, Cost: 1585424.32, Comm 0.00, Size: 70432.00, Stock: 600887
# 2019-01-03, BUY EXECUTED, ref:53, Price: 17.40, Cost: 1586062.20, Comm 0.00, Size: 91153.00, Stock: 601012
# 2019-01-03, BUY EXECUTED, ref:54, Price: 55.15, Cost: 1582418.95, Comm 0.00, Size: 28693.00, Stock: 601318
# 2019-01-03, BUY EXECUTED, ref:55, Price: 41.20, Cost: 1588342.40, Comm 0.00, Size: 38552.00, Stock: 601336
# 2019-01-03, BUY EXECUTED, ref:56, Price: 7.21, Cost: 1592162.67, Comm 0.00, Size: 220827.00, Stock: 601878
# 2019-01-03, BUY EXECUTED, ref:57, Price: 3.36, Cost: 1583332.80, Comm 0.00, Size: 471230.00, Stock: 601992
# 2019-01-03, BUY EXECUTED, ref:58, Price: 72.00, Cost: 1584648.00, Comm 0.00, Size: 22009.00, Stock: 603259
# 2019-01-03, BUY EXECUTED, ref:59, Price: 29.25, Cost: 1579529.25, Comm 0.00, Size: 54001.00, Stock: 603799
# 2019-01-03, BUY EXECUTED, ref:60, Price: 59.79, Cost: 1583059.83, Comm 0.00, Size: 26477.00, Stock: 603986
# 2019-01-03, 当前总资产 98664206.25
# --------------2019-01-03 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000063', '000333', '000503', '000568', '000661', '000728', '000776', '000786', '000792', '000963', '002008', '002032', '002179', '002202', '002236', '002252', '002271', '002450', '002456', '002475', '002555', '002594', '002673', '002714', '300003', '300059', '300122', '300124', '300136', '300296', '300408', '300433', '600031', '600104', '600118', '600271', '600309', '600332', '600352', '600436', '600438', '600487', '600498', '600516', '600519', '600522', '600570', '600585', '600588', '600760', '600809', '600867', '600887', '601108', '601318', '601688', '601877', '601878', '601888', '603986']
# sell_stock ['000651', '000858', '001979', '002001', '002007', '002024', '002027', '002044', '002081', '002230', '002304', '002310', '002415', '002460', '002466', '002572', '300015', '300070', '300144', '600176', '600196', '600276', '600535', '601012', '601336', '601992', '603259', '603799']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-04, SELL EXECUTED, ref:61, Price: 35.72, Cost: 1583326.60, Comm 0.00, Size: -44227.00, Stock: 000651
# 2019-01-04, SELL EXECUTED, ref:62, Price: 48.23, Cost: 1586468.16, Comm 0.00, Size: -31704.00, Stock: 000858
# 2019-01-04, SELL EXECUTED, ref:63, Price: 16.85, Cost: 1575806.50, Comm 0.00, Size: -94078.00, Stock: 001979
# 2019-01-04, SELL EXECUTED, ref:64, Price: 13.93, Cost: 1584432.00, Comm 0.00, Size: -110030.00, Stock: 002001
# 2019-01-04, SELL EXECUTED, ref:65, Price: 30.11, Cost: 1579625.04, Comm 0.00, Size: -52972.00, Stock: 002007
# 2019-01-04, SELL EXECUTED, ref:66, Price: 10.00, Cost: 1581747.18, Comm 0.00, Size: -157859.00, Stock: 002024
# 2019-01-04, SELL EXECUTED, ref:67, Price: 5.03, Cost: 1567562.85, Comm 0.00, Size: -315405.00, Stock: 002027
# 2019-01-04, SELL EXECUTED, ref:68, Price: 13.76, Cost: 1536755.22, Comm 0.00, Size: -110877.00, Stock: 002044
# 2019-01-04, SELL EXECUTED, ref:69, Price: 7.82, Cost: 1593346.95, Comm 0.00, Size: -200421.00, Stock: 002081
# 2019-01-04, SELL EXECUTED, ref:70, Price: 25.16, Cost: 1579535.36, Comm 0.00, Size: -63232.00, Stock: 002230
# 2019-01-04, SELL EXECUTED, ref:71, Price: 88.00, Cost: 1581580.00, Comm 0.00, Size: -17380.00, Stock: 002304
# 2019-01-04, SELL EXECUTED, ref:72, Price: 6.75, Cost: 1590194.75, Comm 0.00, Size: -228805.00, Stock: 002310
# 2019-01-04, SELL EXECUTED, ref:73, Price: 25.15, Cost: 1575915.84, Comm 0.00, Size: -61728.00, Stock: 002415
# 2019-01-04, SELL EXECUTED, ref:74, Price: 21.74, Cost: 1565286.10, Comm 0.00, Size: -72133.00, Stock: 002460
# 2019-01-04, SELL EXECUTED, ref:75, Price: 28.80, Cost: 1565872.00, Comm 0.00, Size: -54560.00, Stock: 002466
# 2019-01-04, SELL EXECUTED, ref:76, Price: 15.81, Cost: 1590146.50, Comm 0.00, Size: -97555.00, Stock: 002572
# 2019-01-04, SELL EXECUTED, ref:77, Price: 24.54, Cost: 1583312.20, Comm 0.00, Size: -64310.00, Stock: 300015
# 2019-01-04, SELL EXECUTED, ref:78, Price: 7.61, Cost: 1595763.40, Comm 0.00, Size: -207242.00, Stock: 300070
# 2019-01-04, SELL EXECUTED, ref:79, Price: 18.80, Cost: 1574403.33, Comm 0.00, Size: -81113.00, Stock: 300144
# 2019-01-04, SELL EXECUTED, ref:80, Price: 9.40, Cost: 1593358.82, Comm 0.00, Size: -167194.00, Stock: 600176
# 2019-01-04, SELL EXECUTED, ref:81, Price: 20.80, Cost: 1583321.60, Comm 0.00, Size: -73472.00, Stock: 600196
# 2019-01-04, SELL EXECUTED, ref:82, Price: 50.30, Cost: 1561206.93, Comm 0.00, Size: -29891.00, Stock: 600276
# 2019-01-04, SELL EXECUTED, ref:83, Price: 17.01, Cost: 1585098.70, Comm 0.00, Size: -88553.00, Stock: 600535
# 2019-01-04, SELL EXECUTED, ref:84, Price: 17.50, Cost: 1586062.20, Comm 0.00, Size: -91153.00, Stock: 601012
# 2019-01-04, SELL EXECUTED, ref:85, Price: 41.17, Cost: 1588342.40, Comm 0.00, Size: -38552.00, Stock: 601336
# 2019-01-04, BUY EXECUTED, ref:109, Price: 9.05, Cost: 1567378.55, Comm 0.00, Size: 173191.00, Stock: 002555
# 2019-01-04, BUY EXECUTED, ref:110, Price: 47.80, Cost: 14483.40, Comm 0.00, Size: 303.00, Stock: 002594
# 2019-01-04, BUY EXECUTED, ref:111, Price: 7.73, Cost: 1544198.91, Comm 0.00, Size: 199767.00, Stock: 002673
# 2019-01-04, BUY EXECUTED, ref:112, Price: 28.45, Cost: 1553967.45, Comm 0.00, Size: 54621.00, Stock: 002714
# 2019-01-04, BUY EXECUTED, ref:113, Price: 18.40, Cost: 4508.00, Comm 0.00, Size: 245.00, Stock: 300003
# 2019-01-04, SELL EXECUTED, ref:114, Price: 11.82, Cost: 39377.55, Comm 0.00, Size: -3323.00, Stock: 300059
# 2019-01-04, SELL EXECUTED, ref:115, Price: 36.50, Cost: 22069.80, Comm 0.00, Size: -610.00, Stock: 300122
# 2019-01-04, BUY EXECUTED, ref:116, Price: 20.00, Cost: 1563740.00, Comm 0.00, Size: 78187.00, Stock: 300124
# 2019-01-04, BUY EXECUTED, ref:117, Price: 19.00, Cost: 112423.00, Comm 0.00, Size: 5917.00, Stock: 300136
# 2019-01-04, BUY EXECUTED, ref:118, Price: 6.97, Cost: 1544454.42, Comm 0.00, Size: 221586.00, Stock: 300296
# 2019-01-04, BUY EXECUTED, ref:119, Price: 14.90, Cost: 98876.40, Comm 0.00, Size: 6636.00, Stock: 300408
# 2019-01-04, SELL EXECUTED, ref:120, Price: 6.15, Cost: 1327.15, Comm 0.00, Size: -209.00, Stock: 300433
# 2019-01-04, BUY EXECUTED, ref:121, Price: 7.87, Cost: 1550358.52, Comm 0.00, Size: 196996.00, Stock: 600031
# 2019-01-04, BUY EXECUTED, ref:122, Price: 24.51, Cost: 7622.61, Comm 0.00, Size: 311.00, Stock: 600104
# 2019-01-04, BUY EXECUTED, ref:123, Price: 18.30, Cost: 1554530.10, Comm 0.00, Size: 84947.00, Stock: 600118
# 2019-01-04, SELL EXECUTED, ref:124, Price: 22.48, Cost: 1173.00, Comm 0.00, Size: -51.00, Stock: 600271
# 2019-01-04, BUY EXECUTED, ref:125, Price: 27.13, Cost: 1538352.39, Comm 0.00, Size: 56703.00, Stock: 600309
# 2019-01-04, BUY EXECUTED, ref:126, Price: 32.91, Cost: 21556.05, Comm 0.00, Size: 655.00, Stock: 600332
# 2019-01-04, BUY EXECUTED, ref:127, Price: 8.83, Cost: 1549894.58, Comm 0.00, Size: 175526.00, Stock: 600352
# 2019-01-04, BUY EXECUTED, ref:128, Price: 80.50, Cost: 1552684.00, Comm 0.00, Size: 19288.00, Stock: 600436
# 2019-01-04, BUY EXECUTED, ref:129, Price: 7.81, Cost: 1536601.88, Comm 0.00, Size: 196748.00, Stock: 600438
# 2019-01-04, BUY EXECUTED, ref:130, Price: 16.15, Cost: 1532748.05, Comm 0.00, Size: 94907.00, Stock: 600487
# 2019-01-04, BUY EXECUTED, ref:131, Price: 27.18, Cost: 1542872.70, Comm 0.00, Size: 56765.00, Stock: 600498
# 2019-01-04, BUY EXECUTED, ref:132, Price: 16.50, Cost: 1547172.00, Comm 0.00, Size: 93768.00, Stock: 600516
# 2019-01-04, BUY EXECUTED, ref:133, Price: 587.28, Cost: 2349.12, Comm 0.00, Size: 4.00, Stock: 600519
# 2019-01-04, BUY EXECUTED, ref:134, Price: 7.85, Cost: 1542532.85, Comm 0.00, Size: 196501.00, Stock: 600522
# 2019-01-04, SELL EXECUTED, ref:135, Price: 50.47, Cost: 37822.68, Comm 0.00, Size: -756.00, Stock: 600570
# 2019-01-04, BUY EXECUTED, ref:136, Price: 27.77, Cost: 1536708.49, Comm 0.00, Size: 55337.00, Stock: 600585
# 2019-01-04, BUY EXECUTED, ref:137, Price: 22.00, Cost: 1536326.00, Comm 0.00, Size: 69833.00, Stock: 600588
# 2019-01-04, BUY EXECUTED, ref:138, Price: 28.51, Cost: 1545897.73, Comm 0.00, Size: 54223.00, Stock: 600760
# 2019-01-04, BUY EXECUTED, ref:139, Price: 32.64, Cost: 30289.92, Comm 0.00, Size: 928.00, Stock: 600809
# 2019-01-04, BUY EXECUTED, ref:140, Price: 11.90, Cost: 132090.00, Comm 0.00, Size: 11100.00, Stock: 600867
# 2019-01-04, SELL EXECUTED, ref:141, Price: 22.11, Cost: 8508.78, Comm 0.00, Size: -378.00, Stock: 600887
# 2019-01-04, BUY EXECUTED, ref:142, Price: 7.22, Cost: 1538733.62, Comm 0.00, Size: 213121.00, Stock: 601108
# 2019-01-04, SELL EXECUTED, ref:143, Price: 55.28, Cost: 35075.40, Comm 0.00, Size: -636.00, Stock: 601318
# 2019-01-04, BUY EXECUTED, ref:144, Price: 16.43, Cost: 1549907.62, Comm 0.00, Size: 94334.00, Stock: 601688
# 2019-01-04, BUY EXECUTED, ref:145, Price: 22.12, Cost: 1535105.88, Comm 0.00, Size: 69399.00, Stock: 601877
# 2019-01-04, SELL EXECUTED, ref:146, Price: 7.19, Cost: 49237.09, Comm 0.00, Size: -6829.00, Stock: 601878
# 2019-01-04, BUY EXECUTED, ref:147, Price: 56.05, Cost: 1536666.80, Comm 0.00, Size: 27416.00, Stock: 601888
# 2019-01-04, SELL EXECUTED, ref:148, Price: 58.13, Cost: 5261.52, Comm 0.00, Size: -88.00, Stock: 603986
# 2019-01-04, 当前总资产 101825846.19
# --------------2019-01-04 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000166', '000408', '000425', '000553', '000627', '000630', '000709', '000839', '000959', '001965', '002120', '002241', '002352', '002468', '002493', '002558', '002602', '002624', '002925', '300024', '600068', '600157', '600170', '600177', '600219', '600221', '600233', '600297', '600362', '600415', '600489', '600518', '600547', '600674', '600688', '600760', '600886', '600900', '600919', '600926', '600998', '601018', '601117', '601212', '601216', '601228', '601238', '601333', '601360', '601600', '601633', '601727', '601888', '601898', '601919', '601985', '601989', '601991', '603156', '603833']
# sell_stock ['000063', '000333', '000503', '000568', '000661', '000728', '000776', '000786', '000792', '000963', '002008', '002032', '002179', '002202', '002236', '002252', '002271', '002450', '002456', '002475', '002555', '002594', '002673', '002714', '300003', '300059', '300122', '300124', '300136', '300296', '300408', '300433', '600031', '600104', '600118', '600271', '600309', '600332', '600352', '600436', '600438', '600487', '600498', '600516', '600519', '600522', '600570', '600585', '600588', '600809', '600867', '600887', '601108', '601318', '601688', '601877', '601878', '603986']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-07, SELL EXECUTED, ref:149, Price: 19.45, Cost: 1627140.09, Comm 0.00, Size: -83183.00, Stock: 000063
# 2019-01-07, SELL EXECUTED, ref:150, Price: 37.66, Cost: 1564800.30, Comm 0.00, Size: -43155.00, Stock: 000333
# 2019-01-07, SELL EXECUTED, ref:151, Price: 15.93, Cost: 1613064.95, Comm 0.00, Size: -103661.00, Stock: 000503
# 2019-01-07, SELL EXECUTED, ref:152, Price: 39.13, Cost: 1620607.46, Comm 0.00, Size: -40969.00, Stock: 000568
# 2019-01-07, SELL EXECUTED, ref:153, Price: 173.32, Cost: 1581680.00, Comm 0.00, Size: -9304.00, Stock: 000661
# 2019-01-07, SELL EXECUTED, ref:154, Price: 7.79, Cost: 1551328.35, Comm 0.00, Size: -216969.00, Stock: 000728
# 2019-01-07, SELL EXECUTED, ref:155, Price: 13.25, Cost: 1545703.40, Comm 0.00, Size: -126697.00, Stock: 000776
# 2019-01-07, SELL EXECUTED, ref:156, Price: 14.13, Cost: 1554109.20, Comm 0.00, Size: -115290.00, Stock: 000786
# 2019-01-07, SELL EXECUTED, ref:157, Price: 6.81, Cost: 1536606.87, Comm 0.00, Size: -232467.00, Stock: 000792
# 2019-01-07, SELL EXECUTED, ref:158, Price: 25.55, Cost: 1592722.59, Comm 0.00, Size: -67219.00, Stock: 000963
# 2019-01-07, SELL EXECUTED, ref:159, Price: 28.16, Cost: 1637921.60, Comm 0.00, Size: -56682.00, Stock: 002008
# 2019-01-07, SELL EXECUTED, ref:160, Price: 50.99, Cost: 1565428.66, Comm 0.00, Size: -32498.00, Stock: 002032
# 2019-01-07, SELL EXECUTED, ref:161, Price: 34.80, Cost: 1547170.00, Comm 0.00, Size: -45505.00, Stock: 002179
# 2019-01-07, SELL EXECUTED, ref:162, Price: 9.96, Cost: 1620717.40, Comm 0.00, Size: -167257.00, Stock: 002202
# 2019-01-07, SELL EXECUTED, ref:163, Price: 11.69, Cost: 1576249.31, Comm 0.00, Size: -140611.00, Stock: 002236
# 2019-01-07, SELL EXECUTED, ref:164, Price: 7.69, Cost: 1529768.52, Comm 0.00, Size: -216069.00, Stock: 002252
# 2019-01-07, SELL EXECUTED, ref:165, Price: 13.26, Cost: 1639332.30, Comm 0.00, Size: -125881.00, Stock: 002271
# 2019-01-07, SELL EXECUTED, ref:166, Price: 7.01, Cost: 1613813.90, Comm 0.00, Size: -224774.00, Stock: 002450
# 2019-01-07, SELL EXECUTED, ref:167, Price: 8.99, Cost: 1627796.73, Comm 0.00, Size: -179355.00, Stock: 002456
# 2019-01-07, SELL EXECUTED, ref:168, Price: 13.25, Cost: 1600116.80, Comm 0.00, Size: -116147.00, Stock: 002475
# 2019-01-07, SELL EXECUTED, ref:169, Price: 9.57, Cost: 1567378.55, Comm 0.00, Size: -173191.00, Stock: 002555
# 2019-01-07, SELL EXECUTED, ref:170, Price: 50.85, Cost: 1600704.66, Comm 0.00, Size: -32504.00, Stock: 002594
# 2019-01-07, SELL EXECUTED, ref:171, Price: 8.39, Cost: 1544198.91, Comm 0.00, Size: -199767.00, Stock: 002673
# 2019-01-07, SELL EXECUTED, ref:172, Price: 29.79, Cost: 1553967.45, Comm 0.00, Size: -54621.00, Stock: 002714
# 2019-01-07, SELL EXECUTED, ref:173, Price: 19.45, Cost: 1596135.59, Comm 0.00, Size: -83272.00, Stock: 300003
# 2019-01-07, SELL EXECUTED, ref:174, Price: 12.70, Cost: 1543948.35, Comm 0.00, Size: -130291.00, Stock: 300059
# 2019-01-07, SELL EXECUTED, ref:175, Price: 37.95, Cost: 1566087.48, Comm 0.00, Size: -43286.00, Stock: 300122
# 2019-01-07, SELL EXECUTED, ref:176, Price: 20.65, Cost: 1563740.00, Comm 0.00, Size: -78187.00, Stock: 300124
# 2019-01-07, SELL EXECUTED, ref:177, Price: 20.13, Cost: 1667411.20, Comm 0.00, Size: -78580.00, Stock: 300136
# 2019-01-07, SELL EXECUTED, ref:178, Price: 7.30, Cost: 1544454.42, Comm 0.00, Size: -221586.00, Stock: 300296
# 2019-01-07, SELL EXECUTED, ref:179, Price: 15.36, Cost: 1666545.54, Comm 0.00, Size: -104493.00, Stock: 300408
# 2019-01-07, SELL EXECUTED, ref:180, Price: 6.46, Cost: 1572088.55, Comm 0.00, Size: -247573.00, Stock: 300433
# 2019-01-07, SELL EXECUTED, ref:181, Price: 8.12, Cost: 1550358.52, Comm 0.00, Size: -196996.00, Stock: 600031
# 2019-01-07, SELL EXECUTED, ref:182, Price: 24.80, Cost: 1591580.36, Comm 0.00, Size: -63042.00, Stock: 600104
# 2019-01-07, SELL EXECUTED, ref:183, Price: 18.59, Cost: 1554530.10, Comm 0.00, Size: -84947.00, Stock: 600118
# 2019-01-07, SELL EXECUTED, ref:184, Price: 24.95, Cost: 1581457.00, Comm 0.00, Size: -68759.00, Stock: 600271
# 2019-01-07, SELL EXECUTED, ref:185, Price: 28.79, Cost: 1538352.39, Comm 0.00, Size: -56703.00, Stock: 600309
# 2019-01-07, SELL EXECUTED, ref:186, Price: 34.30, Cost: 1599782.21, Comm 0.00, Size: -46856.00, Stock: 600332
# 2019-01-07, SELL EXECUTED, ref:187, Price: 9.09, Cost: 1549894.58, Comm 0.00, Size: -175526.00, Stock: 600352
# 2019-01-07, SELL EXECUTED, ref:188, Price: 83.85, Cost: 1552684.00, Comm 0.00, Size: -19288.00, Stock: 600436
# 2019-01-07, SELL EXECUTED, ref:189, Price: 8.18, Cost: 1536601.88, Comm 0.00, Size: -196748.00, Stock: 600438
# 2019-01-07, SELL EXECUTED, ref:190, Price: 17.00, Cost: 1532748.05, Comm 0.00, Size: -94907.00, Stock: 600487
# 2019-01-07, SELL EXECUTED, ref:191, Price: 27.96, Cost: 1542872.70, Comm 0.00, Size: -56765.00, Stock: 600498
# 2019-01-07, SELL EXECUTED, ref:192, Price: 17.19, Cost: 1547172.00, Comm 0.00, Size: -93768.00, Stock: 600516
# 2019-01-07, SELL EXECUTED, ref:193, Price: 608.00, Cost: 1588069.83, Comm 0.00, Size: -2647.00, Stock: 600519
# 2019-01-07, SELL EXECUTED, ref:194, Price: 8.24, Cost: 1542532.85, Comm 0.00, Size: -196501.00, Stock: 600522
# 2019-01-07, SELL EXECUTED, ref:195, Price: 53.80, Cost: 1529817.34, Comm 0.00, Size: -30578.00, Stock: 600570
# 2019-01-07, SELL EXECUTED, ref:196, Price: 28.70, Cost: 1536708.49, Comm 0.00, Size: -55337.00, Stock: 600585
# 2019-01-07, SELL EXECUTED, ref:197, Price: 23.65, Cost: 1536326.00, Comm 0.00, Size: -69833.00, Stock: 600588
# 2019-01-07, SELL EXECUTED, ref:198, Price: 34.11, Cost: 1606668.72, Comm 0.00, Size: -47224.00, Stock: 600809
# 2019-01-07, SELL EXECUTED, ref:199, Price: 12.55, Cost: 1730367.60, Comm 0.00, Size: -126084.00, Stock: 600867
# 2019-01-07, SELL EXECUTED, ref:200, Price: 22.74, Cost: 1576915.54, Comm 0.00, Size: -70054.00, Stock: 600887
# 2019-01-07, SELL EXECUTED, ref:201, Price: 7.99, Cost: 1538733.62, Comm 0.00, Size: -213121.00, Stock: 601108
# 2019-01-07, SELL EXECUTED, ref:202, Price: 57.09, Cost: 1547343.55, Comm 0.00, Size: -28057.00, Stock: 601318
# 2019-01-07, SELL EXECUTED, ref:203, Price: 17.77, Cost: 1549907.62, Comm 0.00, Size: -94334.00, Stock: 601688
# 2019-01-07, SELL EXECUTED, ref:204, Price: 22.46, Cost: 1535105.88, Comm 0.00, Size: -69399.00, Stock: 601877
# 2019-01-07, SELL EXECUTED, ref:205, Price: 8.02, Cost: 1542925.58, Comm 0.00, Size: -213998.00, Stock: 601878
# 2019-01-07, SELL EXECUTED, ref:206, Price: 61.20, Cost: 1577798.31, Comm 0.00, Size: -26389.00, Stock: 603986
# 2019-01-07, BUY EXECUTED, ref:207, Price: 4.40, Cost: 1604944.00, Comm 0.00, Size: 364760.00, Stock: 000166
# 2019-01-07, BUY EXECUTED, ref:208, Price: 11.21, Cost: 1615114.38, Comm 0.00, Size: 144078.00, Stock: 000408
# 2019-01-07, BUY EXECUTED, ref:209, Price: 3.27, Cost: 1622161.98, Comm 0.00, Size: 496074.00, Stock: 000425
# 2019-01-07, BUY EXECUTED, ref:210, Price: 9.57, Cost: 1657265.61, Comm 0.00, Size: 173173.00, Stock: 000553
# 2019-01-07, BUY EXECUTED, ref:211, Price: 5.75, Cost: 1629239.50, Comm 0.00, Size: 283346.00, Stock: 000627
# 2019-01-07, BUY EXECUTED, ref:212, Price: 2.01, Cost: 1620303.21, Comm 0.00, Size: 806121.00, Stock: 000630
# 2019-01-07, BUY EXECUTED, ref:213, Price: 2.91, Cost: 1617799.95, Comm 0.00, Size: 555945.00, Stock: 000709
# 2019-01-07, BUY EXECUTED, ref:214, Price: 3.58, Cost: 1621299.66, Comm 0.00, Size: 452877.00, Stock: 000839
# 2019-01-07, BUY EXECUTED, ref:215, Price: 3.86, Cost: 1616429.04, Comm 0.00, Size: 418764.00, Stock: 000959
# 2019-01-07, BUY EXECUTED, ref:216, Price: 8.10, Cost: 1616225.40, Comm 0.00, Size: 199534.00, Stock: 001965
# 2019-01-07, BUY EXECUTED, ref:217, Price: 30.06, Cost: 1613290.14, Comm 0.00, Size: 53669.00, Stock: 002120
# 2019-01-07, BUY EXECUTED, ref:218, Price: 6.95, Cost: 1626279.15, Comm 0.00, Size: 233997.00, Stock: 002241
# 2019-01-07, BUY EXECUTED, ref:219, Price: 32.88, Cost: 1608785.52, Comm 0.00, Size: 48929.00, Stock: 002352
# 2019-01-07, BUY EXECUTED, ref:220, Price: 16.41, Cost: 1617156.27, Comm 0.00, Size: 98547.00, Stock: 002468
# 2019-01-07, BUY EXECUTED, ref:221, Price: 10.32, Cost: 1626421.68, Comm 0.00, Size: 157599.00, Stock: 002493
# 2019-01-07, BUY EXECUTED, ref:222, Price: 19.55, Cost: 1604839.95, Comm 0.00, Size: 82089.00, Stock: 002558
# 2019-01-07, BUY EXECUTED, ref:223, Price: 20.18, Cost: 1605863.86, Comm 0.00, Size: 79577.00, Stock: 002602
# 2019-01-07, BUY EXECUTED, ref:224, Price: 26.28, Cost: 1592226.36, Comm 0.00, Size: 60587.00, Stock: 002624
# 2019-01-07, BUY EXECUTED, ref:225, Price: 42.77, Cost: 1637877.15, Comm 0.00, Size: 38295.00, Stock: 002925
# 2019-01-07, BUY EXECUTED, ref:226, Price: 13.80, Cost: 1615745.40, Comm 0.00, Size: 117083.00, Stock: 300024
# 2019-01-07, BUY EXECUTED, ref:227, Price: 6.40, Cost: 1617292.80, Comm 0.00, Size: 252702.00, Stock: 600068
# 2019-01-07, BUY EXECUTED, ref:228, Price: 1.33, Cost: 1624455.35, Comm 0.00, Size: 1221395.00, Stock: 600157
# 2019-01-07, BUY EXECUTED, ref:229, Price: 3.14, Cost: 1622576.16, Comm 0.00, Size: 516744.00, Stock: 600170
# 2019-01-07, BUY EXECUTED, ref:230, Price: 7.34, Cost: 1623299.72, Comm 0.00, Size: 221158.00, Stock: 600177
# 2019-01-07, BUY EXECUTED, ref:231, Price: 2.16, Cost: 1619740.80, Comm 0.00, Size: 749880.00, Stock: 600219
# 2019-01-07, BUY EXECUTED, ref:232, Price: 1.91, Cost: 1612242.46, Comm 0.00, Size: 844106.00, Stock: 600221
# 2019-01-07, BUY EXECUTED, ref:233, Price: 10.06, Cost: 1621913.44, Comm 0.00, Size: 161224.00, Stock: 600233
# 2019-01-07, BUY EXECUTED, ref:234, Price: 4.18, Cost: 1619992.44, Comm 0.00, Size: 387558.00, Stock: 600297
# 2019-01-07, BUY EXECUTED, ref:235, Price: 13.28, Cost: 1624462.72, Comm 0.00, Size: 122324.00, Stock: 600362
# 2019-01-07, BUY EXECUTED, ref:236, Price: 3.68, Cost: 1638961.60, Comm 0.00, Size: 445370.00, Stock: 600415
# 2019-01-07, BUY EXECUTED, ref:237, Price: 8.50, Cost: 1575177.50, Comm 0.00, Size: 185315.00, Stock: 600489
# 2019-01-07, BUY EXECUTED, ref:238, Price: 7.07, Cost: 1591973.11, Comm 0.00, Size: 225173.00, Stock: 600518
# 2019-01-07, BUY EXECUTED, ref:262, Price: 5.34, Cost: 1615264.56, Comm 0.00, Size: 302484.00, Stock: 601985
# 2019-01-07, BUY EXECUTED, ref:263, Price: 4.52, Cost: 1615814.12, Comm 0.00, Size: 357481.00, Stock: 601989
# 2019-01-07, BUY EXECUTED, ref:264, Price: 3.20, Cost: 1622380.80, Comm 0.00, Size: 506994.00, Stock: 601991
# 2019-01-07, BUY EXECUTED, ref:265, Price: 42.26, Cost: 1617586.02, Comm 0.00, Size: 38277.00, Stock: 603156
# 2019-01-07, BUY EXECUTED, ref:266, Price: 77.68, Cost: 1612636.80, Comm 0.00, Size: 20760.00, Stock: 603833
# 2019-01-07, 当前总资产 103385473.48
# --------------2019-01-07 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000002', '000166', '000333', '000783', '000858', '000963', '001979', '002027', '002032', '002146', '002252', '002271', '002304', '002468', '002555', '002572', '002673', '002736', '002797', '300003', '300033', '300296', '600027', '600048', '600061', '600104', '600109', '600170', '600271', '600340', '600369', '600383', '600519', '600690', '600739', '600809', '600837', '600900', '600909', '600958', '600999', '601066', '601108', '601155', '601186', '601198', '601211', '601229', '601318', '601328', '601390', '601601', '601628', '601668', '601688', '601766', '601788', '601800', '601818', '601881']
# sell_stock ['000408', '000425', '000553', '000627', '000630', '000709', '000839', '000959', '001965', '002120', '002241', '002352', '002493', '002558', '002602', '002624', '002925', '300024', '600068', '600157', '600177', '600219', '600221', '600233', '600297', '600362', '600415', '600489', '600518', '600547', '600674', '600688', '600760', '600886', '600919', '600926', '600998', '601018', '601117', '601212', '601216', '601228', '601238', '601333', '601360', '601600', '601633', '601727', '601888', '601898', '601919', '601985', '601989', '601991', '603156', '603833']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-08, SELL EXECUTED, ref:267, Price: 11.23, Cost: 1615114.38, Comm 0.00, Size: -144078.00, Stock: 000408
# 2019-01-08, SELL EXECUTED, ref:268, Price: 3.27, Cost: 1622161.98, Comm 0.00, Size: -496074.00, Stock: 000425
# 2019-01-08, SELL EXECUTED, ref:269, Price: 9.28, Cost: 1657265.61, Comm 0.00, Size: -173173.00, Stock: 000553
# 2019-01-08, SELL EXECUTED, ref:270, Price: 5.68, Cost: 1629239.50, Comm 0.00, Size: -283346.00, Stock: 000627
# 2019-01-08, SELL EXECUTED, ref:271, Price: 2.02, Cost: 1620303.21, Comm 0.00, Size: -806121.00, Stock: 000630
# 2019-01-08, SELL EXECUTED, ref:272, Price: 2.93, Cost: 1617799.95, Comm 0.00, Size: -555945.00, Stock: 000709
# 2019-01-08, SELL EXECUTED, ref:273, Price: 3.68, Cost: 1621299.66, Comm 0.00, Size: -452877.00, Stock: 000839
# 2019-01-08, SELL EXECUTED, ref:274, Price: 3.88, Cost: 1616429.04, Comm 0.00, Size: -418764.00, Stock: 000959
# 2019-01-08, SELL EXECUTED, ref:275, Price: 8.16, Cost: 1616225.40, Comm 0.00, Size: -199534.00, Stock: 001965
# 2019-01-08, SELL EXECUTED, ref:276, Price: 29.85, Cost: 1613290.14, Comm 0.00, Size: -53669.00, Stock: 002120
# 2019-01-08, SELL EXECUTED, ref:277, Price: 7.03, Cost: 1626279.15, Comm 0.00, Size: -233997.00, Stock: 002241
# 2019-01-08, SELL EXECUTED, ref:278, Price: 32.80, Cost: 1608785.52, Comm 0.00, Size: -48929.00, Stock: 002352
# 2019-01-08, SELL EXECUTED, ref:279, Price: 10.24, Cost: 1626421.68, Comm 0.00, Size: -157599.00, Stock: 002493
# 2019-01-08, SELL EXECUTED, ref:280, Price: 19.87, Cost: 1604839.95, Comm 0.00, Size: -82089.00, Stock: 002558
# 2019-01-08, SELL EXECUTED, ref:281, Price: 20.10, Cost: 1605863.86, Comm 0.00, Size: -79577.00, Stock: 002602
# 2019-01-08, SELL EXECUTED, ref:282, Price: 26.49, Cost: 1592226.36, Comm 0.00, Size: -60587.00, Stock: 002624
# 2019-01-08, SELL EXECUTED, ref:283, Price: 44.59, Cost: 1637877.15, Comm 0.00, Size: -38295.00, Stock: 002925
# 2019-01-08, SELL EXECUTED, ref:284, Price: 13.85, Cost: 1615745.40, Comm 0.00, Size: -117083.00, Stock: 300024
# 2019-01-08, SELL EXECUTED, ref:285, Price: 6.46, Cost: 1617292.80, Comm 0.00, Size: -252702.00, Stock: 600068
# 2019-01-08, SELL EXECUTED, ref:286, Price: 1.49, Cost: 1624455.35, Comm 0.00, Size: -1221395.00, Stock: 600157
# 2019-01-08, SELL EXECUTED, ref:287, Price: 7.29, Cost: 1623299.72, Comm 0.00, Size: -221158.00, Stock: 600177
# 2019-01-08, SELL EXECUTED, ref:288, Price: 2.18, Cost: 1619740.80, Comm 0.00, Size: -749880.00, Stock: 600219
# 2019-01-08, SELL EXECUTED, ref:289, Price: 1.91, Cost: 1612242.46, Comm 0.00, Size: -844106.00, Stock: 600221
# 2019-01-08, SELL EXECUTED, ref:290, Price: 10.06, Cost: 1621913.44, Comm 0.00, Size: -161224.00, Stock: 600233
# 2019-01-08, SELL EXECUTED, ref:291, Price: 4.17, Cost: 1619992.44, Comm 0.00, Size: -387558.00, Stock: 600297
# 2019-01-08, SELL EXECUTED, ref:292, Price: 13.50, Cost: 1624462.72, Comm 0.00, Size: -122324.00, Stock: 600362
# 2019-01-08, SELL EXECUTED, ref:293, Price: 3.85, Cost: 1638961.60, Comm 0.00, Size: -445370.00, Stock: 600415
# 2019-01-08, SELL EXECUTED, ref:294, Price: 8.52, Cost: 1575177.50, Comm 0.00, Size: -185315.00, Stock: 600489
# 2019-01-08, SELL EXECUTED, ref:295, Price: 7.20, Cost: 1591973.11, Comm 0.00, Size: -225173.00, Stock: 600518
# 2019-01-08, SELL EXECUTED, ref:296, Price: 30.62, Cost: 1578976.00, Comm 0.00, Size: -51940.00, Stock: 600547
# 2019-01-08, SELL EXECUTED, ref:297, Price: 8.39, Cost: 1614163.98, Comm 0.00, Size: -192621.00, Stock: 600674
# 2019-01-08, SELL EXECUTED, ref:298, Price: 5.18, Cost: 1621669.32, Comm 0.00, Size: -314277.00, Stock: 600688
# 2019-01-08, SELL EXECUTED, ref:299, Price: 30.49, Cost: 1573590.83, Comm 0.00, Size: -55157.00, Stock: 600760
# 2019-01-08, SELL EXECUTED, ref:300, Price: 7.84, Cost: 1616370.54, Comm 0.00, Size: -206697.00, Stock: 600886
# 2019-01-08, SELL EXECUTED, ref:301, Price: 6.06, Cost: 1614889.60, Comm 0.00, Size: -264736.00, Stock: 600919
# 2019-01-08, SELL EXECUTED, ref:302, Price: 7.51, Cost: 1616495.43, Comm 0.00, Size: -212977.00, Stock: 600926
# 2019-01-08, SELL EXECUTED, ref:303, Price: 14.70, Cost: 1612235.12, Comm 0.00, Size: -110276.00, Stock: 600998
# 2019-01-08, SELL EXECUTED, ref:304, Price: 3.44, Cost: 1621722.96, Comm 0.00, Size: -474188.00, Stock: 601018
# 2019-01-08, SELL EXECUTED, ref:305, Price: 5.47, Cost: 1621098.18, Comm 0.00, Size: -295282.00, Stock: 601117
# 2019-01-08, SELL EXECUTED, ref:306, Price: 3.15, Cost: 1591438.68, Comm 0.00, Size: -520078.00, Stock: 601212
# 2019-01-08, SELL EXECUTED, ref:307, Price: 2.69, Cost: 1630357.20, Comm 0.00, Size: -603836.00, Stock: 601216
# 2019-01-08, SELL EXECUTED, ref:308, Price: 4.05, Cost: 1612241.80, Comm 0.00, Size: -400060.00, Stock: 601228
# 2019-01-08, SELL EXECUTED, ref:309, Price: 10.42, Cost: 1613795.58, Comm 0.00, Size: -155322.00, Stock: 601238
# 2019-01-08, SELL EXECUTED, ref:310, Price: 3.37, Cost: 1617171.20, Comm 0.00, Size: -493040.00, Stock: 601333
# 2019-01-08, SELL EXECUTED, ref:311, Price: 20.79, Cost: 1634347.80, Comm 0.00, Size: -78954.00, Stock: 601360
# 2019-01-08, SELL EXECUTED, ref:312, Price: 3.61, Cost: 1621272.72, Comm 0.00, Size: -451608.00, Stock: 601600
# 2019-01-08, SELL EXECUTED, ref:313, Price: 5.73, Cost: 1620799.36, Comm 0.00, Size: -285352.00, Stock: 601633
# 2019-01-08, SELL EXECUTED, ref:314, Price: 5.15, Cost: 1612237.50, Comm 0.00, Size: -316125.00, Stock: 601727
# 2019-01-08, SELL EXECUTED, ref:315, Price: 57.82, Cost: 1583661.02, Comm 0.00, Size: -28235.00, Stock: 601888
# 2019-01-08, SELL EXECUTED, ref:316, Price: 4.79, Cost: 1615641.25, Comm 0.00, Size: -340135.00, Stock: 601898
# 2019-01-08, SELL EXECUTED, ref:317, Price: 4.35, Cost: 1612242.06, Comm 0.00, Size: -375814.00, Stock: 601919
# 2019-01-08, SELL EXECUTED, ref:318, Price: 5.42, Cost: 1615264.56, Comm 0.00, Size: -302484.00, Stock: 601985
# 2019-01-08, SELL EXECUTED, ref:319, Price: 4.60, Cost: 1615814.12, Comm 0.00, Size: -357481.00, Stock: 601989
# 2019-01-08, SELL EXECUTED, ref:320, Price: 3.20, Cost: 1622380.80, Comm 0.00, Size: -506994.00, Stock: 601991
# 2019-01-08, SELL EXECUTED, ref:321, Price: 42.40, Cost: 1617586.02, Comm 0.00, Size: -38277.00, Stock: 603156
# 2019-01-08, SELL EXECUTED, ref:322, Price: 80.50, Cost: 1612636.80, Comm 0.00, Size: -20760.00, Stock: 603833
# 2019-01-08, BUY EXECUTED, ref:323, Price: 25.05, Cost: 1636917.30, Comm 0.00, Size: 65346.00, Stock: 000002
# 2019-01-08, BUY EXECUTED, ref:324, Price: 4.37, Cost: 39194.53, Comm 0.00, Size: 8969.00, Stock: 000166
# 2019-01-08, BUY EXECUTED, ref:325, Price: 37.05, Cost: 1639573.65, Comm 0.00, Size: 44253.00, Stock: 000333
# 2019-01-08, BUY EXECUTED, ref:326, Price: 5.70, Cost: 1639810.20, Comm 0.00, Size: 287686.00, Stock: 000783
# 2019-01-08, BUY EXECUTED, ref:327, Price: 49.48, Cost: 1642538.08, Comm 0.00, Size: 33196.00, Stock: 000858
# 2019-01-08, BUY EXECUTED, ref:328, Price: 25.45, Cost: 1647938.40, Comm 0.00, Size: 64752.00, Stock: 000963
# 2019-01-08, BUY EXECUTED, ref:329, Price: 17.72, Cost: 1646223.44, Comm 0.00, Size: 92902.00, Stock: 001979
# 2019-01-08, BUY EXECUTED, ref:330, Price: 5.31, Cost: 1640020.05, Comm 0.00, Size: 308855.00, Stock: 002027
# 2019-01-08, BUY EXECUTED, ref:331, Price: 50.75, Cost: 1627298.75, Comm 0.00, Size: 32065.00, Stock: 002032
# 2019-01-08, BUY EXECUTED, ref:332, Price: 8.01, Cost: 1645149.87, Comm 0.00, Size: 205387.00, Stock: 002146
# 2019-01-08, BUY EXECUTED, ref:333, Price: 7.75, Cost: 1630623.25, Comm 0.00, Size: 210403.00, Stock: 002252
# 2019-01-08, BUY EXECUTED, ref:334, Price: 13.39, Cost: 1635709.01, Comm 0.00, Size: 122159.00, Stock: 002271
# 2019-01-08, BUY EXECUTED, ref:335, Price: 89.50, Cost: 1638924.00, Comm 0.00, Size: 18312.00, Stock: 002304
# 2019-01-08, BUY EXECUTED, ref:336, Price: 16.50, Cost: 14883.00, Comm 0.00, Size: 902.00, Stock: 002468
# 2019-01-08, BUY EXECUTED, ref:337, Price: 9.75, Cost: 1636927.50, Comm 0.00, Size: 167890.00, Stock: 002555
# 2019-01-08, BUY EXECUTED, ref:338, Price: 16.69, Cost: 1644816.19, Comm 0.00, Size: 98551.00, Stock: 002572
# 2019-01-08, BUY EXECUTED, ref:339, Price: 8.34, Cost: 1634973.60, Comm 0.00, Size: 196040.00, Stock: 002673
# 2019-01-08, BUY EXECUTED, ref:340, Price: 8.99, Cost: 1626075.24, Comm 0.00, Size: 180876.00, Stock: 002736
# 2019-01-08, BUY EXECUTED, ref:341, Price: 6.18, Cost: 1613437.32, Comm 0.00, Size: 261074.00, Stock: 002797
# 2019-01-08, BUY EXECUTED, ref:342, Price: 19.15, Cost: 1632671.55, Comm 0.00, Size: 85257.00, Stock: 300003
# 2019-01-08, BUY EXECUTED, ref:343, Price: 41.92, Cost: 1627208.64, Comm 0.00, Size: 38817.00, Stock: 300033
# 2019-01-08, BUY EXECUTED, ref:344, Price: 7.26, Cost: 1630196.70, Comm 0.00, Size: 224545.00, Stock: 300296
# 2019-01-08, BUY EXECUTED, ref:345, Price: 4.55, Cost: 1633345.35, Comm 0.00, Size: 358977.00, Stock: 600027
# 2019-01-08, BUY EXECUTED, ref:346, Price: 12.18, Cost: 1639622.88, Comm 0.00, Size: 134616.00, Stock: 600048
# 2019-01-08, BUY EXECUTED, ref:347, Price: 9.88, Cost: 1630328.44, Comm 0.00, Size: 165013.00, Stock: 600061
# 2019-01-08, BUY EXECUTED, ref:348, Price: 24.59, Cost: 1636267.78, Comm 0.00, Size: 66542.00, Stock: 600104
# 2019-01-08, BUY EXECUTED, ref:349, Price: 7.80, Cost: 1628577.60, Comm 0.00, Size: 208792.00, Stock: 600109
# 2019-01-08, BUY EXECUTED, ref:350, Price: 3.13, Cost: 9133.34, Comm 0.00, Size: 2918.00, Stock: 600170
# 2019-01-08, BUY EXECUTED, ref:351, Price: 24.73, Cost: 1627060.89, Comm 0.00, Size: 65793.00, Stock: 600271
# 2019-01-08, BUY EXECUTED, ref:352, Price: 26.30, Cost: 1630731.50, Comm 0.00, Size: 62005.00, Stock: 600340
# 2019-01-08, BUY EXECUTED, ref:353, Price: 4.05, Cost: 1624896.45, Comm 0.00, Size: 401209.00, Stock: 600369
# 2019-01-08, BUY EXECUTED, ref:354, Price: 9.87, Cost: 1635271.47, Comm 0.00, Size: 165681.00, Stock: 600383
# 2019-01-08, BUY EXECUTED, ref:355, Price: 605.50, Cost: 1636666.50, Comm 0.00, Size: 2703.00, Stock: 600519
# 2019-01-08, BUY EXECUTED, ref:356, Price: 13.41, Cost: 1635711.57, Comm 0.00, Size: 121977.00, Stock: 600690
# 2019-01-08, BUY EXECUTED, ref:357, Price: 10.73, Cost: 1635402.22, Comm 0.00, Size: 152414.00, Stock: 600739
# 2019-01-08, BUY EXECUTED, ref:358, Price: 33.60, Cost: 1624358.40, Comm 0.00, Size: 48344.00, Stock: 600809
# 2019-01-08, BUY EXECUTED, ref:359, Price: 9.57, Cost: 1631818.98, Comm 0.00, Size: 170514.00, Stock: 600837
# 2019-01-08, BUY EXECUTED, ref:360, Price: 15.20, Cost: 33029.60, Comm 0.00, Size: 2173.00, Stock: 600900
# 2019-01-08, BUY EXECUTED, ref:361, Price: 5.16, Cost: 1630611.60, Comm 0.00, Size: 316010.00, Stock: 600909
# 2019-01-08, BUY EXECUTED, ref:362, Price: 8.62, Cost: 1627490.48, Comm 0.00, Size: 188804.00, Stock: 600958
# 2019-01-08, BUY EXECUTED, ref:363, Price: 14.09, Cost: 1629987.56, Comm 0.00, Size: 115684.00, Stock: 600999
# 2019-01-08, BUY EXECUTED, ref:364, Price: 10.22, Cost: 1638531.72, Comm 0.00, Size: 160326.00, Stock: 601066
# 2019-01-08, BUY EXECUTED, ref:365, Price: 7.88, Cost: 1626613.24, Comm 0.00, Size: 206423.00, Stock: 601108
# 2019-01-08, BUY EXECUTED, ref:366, Price: 25.16, Cost: 1634972.28, Comm 0.00, Size: 64983.00, Stock: 601155
# 2019-01-08, BUY EXECUTED, ref:367, Price: 11.15, Cost: 1633999.05, Comm 0.00, Size: 146547.00, Stock: 601186
# 2019-01-08, BUY EXECUTED, ref:368, Price: 10.26, Cost: 1624270.86, Comm 0.00, Size: 158311.00, Stock: 601198
# 2019-01-08, BUY EXECUTED, ref:369, Price: 16.72, Cost: 1629129.92, Comm 0.00, Size: 97436.00, Stock: 601211
# 2019-01-08, BUY EXECUTED, ref:370, Price: 11.24, Cost: 1636926.16, Comm 0.00, Size: 145634.00, Stock: 601229
# 2019-01-08, BUY EXECUTED, ref:371, Price: 56.05, Cost: 1629653.75, Comm 0.00, Size: 29075.00, Stock: 601318
# 2019-01-08, BUY EXECUTED, ref:372, Price: 5.84, Cost: 1639743.52, Comm 0.00, Size: 280778.00, Stock: 601328
# 2019-01-08, BUY EXECUTED, ref:373, Price: 7.04, Cost: 1636933.76, Comm 0.00, Size: 232519.00, Stock: 601390
# 2019-01-08, BUY EXECUTED, ref:374, Price: 28.44, Cost: 1641528.36, Comm 0.00, Size: 57719.00, Stock: 601601
# 2019-01-08, BUY EXECUTED, ref:375, Price: 20.24, Cost: 1637739.84, Comm 0.00, Size: 80916.00, Stock: 601628
# 2019-01-08, BUY EXECUTED, ref:376, Price: 5.72, Cost: 1631229.60, Comm 0.00, Size: 285180.00, Stock: 601668
# 2019-01-08, BUY EXECUTED, ref:377, Price: 17.70, Cost: 1638772.20, Comm 0.00, Size: 92586.00, Stock: 601688
# 2019-01-08, BUY EXECUTED, ref:378, Price: 9.19, Cost: 1629837.31, Comm 0.00, Size: 177349.00, Stock: 601766
# 2019-01-08, BUY EXECUTED, ref:379, Price: 9.68, Cost: 1635242.40, Comm 0.00, Size: 168930.00, Stock: 601788
# 2019-01-08, BUY EXECUTED, ref:380, Price: 11.35, Cost: 1631187.95, Comm 0.00, Size: 143717.00, Stock: 601800
# 2019-01-08, BUY EXECUTED, ref:381, Price: 3.85, Cost: 1641197.25, Comm 0.00, Size: 426285.00, Stock: 601818
# 2019-01-08, BUY EXECUTED, ref:382, Price: 7.51, Cost: 1628258.12, Comm 0.00, Size: 216812.00, Stock: 601881
# 2019-01-08, 当前总资产 103379892.76
# --------------2019-01-08 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000001', '000063', '000625', '000776', '000839', '000858', '000963', '002008', '002065', '002153', '002230', '002236', '002252', '002271', '002415', '002450', '002466', '002624', '002673', '002736', '300003', '300015', '300033', '300059', '300072', '300122', '300136', '300296', '600036', '600089', '600111', '600118', '600176', '600188', '600340', '600406', '600436', '600487', '600489', '600498', '600518', '600519', '600522', '600547', '600549', '600570', '600588', '600690', '600739', '600837', '600999', '601198', '601211', '601336', '601377', '601601', '601989', '603799', '603986', '603993']
# sell_stock ['000002', '000166', '000333', '000783', '001979', '002027', '002032', '002146', '002304', '002468', '002555', '002572', '002797', '600027', '600048', '600061', '600104', '600109', '600170', '600271', '600369', '600383', '600809', '600900', '600909', '600958', '601066', '601108', '601155', '601186', '601229', '601318', '601328', '601390', '601628', '601668', '601688', '601766', '601788', '601800', '601818', '601881']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-01-09, SELL EXECUTED, ref:383, Price: 25.40, Cost: 1636917.30, Comm 0.00, Size: -65346.00, Stock: 000002
# 2019-01-09, SELL EXECUTED, ref:384, Price: 4.39, Cost: 1644138.53, Comm 0.00, Size: -373729.00, Stock: 000166
# 2019-01-09, SELL EXECUTED, ref:385, Price: 38.25, Cost: 1639573.65, Comm 0.00, Size: -44253.00, Stock: 000333
# 2019-01-09, SELL EXECUTED, ref:386, Price: 5.71, Cost: 1639810.20, Comm 0.00, Size: -287686.00, Stock: 000783
# 2019-01-09, SELL EXECUTED, ref:387, Price: 17.90, Cost: 1646223.44, Comm 0.00, Size: -92902.00, Stock: 001979
# 2019-01-09, SELL EXECUTED, ref:388, Price: 5.51, Cost: 1640020.05, Comm 0.00, Size: -308855.00, Stock: 002027
# 2019-01-09, SELL EXECUTED, ref:389, Price: 51.10, Cost: 1627298.75, Comm 0.00, Size: -32065.00, Stock: 002032
# ...
# 2019-12-17, BUY EXECUTED, ref:24214, Price: 10.99, Cost: 2311966.30, Comm 0.00, Size: 210370.00, Stock: 601828
# 2019-12-17, BUY EXECUTED, ref:24215, Price: 8.66, Cost: 2304538.58, Comm 0.00, Size: 266113.00, Stock: 601838
# 2019-12-17, SELL EXECUTED, ref:24216, Price: 5.77, Cost: 2112.70, Comm 0.00, Size: -370.00, Stock: 601857
# 2019-12-17, BUY EXECUTED, ref:24217, Price: 26.41, Cost: 22184.40, Comm 0.00, Size: 840.00, Stock: 601877
# 2019-12-17, BUY EXECUTED, ref:24218, Price: 85.58, Cost: 130338.34, Comm 0.00, Size: 1523.00, Stock: 601888
# 2019-12-17, BUY EXECUTED, ref:24219, Price: 4.82, Cost: 2305078.24, Comm 0.00, Size: 478232.00, Stock: 601898
# 2019-12-17, BUY EXECUTED, ref:24220, Price: 7.15, Cost: 2309857.55, Comm 0.00, Size: 323057.00, Stock: 601939
# 2019-12-17, BUY EXECUTED, ref:24221, Price: 3.65, Cost: 2309862.35, Comm 0.00, Size: 632839.00, Stock: 601988
# 2019-12-17, BUY EXECUTED, ref:24222, Price: 2.42, Cost: 2309860.96, Comm 0.00, Size: 954488.00, Stock: 601991
# 2019-12-17, BUY EXECUTED, ref:24223, Price: 9.53, Cost: 10635.48, Comm 0.00, Size: 1116.00, Stock: 601997
# 2019-12-17, BUY EXECUTED, ref:24224, Price: 6.12, Cost: 2309859.36, Comm 0.00, Size: 377428.00, Stock: 601998
# 2019-12-17, SELL EXECUTED, ref:24225, Price: 28.07, Cost: 18967.32, Comm 0.00, Size: -684.00, Stock: 603156
# 2019-12-17, BUY EXECUTED, ref:24226, Price: 28.77, Cost: 2339950.41, Comm 0.00, Size: 81333.00, Stock: 603260
# 2019-12-17, BUY EXECUTED, ref:24227, Price: 99.00, Cost: 84744.00, Comm 0.00, Size: 856.00, Stock: 603833
# 2019-12-17, 当前总资产 147562404.61
# --------------2019-12-17 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000069', '000423', '000503', '000671', '000768', '000783', '000786', '000961', '002027', '002044', '002050', '002456', '002555', '002602', '002624', '002673', '002714', '002736', '002773', '002797', '300017', '300033', '300059', '300122', '300124', '300408', '300433', '600009', '600010', '600030', '600048', '600068', '600100', '600109', '600271', '600383', '600438', '600535', '600570', '600690', '600760', '600837', '600926', '600999', '601066', '601108', '601138', '601198', '601228', '601288', '601377', '601555', '601601', '601688', '601878', '601881', '601901', '603799', '603858', '603993']
# sell_stock ['000425', '000538', '000553', '000630', '000661', '000792', '000898', '000959', '001965', '002024', '002032', '002085', '002142', '002294', '002310', '002311', '002493', '002558', '002601', '300024', '600015', '600016', '600018', '600028', '600176', '600177', '600221', '600297', '600436', '600519', '600549', '600660', '600674', '600886', '600919', '601018', '601169', '601328', '601333', '601398', '601766', '601828', '601838', '601857', '601877', '601888', '601898', '601939', '601988', '601991', '601997', '601998', '603156', '603260', '603833']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2019-12-18, SELL EXECUTED, ref:24228, Price: 5.02, Cost: 2319028.36, Comm 0.00, Size: -458306.00, Stock: 000425
# 2019-12-18, SELL EXECUTED, ref:24229, Price: 87.39, Cost: 2310073.50, Comm 0.00, Size: -26425.00, Stock: 000538
# 2019-12-18, SELL EXECUTED, ref:24230, Price: 9.76, Cost: 2307469.40, Comm 0.00, Size: -239116.00, Stock: 000553
# 2019-12-18, SELL EXECUTED, ref:24231, Price: 2.22, Cost: 2309861.40, Comm 0.00, Size: -1049937.00, Stock: 000630
# 2019-12-18, SELL EXECUTED, ref:24232, Price: 441.95, Cost: 2306719.80, Comm 0.00, Size: -5082.00, Stock: 000661
# 2019-12-18, SELL EXECUTED, ref:24233, Price: 7.84, Cost: 2286500.94, Comm 0.00, Size: -292018.00, Stock: 000792
# 2019-12-18, SELL EXECUTED, ref:24234, Price: 3.22, Cost: 2331585.90, Comm 0.00, Size: -724095.00, Stock: 000898
# 2019-12-18, SELL EXECUTED, ref:24235, Price: 3.54, Cost: 2309860.00, Comm 0.00, Size: -659960.00, Stock: 000959
# 2019-12-18, SELL EXECUTED, ref:24236, Price: 8.70, Cost: 2309855.76, Comm 0.00, Size: -270792.00, Stock: 001965
# 2019-12-18, SELL EXECUTED, ref:24237, Price: 10.20, Cost: 2312160.22, Comm 0.00, Size: -229837.00, Stock: 002024
# 2019-12-18, SELL EXECUTED, ref:24238, Price: 75.75, Cost: 2306144.01, Comm 0.00, Size: -30549.00, Stock: 002032
# 2019-12-18, SELL EXECUTED, ref:24239, Price: 7.09, Cost: 2306570.40, Comm 0.00, Size: -329040.00, Stock: 002085
# 2019-12-18, SELL EXECUTED, ref:24240, Price: 27.88, Cost: 2295654.48, Comm 0.00, Size: -83448.00, Stock: 002142
# 2019-12-18, SELL EXECUTED, ref:24241, Price: 18.80, Cost: 2319881.50, Comm 0.00, Size: -125399.00, Stock: 002294
# 2019-12-18, SELL EXECUTED, ref:24242, Price: 4.91, Cost: 2319444.16, Comm 0.00, Size: -479224.00, Stock: 002310
# 2019-12-18, SELL EXECUTED, ref:24243, Price: 32.70, Cost: 2303880.12, Comm 0.00, Size: -74511.00, Stock: 002311
# 2019-12-18, SELL EXECUTED, ref:24244, Price: 12.50, Cost: 2344643.68, Comm 0.00, Size: -184937.00, Stock: 002493
# 2019-12-18, SELL EXECUTED, ref:24245, Price: 17.98, Cost: 2309862.17, Comm 0.00, Size: -130427.00, Stock: 002558
# 2019-12-18, SELL EXECUTED, ref:24246, Price: 13.59, Cost: 2265099.59, Comm 0.00, Size: -174067.00, Stock: 002601
# 2019-12-18, SELL EXECUTED, ref:24247, Price: 14.59, Cost: 2321302.40, Comm 0.00, Size: -163472.00, Stock: 300024
# 2019-12-18, BUY EXECUTED, ref:24338, Price: 11.39, Cost: 2334346.33, Comm 0.00, Size: 204947.00, Stock: 601881
# 2019-12-18, BUY EXECUTED, ref:24339, Price: 7.09, Cost: 2326555.14, Comm 0.00, Size: 328146.00, Stock: 601901
# 2019-12-18, BUY EXECUTED, ref:24340, Price: 31.80, Cost: 2311669.20, Comm 0.00, Size: 72694.00, Stock: 603799
# 2019-12-18, BUY EXECUTED, ref:24341, Price: 20.50, Cost: 2332982.00, Comm 0.00, Size: 113804.00, Stock: 603858
# 2019-12-18, BUY EXECUTED, ref:24342, Price: 3.81, Cost: 2330287.44, Comm 0.00, Size: 611624.00, Stock: 603993
# 2019-12-18, 当前总资产 148638924.19
# 2019-12-19, 当前总资产 148120875.14
# 2019-12-20, 当前总资产 148201190.99
# 2019-12-23, 当前总资产 145793063.70
# 2019-12-24, 当前总资产 147942599.06
# 2019-12-25, 当前总资产 148601829.81
# 2019-12-26, 当前总资产 150756587.18
# 2019-12-27, 当前总资产 148813595.44
# 2019-12-30, 当前总资产 152283875.80
# 2019-12-31, 当前总资产 152549449.14

# %%
strat = result[0]
print("--------------- AnnualReturn -----------------")
print(strat.analyzers._AnnualReturn.get_analysis())
print("--------------- DrawDown -----------------")
print(strat.analyzers._DrawDown.get_analysis())
print("--------------- Returns -----------------")
print(strat.analyzers._Returns.get_analysis())
print("--------------- SharpeRatio -----------------")
print(strat.analyzers._SharpeRatio.get_analysis())
print("--------------- SharpeRatio_A -----------------")
print(strat.analyzers._SharpeRatio_A.get_analysis())
# Out:
# --------------- AnnualReturn -----------------
# OrderedDict([(2019, 0.525494491399999)])
# --------------- DrawDown -----------------
# AutoOrderedDict([('len', 0), ('drawdown', 0.0), ('moneydown', 0.0), ('max', AutoOrderedDict([('len', 172), ('drawdown', 15.282466865953348), ('moneydown', 22697469.970000133)]))])
# --------------- Returns -----------------
# OrderedDict([('rtot', 0.4223186141552842), ('ravg', 0.0017308139924396893), ('rnorm', 0.5467641847924308), ('rnorm100', 54.67641847924308)])
# --------------- SharpeRatio -----------------
# OrderedDict([('sharperatio', 2.012662825009006)])
# --------------- SharpeRatio_A -----------------
# OrderedDict([('sharperatio', None)])

# %%
# 绘制累计收益率
ret = pd.Series(strat.analyzers._TimeReturn.get_analysis())
(ret + 1).cumprod().plot(figsize=(12,6))

# %%
def get_my_analyzer(result):
    analyzer = {}

    # 提取年化收益
    analyzer['年化收益率'] = result.analyzers._Returns.get_analysis()['rnorm']
    analyzer['年化收益率（%）'] = result.analyzers._Returns.get_analysis()['rnorm100']
    # 提取最大回撤
    analyzer['最大回撤（%）'] = result.analyzers._DrawDown.get_analysis()['max']['drawdown'] * (-1)
    # 提取夏普比率
    analyzer['夏普比率'] = result.analyzers._SharpeRatio.get_analysis()['sharperatio']
    
    return analyzer

ret = []
# for i in result:
ret.append(get_my_analyzer(result[0]))
    
pd.DataFrame(ret).sort_values(by='年化收益率', ascending=False)
# Out:
#       年化收益率   年化收益率（%）    最大回撤（%）      夏普比率
# 0  0.546764  54.676418 -15.282467  2.012663
