# %%
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy
from datas import *

# %% [markdown]
# # 一、数据准备

# %% [markdown]
# ## 1.1 读取日度行情表
#
# 表内字段就是 Backtrader 默认情况下要求输入的 7 个字段： 'datetime' 、'open'、'high'、'low'、'close'、'volume'、'openinterest'，外加一个 'sec_code' 股票代码字段。

# %%
year = 2021
list_assets, df_assets = get_hs300_stocks(f'{year}-01-01')
df_org= get_all_date_data(f'{year}-01-01', f'{year+1}-01-01', list_assets)
df1 = df_org.rename(columns={
        "date": "datetime", 
        "asset": "sec_code"})
df1["openinterest"] = 0
daily_price=df1[['sec_code','datetime', "open", "close", "high", "low", "volume", 'openinterest']]
daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])

# 以 datetime 为 index，类型为 datetime 或 date 类型，Datafeeds 默认情况下是将 index 匹配给 datetime 字段；
daily_price = daily_price.set_index(['datetime'])
daily_price
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_hs300 error_code:0
# query_hs300  error_msg:success
# logout success!
# 300
# <ipython-input-109-8c1e2acb5d46>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_price['datetime'] = pd.to_datetime(daily_price['datetime'])
#            sec_code   open  close   high    low  volume  openinterest
# datetime
# 2021-01-04   600000   9.64   9.69   9.73   9.55  629069             0
# 2021-01-05   600000   9.68   9.68   9.68   9.52  538592             0
# 2021-01-06   600000   9.62   9.82   9.83   9.62  618813             0
# 2021-01-07   600000   9.83   9.81   9.93   9.66  570904             0
# 2021-01-08   600000   9.83   9.83   9.90   9.73  558015             0
# ...             ...    ...    ...    ...    ...     ...           ...
# 2021-12-27   300676  89.32  89.87  90.20  89.03   21026             0
# 2021-12-28   300676  89.87  88.65  90.30  88.42   27472             0
# 2021-12-29   300676  88.66  88.19  89.70  88.10   30774             0
# 2021-12-30   300676  87.88  87.79  88.59  87.15   34217             0
# 2021-12-31   300676  87.90  87.80  89.65  87.71   30712             0
#
# [72729 rows x 7 columns]

# %% [markdown]
# ## 1.2 生成调仓信息表
#
# 表内数据说明：
#
# + trade_date： 调仓期（每月最后一个交易日）;
#
# + sec_code：持仓成分股；
#
# + weight：持仓权重。

# %%
from alphalens.utils import get_clean_factor_and_forward_returns
from alphalens.tears import create_full_tear_sheet

df_2 = df_org[['date', 'asset', "close"]]
df_2['date'] = pd.to_datetime(df_2['date'])
# print(df_all)

close = df_2.pivot(index='date', columns='asset', values='close')

alpha_num = 83
alpha_name = 'Alphas101'

# 读取已经计算好的因子
alpha = pd.read_csv('alphas/{}/{}/alpha{:03d}.csv'.format(alpha_name, year, alpha_num))

# 筛选出今年的数据，需与股票收盘日期区间一致
alpha = alpha[(alpha['date'] >= f'{year}-01-01') & (alpha['date'] <= f'{year+1}-01-01')]

# 因子矩阵转换为一维数据(alphalens需要的格式)
alpha = alpha.melt(id_vars=['date'], var_name='asset', value_name='factor' )

# date列转为日期格式
alpha['date'] = pd.to_datetime(alpha['date'])
alpha = alpha[['date', 'asset', 'factor']]

# 设置二级索引
alpha = alpha.set_index(['date', 'asset'], drop=True)
alpha.sort_index(inplace=True)


ret = get_clean_factor_and_forward_returns(alpha, close,quantiles=5)
ret = ret.reset_index()
ret = ret[ret['factor_quantile'] == 5]
ret = ret[['date','asset']]
ret['weight'] = 1/60
trade_info = ret.rename(columns={
        "date": "trade_date", 
        "asset": "sec_code"})
trade_info
# Out:
# <ipython-input-110-3029e40aae47>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['date'] = pd.to_datetime(df_2['date'])
# Dropped 4.5% entries from factor data: 4.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
#       trade_date sec_code    weight
# 0     2021-01-04   000001  0.016667
# 4     2021-01-04   000069  0.016667
# 8     2021-01-04   000333  0.016667
# 17    2021-01-04   000656  0.016667
# 19    2021-01-04   000671  0.016667
# ...          ...      ...       ...
# 69614 2021-12-17   603369  0.016667
# 69616 2021-12-17   603501  0.016667
# 69618 2021-12-17   603799  0.016667
# 69621 2021-12-17   603986  0.016667
# 69625 2021-12-17   688012  0.016667
#
# [13977 rows x 3 columns]

# %% [markdown]
# # 二、 回测分析

# %% [markdown]
# ## 2.1 加载策略和数据

# %%
# 回测策略
class TestStrategy(bt.Strategy):
    params = (
        ('buy_stocks', None), # 传入各个调仓日的股票列表和相应的权重
    )
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print(f'{dt.isoformat()}, {txt}')

    def __init__(self):
         # 读取调仓日期，即每月的最后一个交易日，回测时，会在这一天下单，然后在下一个交易日，以开盘价买入
        self.trade_dates = pd.to_datetime(self.p.buy_stocks['trade_date'].unique()).tolist()
        self.buy_stock = self.p.buy_stocks # 保留调仓信息
        self.order_list = []  # 记录以往订单，在调仓日要全部取消未成交的订单
        self.buy_stocks_pre = [] # 记录上一期持仓
    
    def next(self):
        # 获取当前的回测时间点
        dt = self.datas[0].datetime.date(0)
        # 打印当前时刻的总资产
        self.log('当前总资产 %.2f' %(self.broker.getvalue()))
        # 如果是调仓日，则进行调仓操作
        if dt in self.trade_dates:
            print(f"--------------{dt} 为调仓日----------")
            #取消之前所下的没成交也未到期的订单
            if len(self.order_list) > 0:
                print("--------------- 撤销未完成的订单 -----------------")
                for od in self.order_list:
                    # 如果订单未完成，则撤销订单
                    self.cancel(od) 
                 #重置订单列表
                self.order_list = [] 

            # 提取当前调仓日的持仓列表
            buy_stocks_data = self.buy_stock.query(f"trade_date=='{dt}'")
            long_list = buy_stocks_data['sec_code'].tolist()
            print('long_list', long_list)  # 打印持仓列表

            # 对现有持仓中，调仓后不再继续持有的股票进行卖出平仓
            sell_stock = [i for i in self.buy_stocks_pre if i not in long_list]
            print('sell_stock', sell_stock)
            if sell_stock:
                print("-----------对不再持有的股票进行平仓--------------")
                for stock in sell_stock:
                    data = self.getdatabyname(stock)
                    if self.getposition(data).size > 0 :
                        od = self.close(data=data)  
                        self.order_list.append(od) # 记录卖出订单

            # 买入此次调仓的股票：多退少补原则
            print("-----------买入此次调仓期的股票--------------")
            for stock in long_list:
                w = buy_stocks_data.query(f"sec_code=='{stock}'")['weight'].iloc[0] # 提取持仓权重
                data = self.getdatabyname(stock)
                order = self.order_target_percent(data=data, target=w*0.95) # 为减少可用资金不足的情况，留 5% 的现金做备用
                self.order_list.append(order)

            self.buy_stocks_pre = long_list  # 保存此次调仓的股票列表
        
    #订单日志    
    def notify_order(self, order):
        # 未被处理的订单
        if order.status in [order.Submitted, order.Accepted]:
            return
        # 已被处理的订单
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                    (order.ref,
                     order.executed.price,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.size,
                     order.data._name))
            else:  # Sell
                self.log('SELL EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                        (order.ref,
                         order.executed.price,
                         order.executed.value,
                         order.executed.comm,
                         order.executed.size,
                         order.data._name))

# 实例化大脑
cerebro_ = bt.Cerebro() 

# 按股票代码，依次循环传入数据
for stock in daily_price['sec_code'].unique():
    # 日期对齐
    data = pd.DataFrame(index=daily_price.index.unique())
    df = daily_price.query(f"sec_code=='{stock}'")[['open','high','low','close','volume','openinterest']]
    data_ = pd.merge(data, df, left_index=True, right_index=True, how='left')
    data_.loc[:,['volume','openinterest']] = data_.loc[:,['volume','openinterest']].fillna(0)
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(method='pad')
    # data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(0)
    datafeed = bt.feeds.PandasData(dataname=data_, fromdate=datetime.datetime(year,1,1), todate=datetime.datetime(year+1,1,1))
    cerebro_.adddata(datafeed, name=stock)
    print(f"{stock} Done !")
# Out:
# 600000 Done !
# 600004 Done !
# 600009 Done !
# 600010 Done !
# 600011 Done !
# 600015 Done !
# 600016 Done !
# 600018 Done !
# 600019 Done !
# 600025 Done !
# 600027 Done !
# 600028 Done !
# 600029 Done !
# 600030 Done !
# 600031 Done !
# 600036 Done !
# 600048 Done !
# 600050 Done !
# 600061 Done !
# 600066 Done !
# 600068 Done !
# 600085 Done !
# 600104 Done !
# 600109 Done !
# 600111 Done !
# 600115 Done !
# 600118 Done !
# 600150 Done !
# 600161 Done !
# 600176 Done !
# 600177 Done !
# 600183 Done !
# 600196 Done !
# 600208 Done !
# 600233 Done !
# 600271 Done !
# 600276 Done !
# 600297 Done !
# 600299 Done !
# 600309 Done !
# 600332 Done !
# 600340 Done !
# 600346 Done !
# 600352 Done !
# 600362 Done !
# 600369 Done !
# 600383 Done !
# 600390 Done !
# 600406 Done !
# 600436 Done !
# 600438 Done !
# 600482 Done !
# 600487 Done !
# 600489 Done !
# 600498 Done !
# 600519 Done !
# 600522 Done !
# 600547 Done !
# 600570 Done !
# 600584 Done !
# 600585 Done !
# 600588 Done !
# 600600 Done !
# 600606 Done !
# 600637 Done !
# 600655 Done !
# 600660 Done !
# 600690 Done !
# 600703 Done !
# 600705 Done !
# 600741 Done !
# 600745 Done !
# 600760 Done !
# 600763 Done !
# 600795 Done !
# 600809 Done !
# 600837 Done !
# 600845 Done !
# 600848 Done !
# 600872 Done !
# 600886 Done !
# 600887 Done !
# 600893 Done !
# 002463 Done !
# 002475 Done !
# 002493 Done !
# 002508 Done !
# 002555 Done !
# 002558 Done !
# 002594 Done !
# 002600 Done !
# 002601 Done !
# 002602 Done !
# 002607 Done !
# 002624 Done !
# 002673 Done !
# 002714 Done !
# 002736 Done !
# 002739 Done !
# 002773 Done !
# 002812 Done !
# 002821 Done !
# 002841 Done !
# 002916 Done !
# 002938 Done !
# 002939 Done !
# 002945 Done !
# 002958 Done !
# 003816 Done !
# 300003 Done !
# 300014 Done !
# 300015 Done !
# 300033 Done !
# 300059 Done !
# 300122 Done !
# 300124 Done !
# 300136 Done !
# 300142 Done !
# 300144 Done !
# 300347 Done !
# 300408 Done !
# 300413 Done !
# 300433 Done !
# 300498 Done !
# 300529 Done !
# 300601 Done !
# 300628 Done !
# 300676 Done !

# %% [markdown]
# ## 2.2 添加分析器并执行回测

# %%
cerebro = deepcopy(cerebro_)  # 深度复制已经导入数据的 cerebro_，避免重复导入数据 
# 初始资金 100,000,000    
cerebro.broker.setcash(100000.0) 
# 添加策略
cerebro.addstrategy(TestStrategy, buy_stocks=trade_info) # 通过修改参数 buy_stocks ，使用同一策略回测不同的持仓列表

# 添加分析指标
# 返回年初至年末的年度收益率
cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='_AnnualReturn')
# 计算最大回撤相关指标
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='_DrawDown')
# 计算年化收益
cerebro.addanalyzer(bt.analyzers.Returns, _name='_Returns', tann=252)
# 计算年化夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='_SharpeRatio', timeframe=bt.TimeFrame.Days, annualize=True, riskfreerate=0) # 计算夏普比率
cerebro.addanalyzer(bt.analyzers.SharpeRatio_A, _name='_SharpeRatio_A')
# 返回收益率时序
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='_TimeReturn')

# 启动回测
result = cerebro.run()
# Out:
# 2021-01-04, 当前总资产 100000.00
# --------------2021-01-04 为调仓日----------
# long_list ['000001', '000069', '000333', '000656', '000671', '000895', '001979', '002044', '002129', '002146', '002410', '002607', '002773', '002841', '300003', '300015', '300122', '300144', '300601', '300628', '600031', '600048', '600066', '600104', '600161', '600276', '600299', '600369', '600383', '600406', '600570', '600606', '600660', '600741', '600763', '600795', '600809', '600900', '600918', '600926', '600958', '601100', '601155', '601162', '601166', '601336', '601577', '601696', '601788', '601838', '601878', '601888', '601901', '603019', '603156', '603259', '603288', '603658', '603833', '688008']
# sell_stock []
# -----------买入此次调仓期的股票--------------
# 2021-01-05, BUY EXECUTED, ref:181119, Price: 18.40, Cost: 1564.00, Comm 0.00, Size: 85.00, Stock: 000001
# 2021-01-05, BUY EXECUTED, ref:181120, Price: 6.87, Cost: 1573.23, Comm 0.00, Size: 229.00, Stock: 000069
# 2021-01-05, BUY EXECUTED, ref:181121, Price: 98.07, Cost: 1471.05, Comm 0.00, Size: 15.00, Stock: 000333
# 2021-01-05, BUY EXECUTED, ref:181122, Price: 6.59, Cost: 1581.60, Comm 0.00, Size: 240.00, Stock: 000656
# 2021-01-05, BUY EXECUTED, ref:181123, Price: 6.25, Cost: 1575.00, Comm 0.00, Size: 252.00, Stock: 000671
# 2021-01-05, BUY EXECUTED, ref:181124, Price: 48.06, Cost: 1537.92, Comm 0.00, Size: 32.00, Stock: 000895
# 2021-01-05, BUY EXECUTED, ref:181125, Price: 12.90, Cost: 1573.80, Comm 0.00, Size: 122.00, Stock: 001979
# 2021-01-05, BUY EXECUTED, ref:181126, Price: 11.46, Cost: 1558.56, Comm 0.00, Size: 136.00, Stock: 002044
# 2021-01-05, BUY EXECUTED, ref:181127, Price: 26.61, Cost: 1569.99, Comm 0.00, Size: 59.00, Stock: 002129
# 2021-01-05, BUY EXECUTED, ref:181128, Price: 6.41, Cost: 1583.27, Comm 0.00, Size: 247.00, Stock: 002146
# 2021-01-05, BUY EXECUTED, ref:181129, Price: 80.24, Cost: 1524.56, Comm 0.00, Size: 19.00, Stock: 002410
# 2021-01-05, BUY EXECUTED, ref:181130, Price: 34.30, Cost: 1577.80, Comm 0.00, Size: 46.00, Stock: 002607
# 2021-01-05, BUY EXECUTED, ref:181131, Price: 46.42, Cost: 1578.28, Comm 0.00, Size: 34.00, Stock: 002773
# 2021-01-05, BUY EXECUTED, ref:181132, Price: 114.38, Cost: 1486.94, Comm 0.00, Size: 13.00, Stock: 002841
# 2021-01-05, BUY EXECUTED, ref:181133, Price: 26.70, Cost: 1575.30, Comm 0.00, Size: 59.00, Stock: 300003
# 2021-01-05, BUY EXECUTED, ref:181134, Price: 67.51, Cost: 1552.73, Comm 0.00, Size: 23.00, Stock: 300015
# 2021-01-05, BUY EXECUTED, ref:181135, Price: 141.86, Cost: 1560.46, Comm 0.00, Size: 11.00, Stock: 300122
# 2021-01-05, BUY EXECUTED, ref:181136, Price: 17.50, Cost: 1575.00, Comm 0.00, Size: 90.00, Stock: 300144
# 2021-01-05, BUY EXECUTED, ref:181137, Price: 164.00, Cost: 1476.00, Comm 0.00, Size: 9.00, Stock: 300601
# 2021-01-05, BUY EXECUTED, ref:181138, Price: 71.52, Cost: 1573.44, Comm 0.00, Size: 22.00, Stock: 300628
# 2021-01-05, BUY EXECUTED, ref:181139, Price: 34.51, Cost: 1552.95, Comm 0.00, Size: 45.00, Stock: 600031
# 2021-01-05, BUY EXECUTED, ref:181140, Price: 15.19, Cost: 1564.57, Comm 0.00, Size: 103.00, Stock: 600048
# 2021-01-05, BUY EXECUTED, ref:181141, Price: 16.32, Cost: 1566.72, Comm 0.00, Size: 96.00, Stock: 600066
# 2021-01-05, BUY EXECUTED, ref:181142, Price: 23.67, Cost: 1585.89, Comm 0.00, Size: 67.00, Stock: 600104
# 2021-01-05, BUY EXECUTED, ref:181143, Price: 40.81, Cost: 1550.78, Comm 0.00, Size: 38.00, Stock: 600161
# 2021-01-05, BUY EXECUTED, ref:181144, Price: 111.20, Cost: 1556.80, Comm 0.00, Size: 14.00, Stock: 600276
# 2021-01-05, BUY EXECUTED, ref:181145, Price: 11.68, Cost: 1576.80, Comm 0.00, Size: 135.00, Stock: 600299
# 2021-01-05, BUY EXECUTED, ref:181146, Price: 5.63, Cost: 1559.51, Comm 0.00, Size: 277.00, Stock: 600369
# 2021-01-05, BUY EXECUTED, ref:181147, Price: 12.83, Cost: 1565.26, Comm 0.00, Size: 122.00, Stock: 600383
# 2021-01-05, BUY EXECUTED, ref:181148, Price: 26.60, Cost: 1569.40, Comm 0.00, Size: 59.00, Stock: 600406
# 2021-01-05, BUY EXECUTED, ref:181149, Price: 105.53, Cost: 1477.42, Comm 0.00, Size: 14.00, Stock: 600570
# 2021-01-05, BUY EXECUTED, ref:181150, Price: 5.69, Cost: 1570.44, Comm 0.00, Size: 276.00, Stock: 600606
# 2021-01-05, BUY EXECUTED, ref:181151, Price: 52.00, Cost: 1612.00, Comm 0.00, Size: 31.00, Stock: 600660
# 2021-01-05, BUY EXECUTED, ref:181152, Price: 29.47, Cost: 1591.38, Comm 0.00, Size: 54.00, Stock: 600741
# 2021-01-05, BUY EXECUTED, ref:181153, Price: 266.00, Cost: 1330.00, Comm 0.00, Size: 5.00, Stock: 600763
# 2021-01-05, BUY EXECUTED, ref:181154, Price: 2.21, Cost: 1582.36, Comm 0.00, Size: 716.00, Stock: 600795
# 2021-01-05, BUY EXECUTED, ref:181155, Price: 373.00, Cost: 1492.00, Comm 0.00, Size: 4.00, Stock: 600809
# 2021-01-05, BUY EXECUTED, ref:181156, Price: 18.85, Cost: 1564.55, Comm 0.00, Size: 83.00, Stock: 600900
# 2021-01-05, BUY EXECUTED, ref:181157, Price: 17.70, Cost: 1557.60, Comm 0.00, Size: 88.00, Stock: 600918
# 2021-01-05, BUY EXECUTED, ref:181158, Price: 13.90, Cost: 1556.80, Comm 0.00, Size: 112.00, Stock: 600926
# 2021-01-05, BUY EXECUTED, ref:181159, Price: 11.46, Cost: 1558.56, Comm 0.00, Size: 136.00, Stock: 600958
# 2021-01-05, BUY EXECUTED, ref:181160, Price: 111.90, Cost: 1566.60, Comm 0.00, Size: 14.00, Stock: 601100
# 2021-01-05, BUY EXECUTED, ref:181161, Price: 33.40, Cost: 1569.80, Comm 0.00, Size: 47.00, Stock: 601155
# 2021-01-05, BUY EXECUTED, ref:181162, Price: 6.02, Cost: 1565.20, Comm 0.00, Size: 260.00, Stock: 601162
# 2021-01-05, BUY EXECUTED, ref:181163, Price: 19.52, Cost: 1561.60, Comm 0.00, Size: 80.00, Stock: 601166
# 2021-01-05, BUY EXECUTED, ref:181164, Price: 56.05, Cost: 1569.40, Comm 0.00, Size: 28.00, Stock: 601336
# 2021-01-05, BUY EXECUTED, ref:181165, Price: 9.15, Cost: 1573.80, Comm 0.00, Size: 172.00, Stock: 601577
# 2021-01-05, BUY EXECUTED, ref:181166, Price: 28.02, Cost: 1541.10, Comm 0.00, Size: 55.00, Stock: 601696
# 2021-01-05, BUY EXECUTED, ref:181167, Price: 18.20, Cost: 1565.20, Comm 0.00, Size: 86.00, Stock: 601788
# 2021-01-05, BUY EXECUTED, ref:181168, Price: 9.80, Cost: 1577.80, Comm 0.00, Size: 161.00, Stock: 601838
# 2021-01-05, BUY EXECUTED, ref:181169, Price: 15.04, Cost: 1564.16, Comm 0.00, Size: 104.00, Stock: 601878
# 2021-01-05, BUY EXECUTED, ref:181170, Price: 290.00, Cost: 1450.00, Comm 0.00, Size: 5.00, Stock: 601888
# 2021-01-05, BUY EXECUTED, ref:181171, Price: 11.00, Cost: 1551.00, Comm 0.00, Size: 141.00, Stock: 601901
# 2021-01-05, BUY EXECUTED, ref:181172, Price: 34.28, Cost: 1542.60, Comm 0.00, Size: 45.00, Stock: 603019
# 2021-01-05, BUY EXECUTED, ref:181173, Price: 26.00, Cost: 1560.00, Comm 0.00, Size: 60.00, Stock: 603156
# 2021-01-05, BUY EXECUTED, ref:181174, Price: 136.98, Cost: 1506.78, Comm 0.00, Size: 11.00, Stock: 603259
# 2021-01-05, BUY EXECUTED, ref:181175, Price: 200.00, Cost: 1400.00, Comm 0.00, Size: 7.00, Stock: 603288
# 2021-01-05, BUY EXECUTED, ref:181176, Price: 132.00, Cost: 1452.00, Comm 0.00, Size: 11.00, Stock: 603658
# 2021-01-05, BUY EXECUTED, ref:181177, Price: 130.00, Cost: 1560.00, Comm 0.00, Size: 12.00, Stock: 603833
# 2021-01-05, BUY EXECUTED, ref:181178, Price: 80.75, Cost: 1534.25, Comm 0.00, Size: 19.00, Stock: 688008
# 2021-01-05, 当前总资产 100760.51
# --------------2021-01-05 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000063', '000625', '000627', '000723', '000768', '002008', '002049', '002153', '002157', '002202', '002558', '002602', '002624', '003816', '300015', '300144', '300498', '600010', '600011', '600016', '600018', '600025', '600027', '600050', '600066', '600068', '600104', '600276', '600297', '600362', '600369', '600482', '600498', '600795', '600848', '600918', '600926', '601006', '601108', '601166', '601186', '601216', '601236', '601238', '601555', '601668', '601696', '601727', '601766', '601800', '601808', '601838', '601888', '601901', '601988', '601989', '603019', '603288', '603833', '688009']
# sell_stock ['000001', '000069', '000333', '000656', '000671', '000895', '001979', '002044', '002129', '002146', '002410', '002607', '002773', '002841', '300003', '300122', '300601', '300628', '600031', '600048', '600161', '600299', '600383', '600406', '600570', '600606', '600660', '600741', '600763', '600809', '600900', '600958', '601100', '601155', '601162', '601336', '601577', '601788', '601878', '603156', '603259', '603658', '688008']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2021-01-06, SELL EXECUTED, ref:181179, Price: 18.08, Cost: 1564.00, Comm 0.00, Size: -85.00, Stock: 000001
# 2021-01-06, SELL EXECUTED, ref:181180, Price: 6.85, Cost: 1573.23, Comm 0.00, Size: -229.00, Stock: 000069
# 2021-01-06, SELL EXECUTED, ref:181181, Price: 103.00, Cost: 1471.05, Comm 0.00, Size: -15.00, Stock: 000333
# 2021-01-06, SELL EXECUTED, ref:181182, Price: 6.88, Cost: 1581.60, Comm 0.00, Size: -240.00, Stock: 000656
# 2021-01-06, SELL EXECUTED, ref:181183, Price: 6.29, Cost: 1575.00, Comm 0.00, Size: -252.00, Stock: 000671
# 2021-01-06, SELL EXECUTED, ref:181184, Price: 54.46, Cost: 1537.92, Comm 0.00, Size: -32.00, Stock: 000895
# 2021-01-06, SELL EXECUTED, ref:181185, Price: 12.81, Cost: 1573.80, Comm 0.00, Size: -122.00, Stock: 001979
# 2021-01-06, SELL EXECUTED, ref:181186, Price: 12.22, Cost: 1558.56, Comm 0.00, Size: -136.00, Stock: 002044
# 2021-01-06, SELL EXECUTED, ref:181187, Price: 26.92, Cost: 1569.99, Comm 0.00, Size: -59.00, Stock: 002129
# 2021-01-06, SELL EXECUTED, ref:181188, Price: 6.47, Cost: 1583.27, Comm 0.00, Size: -247.00, Stock: 002146
# 2021-01-06, SELL EXECUTED, ref:181189, Price: 79.60, Cost: 1524.56, Comm 0.00, Size: -19.00, Stock: 002410
# 2021-01-06, SELL EXECUTED, ref:181190, Price: 34.30, Cost: 1577.80, Comm 0.00, Size: -46.00, Stock: 002607
# 2021-01-06, SELL EXECUTED, ref:181191, Price: 46.40, Cost: 1578.28, Comm 0.00, Size: -34.00, Stock: 002773
# 2021-01-06, SELL EXECUTED, ref:181192, Price: 117.39, Cost: 1486.94, Comm 0.00, Size: -13.00, Stock: 002841
# 2021-01-06, SELL EXECUTED, ref:181193, Price: 27.82, Cost: 1575.30, Comm 0.00, Size: -59.00, Stock: 300003
# 2021-01-06, SELL EXECUTED, ref:181194, Price: 139.78, Cost: 1560.46, Comm 0.00, Size: -11.00, Stock: 300122
# 2021-01-06, SELL EXECUTED, ref:181195, Price: 153.95, Cost: 1476.00, Comm 0.00, Size: -9.00, Stock: 300601
# 2021-01-06, SELL EXECUTED, ref:181196, Price: 75.37, Cost: 1573.44, Comm 0.00, Size: -22.00, Stock: 300628
# 2021-01-06, SELL EXECUTED, ref:181197, Price: 36.58, Cost: 1552.95, Comm 0.00, Size: -45.00, Stock: 600031
# 2021-01-06, SELL EXECUTED, ref:181198, Price: 15.02, Cost: 1564.57, Comm 0.00, Size: -103.00, Stock: 600048
# 2021-01-06, SELL EXECUTED, ref:181199, Price: 40.97, Cost: 1550.78, Comm 0.00, Size: -38.00, Stock: 600161
# 2021-01-06, SELL EXECUTED, ref:181200, Price: 11.90, Cost: 1576.80, Comm 0.00, Size: -135.00, Stock: 600299
# 2021-01-06, SELL EXECUTED, ref:181201, Price: 12.60, Cost: 1565.26, Comm 0.00, Size: -122.00, Stock: 600383
# 2021-01-06, SELL EXECUTED, ref:181202, Price: 27.00, Cost: 1569.40, Comm 0.00, Size: -59.00, Stock: 600406
# 2021-01-06, SELL EXECUTED, ref:181203, Price: 108.88, Cost: 1477.42, Comm 0.00, Size: -14.00, Stock: 600570
# 2021-01-06, SELL EXECUTED, ref:181204, Price: 5.70, Cost: 1570.44, Comm 0.00, Size: -276.00, Stock: 600606
# 2021-01-06, SELL EXECUTED, ref:181205, Price: 50.99, Cost: 1612.00, Comm 0.00, Size: -31.00, Stock: 600660
# 2021-01-06, SELL EXECUTED, ref:181206, Price: 28.82, Cost: 1591.38, Comm 0.00, Size: -54.00, Stock: 600741
# 2021-01-06, SELL EXECUTED, ref:181207, Price: 285.00, Cost: 1330.00, Comm 0.00, Size: -5.00, Stock: 600763
# 2021-01-06, SELL EXECUTED, ref:181208, Price: 390.50, Cost: 1492.00, Comm 0.00, Size: -4.00, Stock: 600809
# 2021-01-06, SELL EXECUTED, ref:181209, Price: 18.78, Cost: 1564.55, Comm 0.00, Size: -83.00, Stock: 600900
# 2021-01-06, SELL EXECUTED, ref:181210, Price: 11.59, Cost: 1558.56, Comm 0.00, Size: -136.00, Stock: 600958
# 2021-01-06, SELL EXECUTED, ref:181211, Price: 117.00, Cost: 1566.60, Comm 0.00, Size: -14.00, Stock: 601100
# 2021-01-06, SELL EXECUTED, ref:181212, Price: 34.68, Cost: 1569.80, Comm 0.00, Size: -47.00, Stock: 601155
# 2021-01-06, SELL EXECUTED, ref:181213, Price: 6.10, Cost: 1565.20, Comm 0.00, Size: -260.00, Stock: 601162
# 2021-01-06, SELL EXECUTED, ref:181214, Price: 54.86, Cost: 1569.40, Comm 0.00, Size: -28.00, Stock: 601336
# 2021-01-06, SELL EXECUTED, ref:181215, Price: 9.05, Cost: 1573.80, Comm 0.00, Size: -172.00, Stock: 601577
# 2021-01-06, SELL EXECUTED, ref:181216, Price: 18.71, Cost: 1565.20, Comm 0.00, Size: -86.00, Stock: 601788
# 2021-01-06, SELL EXECUTED, ref:181217, Price: 15.16, Cost: 1564.16, Comm 0.00, Size: -104.00, Stock: 601878
# 2021-01-06, SELL EXECUTED, ref:181218, Price: 27.00, Cost: 1560.00, Comm 0.00, Size: -60.00, Stock: 603156
# 2021-01-06, SELL EXECUTED, ref:181219, Price: 142.18, Cost: 1506.78, Comm 0.00, Size: -11.00, Stock: 603259
# 2021-01-06, SELL EXECUTED, ref:181220, Price: 132.00, Cost: 1452.00, Comm 0.00, Size: -11.00, Stock: 603658
# 2021-01-06, SELL EXECUTED, ref:181221, Price: 85.00, Cost: 1534.25, Comm 0.00, Size: -19.00, Stock: 688008
# 2021-01-06, BUY EXECUTED, ref:181222, Price: 34.80, Cost: 1600.80, Comm 0.00, Size: 46.00, Stock: 000063
# 2021-01-06, BUY EXECUTED, ref:181223, Price: 21.30, Cost: 1597.50, Comm 0.00, Size: 75.00, Stock: 000625
# 2021-01-06, BUY EXECUTED, ref:181224, Price: 4.67, Cost: 1592.47, Comm 0.00, Size: 341.00, Stock: 000627
# 2021-01-06, BUY EXECUTED, ref:181225, Price: 6.70, Cost: 1594.60, Comm 0.00, Size: 238.00, Stock: 000723
# 2021-01-06, BUY EXECUTED, ref:181226, Price: 37.50, Cost: 1575.00, Comm 0.00, Size: 42.00, Stock: 000768
# 2021-01-06, BUY EXECUTED, ref:181227, Price: 44.41, Cost: 1554.35, Comm 0.00, Size: 35.00, Stock: 002008
# 2021-01-06, BUY EXECUTED, ref:181228, Price: 144.57, Cost: 1590.27, Comm 0.00, Size: 11.00, Stock: 002049
# 2021-01-06, BUY EXECUTED, ref:181229, Price: 31.18, Cost: 1590.18, Comm 0.00, Size: 51.00, Stock: 002153
# 2021-01-06, BUY EXECUTED, ref:181230, Price: 19.63, Cost: 1609.66, Comm 0.00, Size: 82.00, Stock: 002157
# 2021-01-06, BUY EXECUTED, ref:181231, Price: 15.19, Cost: 1594.95, Comm 0.00, Size: 105.00, Stock: 002202
# 2021-01-06, BUY EXECUTED, ref:181255, Price: 17.36, Cost: 52.08, Comm 0.00, Size: 3.00, Stock: 600918
# 2021-01-06, BUY EXECUTED, ref:181256, Price: 13.54, Cost: 81.24, Comm 0.00, Size: 6.00, Stock: 600926
# 2021-01-06, BUY EXECUTED, ref:181257, Price: 6.47, Cost: 1585.15, Comm 0.00, Size: 245.00, Stock: 601006
# 2021-01-06, BUY EXECUTED, ref:181258, Price: 12.49, Cost: 1586.23, Comm 0.00, Size: 127.00, Stock: 601108
# 2021-01-06, BUY EXECUTED, ref:181259, Price: 18.87, Cost: 75.48, Comm 0.00, Size: 4.00, Stock: 601166
# 2021-01-06, BUY EXECUTED, ref:181260, Price: 7.86, Cost: 1595.58, Comm 0.00, Size: 203.00, Stock: 601186
# 2021-01-06, BUY EXECUTED, ref:181261, Price: 4.77, Cost: 1583.64, Comm 0.00, Size: 332.00, Stock: 601216
# 2021-01-06, BUY EXECUTED, ref:181262, Price: 17.86, Cost: 1571.68, Comm 0.00, Size: 88.00, Stock: 601236
# 2021-01-06, BUY EXECUTED, ref:181263, Price: 12.50, Cost: 1625.00, Comm 0.00, Size: 130.00, Stock: 601238
# 2021-01-06, BUY EXECUTED, ref:181264, Price: 9.89, Cost: 1602.18, Comm 0.00, Size: 162.00, Stock: 601555
# 2021-01-06, BUY EXECUTED, ref:181265, Price: 4.86, Cost: 1584.36, Comm 0.00, Size: 326.00, Stock: 601668
# 2021-01-06, BUY EXECUTED, ref:181266, Price: 27.25, Cost: 81.75, Comm 0.00, Size: 3.00, Stock: 601696
# 2021-01-06, BUY EXECUTED, ref:181267, Price: 5.56, Cost: 1595.72, Comm 0.00, Size: 287.00, Stock: 601727
# 2021-01-06, BUY EXECUTED, ref:181268, Price: 5.44, Cost: 1621.12, Comm 0.00, Size: 298.00, Stock: 601766
# 2021-01-06, BUY EXECUTED, ref:181269, Price: 7.18, Cost: 1593.96, Comm 0.00, Size: 222.00, Stock: 601800
# 2021-01-06, BUY EXECUTED, ref:181270, Price: 13.28, Cost: 1646.72, Comm 0.00, Size: 124.00, Stock: 601808
# 2021-01-06, BUY EXECUTED, ref:181271, Price: 9.39, Cost: 75.12, Comm 0.00, Size: 8.00, Stock: 601838
# 2021-01-06, BUY EXECUTED, ref:181272, Price: 10.15, Cost: 121.80, Comm 0.00, Size: 12.00, Stock: 601901
# 2021-01-06, BUY EXECUTED, ref:181273, Price: 3.17, Cost: 1594.51, Comm 0.00, Size: 503.00, Stock: 601988
# 2021-01-06, BUY EXECUTED, ref:181274, Price: 4.26, Cost: 1601.76, Comm 0.00, Size: 376.00, Stock: 601989
# 2021-01-06, BUY EXECUTED, ref:181275, Price: 5.90, Cost: 1587.10, Comm 0.00, Size: 269.00, Stock: 688009
# 2021-01-06, 当前总资产 101005.76
# --------------2021-01-06 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000063', '000333', '000538', '000651', '000661', '000768', '000876', '000895', '000938', '000977', '002001', '002008', '002049', '002157', '002179', '002230', '002236', '002241', '002304', '002352', '002371', '002384', '002415', '002456', '002475', '002600', '002607', '002624', '002916', '300033', '300059', '300136', '600009', '600085', '600109', '600118', '600183', '600362', '600570', '600584', '600690', '600703', '600745', '600809', '600845', '600893', '600999', '601021', '601138', '601600', '601696', '601698', '601788', '601878', '601899', '603019', '603160', '603501', '603986', '688012']
# sell_stock ['000625', '000627', '000723', '002153', '002202', '002558', '002602', '003816', '300015', '300144', '300498', '600010', '600011', '600016', '600018', '600025', '600027', '600050', '600066', '600068', '600104', '600276', '600297', '600369', '600482', '600498', '600795', '600848', '600918', '600926', '601006', '601108', '601166', '601186', '601216', '601236', '601238', '601555', '601668', '601727', '601766', '601800', '601808', '601838', '601888', '601901', '601988', '601989', '603288', '603833', '688009']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2021-01-07, SELL EXECUTED, ref:181276, Price: 21.34, Cost: 1597.50, Comm 0.00, Size: -75.00, Stock: 000625
# 2021-01-07, SELL EXECUTED, ref:181277, Price: 4.65, Cost: 1592.47, Comm 0.00, Size: -341.00, Stock: 000627
# 2021-01-07, SELL EXECUTED, ref:181278, Price: 6.39, Cost: 1594.60, Comm 0.00, Size: -238.00, Stock: 000723
# 2021-01-07, SELL EXECUTED, ref:181279, Price: 29.80, Cost: 1590.18, Comm 0.00, Size: -51.00, Stock: 002153
# 2021-01-07, SELL EXECUTED, ref:181280, Price: 15.86, Cost: 1594.95, Comm 0.00, Size: -105.00, Stock: 002202
# 2021-01-07, SELL EXECUTED, ref:181281, Price: 17.13, Cost: 1588.86, Comm 0.00, Size: -91.00, Stock: 002558
# 2021-01-07, SELL EXECUTED, ref:181282, Price: 6.89, Cost: 1588.16, Comm 0.00, Size: -224.00, Stock: 002602
# 2021-01-07, SELL EXECUTED, ref:181283, Price: 2.82, Cost: 1587.21, Comm 0.00, Size: -573.00, Stock: 003816
# 2021-01-07, SELL EXECUTED, ref:181284, Price: 71.12, Cost: 1552.73, Comm 0.00, Size: -23.00, Stock: 300015
# 2021-01-07, SELL EXECUTED, ref:181285, Price: 16.97, Cost: 1609.68, Comm 0.00, Size: -92.00, Stock: 300144
# 2021-01-07, SELL EXECUTED, ref:181286, Price: 19.41, Cost: 1597.60, Comm 0.00, Size: -80.00, Stock: 300498
# 2021-01-07, SELL EXECUTED, ref:181287, Price: 1.17, Cost: 1594.71, Comm 0.00, Size: -1363.00, Stock: 600010
# 2021-01-07, SELL EXECUTED, ref:181288, Price: 4.40, Cost: 1592.80, Comm 0.00, Size: -362.00, Stock: 600011
# 2021-01-07, SELL EXECUTED, ref:181289, Price: 5.21, Cost: 1589.28, Comm 0.00, Size: -308.00, Stock: 600016
# 2021-01-07, SELL EXECUTED, ref:181290, Price: 4.63, Cost: 1594.60, Comm 0.00, Size: -340.00, Stock: 600018
# 2021-01-07, SELL EXECUTED, ref:181291, Price: 4.44, Cost: 1591.40, Comm 0.00, Size: -365.00, Stock: 600025
# 2021-01-07, SELL EXECUTED, ref:181292, Price: 3.34, Cost: 1587.30, Comm 0.00, Size: -481.00, Stock: 600027
# 2021-01-07, SELL EXECUTED, ref:181293, Price: 4.30, Cost: 1610.14, Comm 0.00, Size: -371.00, Stock: 600050
# 2021-01-07, SELL EXECUTED, ref:181294, Price: 15.43, Cost: 1674.03, Comm 0.00, Size: -103.00, Stock: 600066
# 2021-01-07, SELL EXECUTED, ref:181295, Price: 6.69, Cost: 1580.26, Comm 0.00, Size: -242.00, Stock: 600068
# 2021-01-07, SELL EXECUTED, ref:181296, Price: 23.05, Cost: 1654.44, Comm 0.00, Size: -70.00, Stock: 600104
# 2021-01-07, SELL EXECUTED, ref:181297, Price: 114.86, Cost: 1556.80, Comm 0.00, Size: -14.00, Stock: 600276
# 2021-01-07, SELL EXECUTED, ref:181298, Price: 2.81, Cost: 1604.60, Comm 0.00, Size: -565.00, Stock: 600297
# 2021-01-07, SELL EXECUTED, ref:181299, Price: 5.48, Cost: 1603.59, Comm 0.00, Size: -285.00, Stock: 600369
# 2021-01-07, SELL EXECUTED, ref:181300, Price: 19.00, Cost: 1577.52, Comm 0.00, Size: -84.00, Stock: 600482
# 2021-01-07, SELL EXECUTED, ref:181301, Price: 24.00, Cost: 1591.68, Comm 0.00, Size: -64.00, Stock: 600498
# 2021-01-07, SELL EXECUTED, ref:181302, Price: 2.17, Cost: 1629.88, Comm 0.00, Size: -738.00, Stock: 600795
# 2021-01-07, SELL EXECUTED, ref:181303, Price: 19.90, Cost: 1590.27, Comm 0.00, Size: -79.00, Stock: 600848
# 2021-01-07, SELL EXECUTED, ref:181304, Price: 17.12, Cost: 1609.68, Comm 0.00, Size: -91.00, Stock: 600918
# 2021-01-07, SELL EXECUTED, ref:181305, Price: 13.99, Cost: 1638.04, Comm 0.00, Size: -118.00, Stock: 600926
# 2021-01-07, SELL EXECUTED, ref:181306, Price: 6.51, Cost: 1585.15, Comm 0.00, Size: -245.00, Stock: 601006
# 2021-01-07, SELL EXECUTED, ref:181307, Price: 12.41, Cost: 1586.23, Comm 0.00, Size: -127.00, Stock: 601108
# 2021-01-07, SELL EXECUTED, ref:181308, Price: 19.80, Cost: 1637.08, Comm 0.00, Size: -84.00, Stock: 601166
# 2021-01-07, SELL EXECUTED, ref:181309, Price: 8.15, Cost: 1595.58, Comm 0.00, Size: -203.00, Stock: 601186
# 2021-01-07, SELL EXECUTED, ref:181310, Price: 4.71, Cost: 1583.64, Comm 0.00, Size: -332.00, Stock: 601216
# 2021-01-07, SELL EXECUTED, ref:181311, Price: 18.15, Cost: 1571.68, Comm 0.00, Size: -88.00, Stock: 601236
# 2021-01-07, SELL EXECUTED, ref:181312, Price: 12.23, Cost: 1625.00, Comm 0.00, Size: -130.00, Stock: 601238
# 2021-01-07, SELL EXECUTED, ref:181313, Price: 9.72, Cost: 1602.18, Comm 0.00, Size: -162.00, Stock: 601555
# 2021-01-07, SELL EXECUTED, ref:181314, Price: 4.96, Cost: 1584.36, Comm 0.00, Size: -326.00, Stock: 601668
# 2021-01-07, SELL EXECUTED, ref:181315, Price: 5.59, Cost: 1595.72, Comm 0.00, Size: -287.00, Stock: 601727
# 2021-01-07, SELL EXECUTED, ref:181316, Price: 6.01, Cost: 1621.12, Comm 0.00, Size: -298.00, Stock: 601766
# 2021-01-07, SELL EXECUTED, ref:181317, Price: 7.36, Cost: 1593.96, Comm 0.00, Size: -222.00, Stock: 601800
# 2021-01-07, SELL EXECUTED, ref:181318, Price: 13.60, Cost: 1646.72, Comm 0.00, Size: -124.00, Stock: 601808
# 2021-01-07, SELL EXECUTED, ref:181319, Price: 9.63, Cost: 1652.92, Comm 0.00, Size: -169.00, Stock: 601838
# 2021-01-07, SELL EXECUTED, ref:181320, Price: 293.35, Cost: 1450.00, Comm 0.00, Size: -5.00, Stock: 601888
# 2021-01-07, SELL EXECUTED, ref:181321, Price: 9.92, Cost: 1672.80, Comm 0.00, Size: -153.00, Stock: 601901
# 2021-01-07, SELL EXECUTED, ref:181322, Price: 3.18, Cost: 1594.51, Comm 0.00, Size: -503.00, Stock: 601988
# 2021-01-07, SELL EXECUTED, ref:181323, Price: 4.30, Cost: 1601.76, Comm 0.00, Size: -376.00, Stock: 601989
# 2021-01-07, SELL EXECUTED, ref:181324, Price: 206.60, Cost: 1400.00, Comm 0.00, Size: -7.00, Stock: 603288
# 2021-01-07, SELL EXECUTED, ref:181325, Price: 132.07, Cost: 1560.00, Comm 0.00, Size: -12.00, Stock: 603833
# 2021-01-07, SELL EXECUTED, ref:181326, Price: 6.00, Cost: 1587.10, Comm 0.00, Size: -269.00, Stock: 688009
# 2021-01-07, BUY EXECUTED, ref:181327, Price: 33.30, Cost: 33.30, Comm 0.00, Size: 1.00, Stock: 000063
# 2021-01-07, BUY EXECUTED, ref:181328, Price: 102.00, Cost: 1530.00, Comm 0.00, Size: 15.00, Stock: 000333
# 2021-01-07, BUY EXECUTED, ref:181329, Price: 136.56, Cost: 1502.16, Comm 0.00, Size: 11.00, Stock: 000538
# 2021-01-07, BUY EXECUTED, ref:181330, Price: 64.06, Cost: 1537.44, Comm 0.00, Size: 24.00, Stock: 000651
# 2021-01-07, BUY EXECUTED, ref:181331, Price: 510.01, Cost: 1530.03, Comm 0.00, Size: 3.00, Stock: 000661
# 2021-01-07, BUY EXECUTED, ref:181332, Price: 25.91, Cost: 1606.42, Comm 0.00, Size: 62.00, Stock: 000876
# 2021-01-07, BUY EXECUTED, ref:181333, Price: 52.46, Cost: 1573.80, Comm 0.00, Size: 30.00, Stock: 000895
# 2021-01-07, BUY EXECUTED, ref:181334, Price: 20.60, Cost: 1586.20, Comm 0.00, Size: 77.00, Stock: 000938
# 2021-01-07, BUY EXECUTED, ref:181335, Price: 27.11, Cost: 1572.38, Comm 0.00, Size: 58.00, Stock: 000977
# 2021-01-07, BUY EXECUTED, ref:181336, Price: 37.98, Cost: 1595.16, Comm 0.00, Size: 42.00, Stock: 002001
# 2021-01-07, BUY EXECUTED, ref:181337, Price: 19.02, Cost: 19.02, Comm 0.00, Size: 1.00, Stock: 002157
# 2021-01-07, BUY EXECUTED, ref:181338, Price: 83.00, Cost: 1577.00, Comm 0.00, Size: 19.00, Stock: 002179
# 2021-01-07, BUY EXECUTED, ref:181339, Price: 42.01, Cost: 1596.38, Comm 0.00, Size: 38.00, Stock: 002230
# 2021-01-07, BUY EXECUTED, ref:181340, Price: 22.53, Cost: 1577.10, Comm 0.00, Size: 70.00, Stock: 002236
# 2021-01-07, BUY EXECUTED, ref:181341, Price: 37.84, Cost: 1589.28, Comm 0.00, Size: 42.00, Stock: 002241
# 2021-01-07, BUY EXECUTED, ref:181342, Price: 252.80, Cost: 1516.80, Comm 0.00, Size: 6.00, Stock: 002304
# 2021-01-07, BUY EXECUTED, ref:181343, Price: 93.40, Cost: 1587.80, Comm 0.00, Size: 17.00, Stock: 002352
# 2021-01-07, BUY EXECUTED, ref:181344, Price: 192.12, Cost: 1536.96, Comm 0.00, Size: 8.00, Stock: 002371
# 2021-01-07, BUY EXECUTED, ref:181345, Price: 26.50, Cost: 1590.00, Comm 0.00, Size: 60.00, Stock: 002384
# 2021-01-07, BUY EXECUTED, ref:181346, Price: 56.00, Cost: 1568.00, Comm 0.00, Size: 28.00, Stock: 002415
# 2021-01-07, BUY EXECUTED, ref:181347, Price: 13.57, Cost: 1587.69, Comm 0.00, Size: 117.00, Stock: 002456
# 2021-01-07, BUY EXECUTED, ref:181348, Price: 55.88, Cost: 1564.64, Comm 0.00, Size: 28.00, Stock: 002475
# 2021-01-07, BUY EXECUTED, ref:181349, Price: 11.93, Cost: 1610.55, Comm 0.00, Size: 135.00, Stock: 002600
# 2021-01-07, BUY EXECUTED, ref:181350, Price: 33.89, Cost: 1592.83, Comm 0.00, Size: 47.00, Stock: 002607
# 2021-01-07, BUY EXECUTED, ref:181351, Price: 29.72, Cost: 29.72, Comm 0.00, Size: 1.00, Stock: 002624
# 2021-01-07, BUY EXECUTED, ref:181352, Price: 120.17, Cost: 1562.21, Comm 0.00, Size: 13.00, Stock: 002916
# 2021-01-07, BUY EXECUTED, ref:181353, Price: 126.79, Cost: 1521.48, Comm 0.00, Size: 12.00, Stock: 300033
# 2021-01-07, BUY EXECUTED, ref:181354, Price: 33.02, Cost: 1584.96, Comm 0.00, Size: 48.00, Stock: 300059
# 2021-01-07, BUY EXECUTED, ref:181355, Price: 36.64, Cost: 1575.52, Comm 0.00, Size: 43.00, Stock: 300136
# 2021-01-07, BUY EXECUTED, ref:181356, Price: 77.66, Cost: 1553.20, Comm 0.00, Size: 20.00, Stock: 600009
# 2021-01-07, BUY EXECUTED, ref:181357, Price: 25.24, Cost: 1564.88, Comm 0.00, Size: 62.00, Stock: 600085
# 2021-01-07, BUY EXECUTED, ref:181358, Price: 16.86, Cost: 1584.84, Comm 0.00, Size: 94.00, Stock: 600109
# 2021-01-07, BUY EXECUTED, ref:181359, Price: 35.70, Cost: 1570.80, Comm 0.00, Size: 44.00, Stock: 600118
# 2021-01-07, BUY EXECUTED, ref:181360, Price: 27.77, Cost: 1582.89, Comm 0.00, Size: 57.00, Stock: 600183
# 2021-01-07, BUY EXECUTED, ref:181361, Price: 103.20, Cost: 1548.00, Comm 0.00, Size: 15.00, Stock: 600570
# 2021-01-07, BUY EXECUTED, ref:181362, Price: 42.67, Cost: 1578.79, Comm 0.00, Size: 37.00, Stock: 600584
# 2021-01-07, BUY EXECUTED, ref:181363, Price: 31.70, Cost: 1585.00, Comm 0.00, Size: 50.00, Stock: 600690
# 2021-01-07, BUY EXECUTED, ref:181364, Price: 29.78, Cost: 1578.34, Comm 0.00, Size: 53.00, Stock: 600703
# 2021-01-07, BUY EXECUTED, ref:181365, Price: 106.70, Cost: 1493.80, Comm 0.00, Size: 14.00, Stock: 600745
# 2021-01-07, BUY EXECUTED, ref:181366, Price: 399.90, Cost: 1599.60, Comm 0.00, Size: 4.00, Stock: 600809
# 2021-01-07, BUY EXECUTED, ref:181367, Price: 67.12, Cost: 1543.76, Comm 0.00, Size: 23.00, Stock: 600845
# 2021-01-07, BUY EXECUTED, ref:181368, Price: 68.52, Cost: 1575.96, Comm 0.00, Size: 23.00, Stock: 600893
# 2021-01-07, BUY EXECUTED, ref:181369, Price: 24.27, Cost: 1577.55, Comm 0.00, Size: 65.00, Stock: 600999
# 2021-01-07, BUY EXECUTED, ref:181370, Price: 56.18, Cost: 1573.04, Comm 0.00, Size: 28.00, Stock: 601021
# 2021-01-07, BUY EXECUTED, ref:181371, Price: 13.79, Cost: 1585.85, Comm 0.00, Size: 115.00, Stock: 601138
# 2021-01-07, BUY EXECUTED, ref:181372, Price: 3.71, Cost: 1587.88, Comm 0.00, Size: 428.00, Stock: 601600
# 2021-01-07, BUY EXECUTED, ref:181373, Price: 26.80, Cost: 26.80, Comm 0.00, Size: 1.00, Stock: 601696
# 2021-01-07, BUY EXECUTED, ref:181374, Price: 19.10, Cost: 1566.20, Comm 0.00, Size: 82.00, Stock: 601698
# 2021-01-07, BUY EXECUTED, ref:181375, Price: 18.30, Cost: 1592.10, Comm 0.00, Size: 87.00, Stock: 601788
# 2021-01-07, BUY EXECUTED, ref:181376, Price: 14.88, Cost: 1592.16, Comm 0.00, Size: 107.00, Stock: 601878
# 2021-01-07, BUY EXECUTED, ref:181377, Price: 10.43, Cost: 1585.36, Comm 0.00, Size: 152.00, Stock: 601899
# 2021-01-07, BUY EXECUTED, ref:181378, Price: 34.28, Cost: 34.28, Comm 0.00, Size: 1.00, Stock: 603019
# 2021-01-07, BUY EXECUTED, ref:181379, Price: 151.50, Cost: 1515.00, Comm 0.00, Size: 10.00, Stock: 603160
# 2021-01-07, BUY EXECUTED, ref:181380, Price: 265.97, Cost: 1595.82, Comm 0.00, Size: 6.00, Stock: 603501
# 2021-01-07, BUY EXECUTED, ref:181381, Price: 202.50, Cost: 1417.50, Comm 0.00, Size: 7.00, Stock: 603986
# 2021-01-07, BUY EXECUTED, ref:181382, Price: 155.00, Cost: 1550.00, Comm 0.00, Size: 10.00, Stock: 688012
# 2021-01-07, 当前总资产 102078.23
# --------------2021-01-07 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000002', '000063', '000066', '000069', '000703', '000723', '000961', '002044', '002120', '002146', '002384', '002422', '002456', '002463', '002555', '002558', '002601', '002602', '002739', '002938', '002958', '300003', '300136', '300142', '300144', '300413', '600004', '600009', '600050', '600066', '600068', '600161', '600196', '600233', '600271', '600332', '600340', '600346', '600352', '600383', '600570', '600606', '600845', '600926', '601021', '601111', '601155', '601186', '601216', '601360', '601377', '601390', '601698', '601872', '601901', '603156', '603160', '688008', '688012', '688036']
# sell_stock ['000333', '000538', '000651', '000661', '000768', '000876', '000895', '000938', '000977', '002001', '002008', '002049', '002157', '002179', '002230', '002236', '002241', '002304', '002352', '002371', '002415', '002475', '002600', '002607', '002624', '002916', '300033', '300059', '600085', '600109', '600118', '600183', '600362', '600584', '600690', '600703', '600745', '600809', '600893', '600999', '601138', '601600', '601696', '601788', '601878', '601899', '603019', '603501', '603986']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2021-01-08, SELL EXECUTED, ref:181383, Price: 104.00, Cost: 1530.00, Comm 0.00, Size: -15.00, Stock: 000333
# 2021-01-08, SELL EXECUTED, ref:181384, Price: 143.85, Cost: 1502.16, Comm 0.00, Size: -11.00, Stock: 000538
# 2021-01-08, SELL EXECUTED, ref:181385, Price: 64.96, Cost: 1537.44, Comm 0.00, Size: -24.00, Stock: 000651
# 2021-01-08, SELL EXECUTED, ref:181386, Price: 515.00, Cost: 1530.03, Comm 0.00, Size: -3.00, Stock: 000661
# 2021-01-08, SELL EXECUTED, ref:181387, Price: 39.32, Cost: 1575.00, Comm 0.00, Size: -42.00, Stock: 000768
# 2021-01-08, SELL EXECUTED, ref:181388, Price: 25.73, Cost: 1606.42, Comm 0.00, Size: -62.00, Stock: 000876
# 2021-01-08, SELL EXECUTED, ref:181389, Price: 52.00, Cost: 1573.80, Comm 0.00, Size: -30.00, Stock: 000895
# 2021-01-08, SELL EXECUTED, ref:181390, Price: 20.18, Cost: 1586.20, Comm 0.00, Size: -77.00, Stock: 000938
# 2021-01-08, SELL EXECUTED, ref:181391, Price: 26.36, Cost: 1572.38, Comm 0.00, Size: -58.00, Stock: 000977
# 2021-01-08, SELL EXECUTED, ref:181392, Price: 39.00, Cost: 1595.16, Comm 0.00, Size: -42.00, Stock: 002001
# 2021-01-08, SELL EXECUTED, ref:181393, Price: 47.60, Cost: 1554.35, Comm 0.00, Size: -35.00, Stock: 002008
# 2021-01-08, SELL EXECUTED, ref:181394, Price: 149.00, Cost: 1590.27, Comm 0.00, Size: -11.00, Stock: 002049
# 2021-01-08, SELL EXECUTED, ref:181395, Price: 19.50, Cost: 1628.68, Comm 0.00, Size: -83.00, Stock: 002157
# 2021-01-08, SELL EXECUTED, ref:181396, Price: 86.30, Cost: 1577.00, Comm 0.00, Size: -19.00, Stock: 002179
# 2021-01-08, SELL EXECUTED, ref:181397, Price: 42.81, Cost: 1596.38, Comm 0.00, Size: -38.00, Stock: 002230
# 2021-01-08, SELL EXECUTED, ref:181398, Price: 23.15, Cost: 1577.10, Comm 0.00, Size: -70.00, Stock: 002236
# 2021-01-08, SELL EXECUTED, ref:181399, Price: 39.45, Cost: 1589.28, Comm 0.00, Size: -42.00, Stock: 002241
# 2021-01-08, SELL EXECUTED, ref:181400, Price: 256.44, Cost: 1516.80, Comm 0.00, Size: -6.00, Stock: 002304
# 2021-01-08, SELL EXECUTED, ref:181401, Price: 94.03, Cost: 1587.80, Comm 0.00, Size: -17.00, Stock: 002352
# 2021-01-08, SELL EXECUTED, ref:181402, Price: 191.50, Cost: 1536.96, Comm 0.00, Size: -8.00, Stock: 002371
# 2021-01-08, SELL EXECUTED, ref:181403, Price: 58.20, Cost: 1568.00, Comm 0.00, Size: -28.00, Stock: 002415
# 2021-01-08, SELL EXECUTED, ref:181404, Price: 59.46, Cost: 1564.64, Comm 0.00, Size: -28.00, Stock: 002475
# 2021-01-08, SELL EXECUTED, ref:181405, Price: 11.55, Cost: 1610.55, Comm 0.00, Size: -135.00, Stock: 002600
# 2021-01-08, SELL EXECUTED, ref:181406, Price: 33.84, Cost: 1592.83, Comm 0.00, Size: -47.00, Stock: 002607
# 2021-01-08, SELL EXECUTED, ref:181407, Price: 28.70, Cost: 1603.07, Comm 0.00, Size: -52.00, Stock: 002624
# 2021-01-08, SELL EXECUTED, ref:181408, Price: 128.56, Cost: 1562.21, Comm 0.00, Size: -13.00, Stock: 002916
# 2021-01-08, SELL EXECUTED, ref:181409, Price: 129.73, Cost: 1521.48, Comm 0.00, Size: -12.00, Stock: 300033
# 2021-01-08, SELL EXECUTED, ref:181410, Price: 34.75, Cost: 1584.96, Comm 0.00, Size: -48.00, Stock: 300059
# 2021-01-08, SELL EXECUTED, ref:181411, Price: 25.18, Cost: 1564.88, Comm 0.00, Size: -62.00, Stock: 600085
# 2021-01-08, SELL EXECUTED, ref:181412, Price: 16.98, Cost: 1584.84, Comm 0.00, Size: -94.00, Stock: 600109
# 2021-01-08, SELL EXECUTED, ref:181413, Price: 36.46, Cost: 1570.80, Comm 0.00, Size: -44.00, Stock: 600118
# 2021-01-08, SELL EXECUTED, ref:181414, Price: 28.18, Cost: 1582.89, Comm 0.00, Size: -57.00, Stock: 600183
# 2021-01-08, SELL EXECUTED, ref:181415, Price: 23.30, Cost: 1649.20, Comm 0.00, Size: -76.00, Stock: 600362
# 2021-01-08, SELL EXECUTED, ref:181416, Price: 42.50, Cost: 1578.79, Comm 0.00, Size: -37.00, Stock: 600584
# 2021-01-08, SELL EXECUTED, ref:181417, Price: 32.45, Cost: 1585.00, Comm 0.00, Size: -50.00, Stock: 600690
# 2021-01-08, SELL EXECUTED, ref:181418, Price: 30.70, Cost: 1578.34, Comm 0.00, Size: -53.00, Stock: 600703
# 2021-01-08, SELL EXECUTED, ref:181419, Price: 105.50, Cost: 1493.80, Comm 0.00, Size: -14.00, Stock: 600745
# 2021-01-08, SELL EXECUTED, ref:181420, Price: 419.20, Cost: 1599.60, Comm 0.00, Size: -4.00, Stock: 600809
# 2021-01-08, SELL EXECUTED, ref:181421, Price: 75.00, Cost: 1575.96, Comm 0.00, Size: -23.00, Stock: 600893
# 2021-01-08, SELL EXECUTED, ref:181422, Price: 24.55, Cost: 1577.55, Comm 0.00, Size: -65.00, Stock: 600999
# 2021-01-08, SELL EXECUTED, ref:181423, Price: 13.86, Cost: 1585.85, Comm 0.00, Size: -115.00, Stock: 601138
# 2021-01-08, SELL EXECUTED, ref:181424, Price: 3.98, Cost: 1587.88, Comm 0.00, Size: -428.00, Stock: 601600
# 2021-01-08, SELL EXECUTED, ref:181425, Price: 27.99, Cost: 1649.65, Comm 0.00, Size: -59.00, Stock: 601696
# 2021-01-08, SELL EXECUTED, ref:181426, Price: 18.67, Cost: 1592.10, Comm 0.00, Size: -87.00, Stock: 601788
# 2021-01-08, SELL EXECUTED, ref:181427, Price: 14.90, Cost: 1592.16, Comm 0.00, Size: -107.00, Stock: 601878
# 2021-01-08, SELL EXECUTED, ref:181428, Price: 11.40, Cost: 1585.36, Comm 0.00, Size: -152.00, Stock: 601899
# 2021-01-08, SELL EXECUTED, ref:181429, Price: 33.86, Cost: 1576.88, Comm 0.00, Size: -46.00, Stock: 603019
# 2021-01-08, SELL EXECUTED, ref:181430, Price: 270.88, Cost: 1595.82, Comm 0.00, Size: -6.00, Stock: 603501
# 2021-01-08, SELL EXECUTED, ref:181431, Price: 200.80, Cost: 1417.50, Comm 0.00, Size: -7.00, Stock: 603986
# 2021-01-08, BUY EXECUTED, ref:181432, Price: 28.98, Cost: 1622.88, Comm 0.00, Size: 56.00, Stock: 000002
# 2021-01-08, BUY EXECUTED, ref:181433, Price: 32.55, Cost: 65.10, Comm 0.00, Size: 2.00, Stock: 000063
# 2021-01-08, BUY EXECUTED, ref:181434, Price: 19.53, Cost: 1601.46, Comm 0.00, Size: 82.00, Stock: 000066
# 2021-01-08, BUY EXECUTED, ref:181435, Price: 6.71, Cost: 1610.40, Comm 0.00, Size: 240.00, Stock: 000069
# 2021-01-08, BUY EXECUTED, ref:181436, Price: 12.92, Cost: 1602.08, Comm 0.00, Size: 124.00, Stock: 000703
# 2021-01-08, BUY EXECUTED, ref:181437, Price: 6.47, Cost: 1643.38, Comm 0.00, Size: 254.00, Stock: 000723
# 2021-01-08, BUY EXECUTED, ref:181438, Price: 7.63, Cost: 1602.30, Comm 0.00, Size: 210.00, Stock: 000961
# 2021-01-08, BUY EXECUTED, ref:181439, Price: 11.83, Cost: 1597.05, Comm 0.00, Size: 135.00, Stock: 002044
# 2021-01-08, BUY EXECUTED, ref:181440, Price: 15.22, Cost: 1598.10, Comm 0.00, Size: 105.00, Stock: 002120
# 2021-01-08, BUY EXECUTED, ref:181441, Price: 6.33, Cost: 1607.82, Comm 0.00, Size: 254.00, Stock: 002146
# 2021-01-08, BUY EXECUTED, ref:181442, Price: 26.21, Cost: 26.21, Comm 0.00, Size: 1.00, Stock: 002384
# 2021-01-08, BUY EXECUTED, ref:181443, Price: 18.63, Cost: 1658.07, Comm 0.00, Size: 89.00, Stock: 002422
# 2021-01-08, BUY EXECUTED, ref:181444, Price: 13.25, Cost: 66.25, Comm 0.00, Size: 5.00, Stock: 002456
# 2021-01-08, BUY EXECUTED, ref:181445, Price: 19.03, Cost: 1598.52, Comm 0.00, Size: 84.00, Stock: 002463
# 2021-01-08, BUY EXECUTED, ref:181446, Price: 31.49, Cost: 1605.99, Comm 0.00, Size: 51.00, Stock: 002555
# 2021-01-08, BUY EXECUTED, ref:181447, Price: 17.03, Cost: 1617.85, Comm 0.00, Size: 95.00, Stock: 002558
# 2021-01-08, BUY EXECUTED, ref:181448, Price: 36.76, Cost: 1580.68, Comm 0.00, Size: 43.00, Stock: 002601
# 2021-01-08, BUY EXECUTED, ref:181449, Price: 6.68, Cost: 1603.20, Comm 0.00, Size: 240.00, Stock: 002602
# 2021-01-08, BUY EXECUTED, ref:181450, Price: 18.81, Cost: 1598.85, Comm 0.00, Size: 85.00, Stock: 002739
# 2021-01-08, BUY EXECUTED, ref:181451, Price: 51.75, Cost: 1604.25, Comm 0.00, Size: 31.00, Stock: 002938
# 2021-01-08, BUY EXECUTED, ref:181452, Price: 4.86, Cost: 1598.94, Comm 0.00, Size: 329.00, Stock: 002958
# 2021-01-08, BUY EXECUTED, ref:181453, Price: 26.59, Cost: 1595.40, Comm 0.00, Size: 60.00, Stock: 300003
# 2021-01-08, BUY EXECUTED, ref:181454, Price: 34.72, Cost: 104.16, Comm 0.00, Size: 3.00, Stock: 300136
# 2021-01-08, BUY EXECUTED, ref:181455, Price: 38.05, Cost: 1598.10, Comm 0.00, Size: 42.00, Stock: 300142
# 2021-01-08, BUY EXECUTED, ref:181456, Price: 16.60, Cost: 1610.20, Comm 0.00, Size: 97.00, Stock: 300144
# 2021-01-08, BUY EXECUTED, ref:181457, Price: 68.00, Cost: 1564.00, Comm 0.00, Size: 23.00, Stock: 300413
# 2021-01-08, BUY EXECUTED, ref:181458, Price: 12.80, Cost: 1600.00, Comm 0.00, Size: 125.00, Stock: 600004
# 2021-01-08, BUY EXECUTED, ref:181459, Price: 76.15, Cost: 76.15, Comm 0.00, Size: 1.00, Stock: 600009
# 2021-01-08, BUY EXECUTED, ref:181460, Price: 4.23, Cost: 1594.71, Comm 0.00, Size: 377.00, Stock: 600050
# 2021-01-08, BUY EXECUTED, ref:181461, Price: 15.07, Cost: 1612.49, Comm 0.00, Size: 107.00, Stock: 600066
# 2021-01-08, BUY EXECUTED, ref:181462, Price: 6.55, Cost: 1611.30, Comm 0.00, Size: 246.00, Stock: 600068
# 2021-01-08, BUY EXECUTED, ref:181463, Price: 40.90, Cost: 1595.10, Comm 0.00, Size: 39.00, Stock: 600161
# 2021-01-08, BUY EXECUTED, ref:181464, Price: 52.24, Cost: 1567.20, Comm 0.00, Size: 30.00, Stock: 600196
# 2021-01-08, BUY EXECUTED, ref:181465, Price: 11.76, Cost: 1599.36, Comm 0.00, Size: 136.00, Stock: 600233
# 2021-01-08, BUY EXECUTED, ref:181466, Price: 12.80, Cost: 1600.00, Comm 0.00, Size: 125.00, Stock: 600271
# 2021-01-08, BUY EXECUTED, ref:181467, Price: 30.00, Cost: 1590.00, Comm 0.00, Size: 53.00, Stock: 600332
# 2021-01-08, BUY EXECUTED, ref:181468, Price: 11.66, Cost: 1574.10, Comm 0.00, Size: 135.00, Stock: 600340
# 2021-01-08, BUY EXECUTED, ref:181469, Price: 33.02, Cost: 1584.96, Comm 0.00, Size: 48.00, Stock: 600346
# 2021-01-08, BUY EXECUTED, ref:181470, Price: 14.57, Cost: 1617.27, Comm 0.00, Size: 111.00, Stock: 600352
# 2021-01-08, BUY EXECUTED, ref:181471, Price: 12.51, Cost: 1601.28, Comm 0.00, Size: 128.00, Stock: 600383
# 2021-01-08, BUY EXECUTED, ref:181472, Price: 98.27, Cost: 98.27, Comm 0.00, Size: 1.00, Stock: 600570
# 2021-01-08, BUY EXECUTED, ref:181473, Price: 5.67, Cost: 1610.28, Comm 0.00, Size: 284.00, Stock: 600606
# 2021-01-08, BUY EXECUTED, ref:181474, Price: 63.42, Cost: 126.84, Comm 0.00, Size: 2.00, Stock: 600845
# 2021-01-08, BUY EXECUTED, ref:181475, Price: 13.91, Cost: 1599.65, Comm 0.00, Size: 115.00, Stock: 600926
# 2021-01-08, BUY EXECUTED, ref:181476, Price: 7.15, Cost: 1601.60, Comm 0.00, Size: 224.00, Stock: 601111
# 2021-01-08, BUY EXECUTED, ref:181477, Price: 33.60, Cost: 1579.20, Comm 0.00, Size: 47.00, Stock: 601155
# 2021-01-08, BUY EXECUTED, ref:181478, Price: 8.00, Cost: 1608.00, Comm 0.00, Size: 201.00, Stock: 601186
# 2021-01-08, BUY EXECUTED, ref:181479, Price: 4.57, Cost: 1604.07, Comm 0.00, Size: 351.00, Stock: 601216
# 2021-01-08, BUY EXECUTED, ref:181480, Price: 15.90, Cost: 1605.90, Comm 0.00, Size: 101.00, Stock: 601360
# 2021-01-08, BUY EXECUTED, ref:181481, Price: 8.85, Cost: 1584.15, Comm 0.00, Size: 179.00, Stock: 601377
# 2021-01-08, BUY EXECUTED, ref:181482, Price: 5.40, Cost: 1614.60, Comm 0.00, Size: 299.00, Stock: 601390
# 2021-01-08, BUY EXECUTED, ref:181483, Price: 19.00, Cost: 57.00, Comm 0.00, Size: 3.00, Stock: 601698
# 2021-01-08, BUY EXECUTED, ref:181484, Price: 5.68, Cost: 1596.08, Comm 0.00, Size: 281.00, Stock: 601872
# 2021-01-08, BUY EXECUTED, ref:181485, Price: 9.79, Cost: 1605.56, Comm 0.00, Size: 164.00, Stock: 601901
# 2021-01-08, BUY EXECUTED, ref:181486, Price: 24.83, Cost: 1613.95, Comm 0.00, Size: 65.00, Stock: 603156
# 2021-01-08, BUY EXECUTED, ref:181487, Price: 84.72, Cost: 1609.68, Comm 0.00, Size: 19.00, Stock: 688008
# 2021-01-08, BUY EXECUTED, ref:181488, Price: 152.00, Cost: 1520.00, Comm 0.00, Size: 10.00, Stock: 688036
# 2021-01-08, 当前总资产 103887.35
# --------------2021-01-08 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000063', '000066', '000333', '000538', '000568', '000596', '000651', '000723', '000858', '000860', '000876', '000895', '002001', '002027', '002049', '002050', '002157', '002179', '002271', '002304', '002311', '002352', '002384', '002673', '002812', '002945', '300347', '300408', '300433', '600109', '600176', '600276', '600436', '600438', '600519', '600584', '600660', '600809', '600887', '600918', '600958', '600999', '601012', '601066', '601100', '601162', '601377', '601390', '601555', '601696', '601766', '601788', '601877', '601878', '601881', '601888', '601901', '603259', '603369', '603658']
# sell_stock ['000002', '000069', '000703', '000961', '002044', '002120', '002146', '002422', '002456', '002463', '002555', '002558', '002601', '002602', '002739', '002938', '002958', '300003', '300136', '300142', '300144', '300413', '600004', '600009', '600050', '600066', '600068', '600161', '600196', '600233', '600271', '600332', '600340', '600346', '600352', '600383', '600570', '600606', '600845', '600926', '601021', '601111', '601155', '601186', '601216', '601360', '601698', '601872', '603156', '603160', '688008', '688012', '688036']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 2021-01-11, SELL EXECUTED, ref:181489, Price: 29.50, Cost: 1622.88, Comm 0.00, Size: -56.00, Stock: 000002
# 2021-01-11, SELL EXECUTED, ref:181490, Price: 6.73, Cost: 1610.40, Comm 0.00, Size: -240.00, Stock: 000069
# 2021-01-11, SELL EXECUTED, ref:181491, Price: 13.00, Cost: 1602.08, Comm 0.00, Size: -124.00, Stock: 000703
# 2021-01-11, SELL EXECUTED, ref:181492, Price: 7.75, Cost: 1602.30, Comm 0.00, Size: -210.00, Stock: 000961
# 2021-01-11, SELL EXECUTED, ref:181493, Price: 12.01, Cost: 1597.05, Comm 0.00, Size: -135.00, Stock: 002044
# 2021-01-11, SELL EXECUTED, ref:181494, Price: 15.71, Cost: 1598.10, Comm 0.00, Size: -105.00, Stock: 002120
# 2021-01-11, SELL EXECUTED, ref:181495, Price: 6.38, Cost: 1607.82, Comm 0.00, Size: -254.00, Stock: 002146
# 2021-01-11, SELL EXECUTED, ref:181496, Price: 18.89, Cost: 1658.07, Comm 0.00, Size: -89.00, Stock: 002422
# 2021-01-11, SELL EXECUTED, ref:181497, Price: 13.65, Cost: 1653.94, Comm 0.00, Size: -122.00, Stock: 002456
# 2021-01-11, SELL EXECUTED, ref:181498, Price: 19.40, Cost: 1598.52, Comm 0.00, Size: -84.00, Stock: 002463
# 2021-01-11, SELL EXECUTED, ref:181499, Price: 33.75, Cost: 1605.99, Comm 0.00, Size: -51.00, Stock: 002555
# 2021-01-11, SELL EXECUTED, ref:181500, Price: 18.40, Cost: 1617.85, Comm 0.00, Size: -95.00, Stock: 002558
# 2021-01-11, SELL EXECUTED, ref:181501, Price: 38.30, Cost: 1580.68, Comm 0.00, Size: -43.00, Stock: 002601
# 2021-01-11, SELL EXECUTED, ref:181502, Price: 7.12, Cost: 1603.20, Comm 0.00, Size: -240.00, Stock: 002602
# 2021-01-11, SELL EXECUTED, ref:181503, Price: 19.12, Cost: 1598.85, Comm 0.00, Size: -85.00, Stock: 002739
# 2021-01-11, SELL EXECUTED, ref:181504, Price: 49.77, Cost: 1604.25, Comm 0.00, Size: -31.00, Stock: 002938
# 2021-01-11, SELL EXECUTED, ref:181505, Price: 4.76, Cost: 1598.94, Comm 0.00, Size: -329.00, Stock: 002958
# 2021-01-11, SELL EXECUTED, ref:181506, Price: 28.31, Cost: 1595.40, Comm 0.00, Size: -60.00, Stock: 300003
# 2021-01-11, SELL EXECUTED, ref:181507, Price: 37.25, Cost: 1679.68, Comm 0.00, Size: -46.00, Stock: 300136
# 2021-01-11, SELL EXECUTED, ref:181508, Price: 38.85, Cost: 1598.10, Comm 0.00, Size: -42.00, Stock: 300142
# 2021-01-11, SELL EXECUTED, ref:181509, Price: 16.85, Cost: 1610.20, Comm 0.00, Size: -97.00, Stock: 300144
# 2021-12-17, BUY EXECUTED, ref:202837, Price: 6.33, Cost: 2171.19, Comm 0.00, Size: 343.00, Stock: 601006
# 2021-12-17, BUY EXECUTED, ref:202838, Price: 3.83, Cost: 2171.61, Comm 0.00, Size: 567.00, Stock: 601077
# 2021-12-17, BUY EXECUTED, ref:202839, Price: 12.27, Cost: 2171.79, Comm 0.00, Size: 177.00, Stock: 601117
# 2021-12-17, BUY EXECUTED, ref:202840, Price: 4.43, Cost: 2166.27, Comm 0.00, Size: 489.00, Stock: 601169
# 2021-12-17, BUY EXECUTED, ref:202841, Price: 7.16, Cost: 2169.48, Comm 0.00, Size: 303.00, Stock: 601229
# 2021-12-17, BUY EXECUTED, ref:202842, Price: 7.86, Cost: 2169.36, Comm 0.00, Size: 276.00, Stock: 601577
# 2021-12-17, BUY EXECUTED, ref:202843, Price: 18.66, Cost: 2164.56, Comm 0.00, Size: 116.00, Stock: 601607
# 2021-12-17, BUY EXECUTED, ref:202844, Price: 14.19, Cost: 2156.88, Comm 0.00, Size: 152.00, Stock: 601696
# 2021-12-17, BUY EXECUTED, ref:202845, Price: 14.25, Cost: 2166.00, Comm 0.00, Size: 152.00, Stock: 601698
# 2021-12-17, BUY EXECUTED, ref:202846, Price: 4.65, Cost: 2166.90, Comm 0.00, Size: 466.00, Stock: 601816
# 2021-12-17, BUY EXECUTED, ref:202847, Price: 18.65, Cost: 2182.05, Comm 0.00, Size: 117.00, Stock: 601919
# 2021-12-17, BUY EXECUTED, ref:202848, Price: 3.05, Cost: 2171.60, Comm 0.00, Size: 712.00, Stock: 601988
# 2021-12-17, BUY EXECUTED, ref:202849, Price: 4.53, Cost: 2169.87, Comm 0.00, Size: 479.00, Stock: 601998
# 2021-12-17, BUY EXECUTED, ref:202850, Price: 58.11, Cost: 2150.07, Comm 0.00, Size: 37.00, Stock: 603369
# 2021-12-17, BUY EXECUTED, ref:202851, Price: 170.15, Cost: 2041.80, Comm 0.00, Size: 12.00, Stock: 603986
# 2021-12-17, BUY EXECUTED, ref:202852, Price: 4.94, Cost: 2168.66, Comm 0.00, Size: 439.00, Stock: 688009
# 2021-12-17, BUY EXECUTED, ref:202853, Price: 145.00, Cost: 2030.00, Comm 0.00, Size: 14.00, Stock: 688012
# 2021-12-17, BUY EXECUTED, ref:202854, Price: 154.00, Cost: 2156.00, Comm 0.00, Size: 14.00, Stock: 688036
# 2021-12-17, 当前总资产 135995.09
# --------------2021-12-17 为调仓日----------
# --------------- 撤销未完成的订单 -----------------
# long_list ['000063', '000333', '000568', '000661', '000723', '000768', '000776', '000858', '000977', '002008', '002129', '002202', '002230', '002241', '002271', '002304', '002371', '002475', '002555', '002594', '002812', '002821', '300014', '300059', '300122', '300124', '300347', '300413', '300433', '600011', '600030', '600048', '600111', '600150', '600196', '600276', '600309', '600406', '600438', '600519', '600703', '600760', '600809', '600872', '600893', '600958', '601012', '601066', '601377', '601633', '601877', '601878', '601888', '601919', '603259', '603369', '603501', '603799', '603986', '688012']
# sell_stock ['000002', '000725', '002007', '002120', '002157', '002252', '002311', '002384', '002414', '002422', '002456', '002463', '002602', '002607', '002624', '002916', '002958', '300601', '600009', '600016', '600027', '600085', '600177', '600183', '600208', '600233', '600436', '600482', '600522', '600763', '600845', '600848', '600998', '601006', '601077', '601117', '601169', '601229', '601577', '601607', '601696', '601698', '601816', '601988', '601998', '688009', '688036']
# -----------对不再持有的股票进行平仓--------------
# -----------买入此次调仓期的股票--------------
# 
# 2021-12-20, BUY EXECUTED, ref:202946, Price: 29.68, Cost: 2136.96, Comm 0.00, Size: 72.00, Stock: 601066
# 2021-12-20, BUY EXECUTED, ref:202947, Price: 9.83, Cost: 2133.11, Comm 0.00, Size: 217.00, Stock: 601377
# 2021-12-20, BUY EXECUTED, ref:202948, Price: 51.60, Cost: 2115.60, Comm 0.00, Size: 41.00, Stock: 601633
# 2021-12-20, BUY EXECUTED, ref:202949, Price: 53.03, Cost: 2121.20, Comm 0.00, Size: 40.00, Stock: 601877
# 2021-12-20, BUY EXECUTED, ref:202950, Price: 13.40, Cost: 2117.20, Comm 0.00, Size: 158.00, Stock: 601878
# 2021-12-20, BUY EXECUTED, ref:202951, Price: 212.00, Cost: 1908.00, Comm 0.00, Size: 9.00, Stock: 601888
# 2021-12-20, SELL EXECUTED, ref:202952, Price: 18.95, Cost: 18.65, Comm 0.00, Size: -1.00, Stock: 601919
# 2021-12-20, BUY EXECUTED, ref:202953, Price: 123.01, Cost: 2091.17, Comm 0.00, Size: 17.00, Stock: 603259
# 2021-12-20, BUY EXECUTED, ref:202954, Price: 115.01, Cost: 2070.18, Comm 0.00, Size: 18.00, Stock: 603799
# 2021-12-20, BUY EXECUTED, ref:202955, Price: 136.29, Cost: 136.29, Comm 0.00, Size: 1.00, Stock: 688012
# 2021-12-20, 当前总资产 133703.06
# 2021-12-21, 当前总资产 134700.07
# 2021-12-22, 当前总资产 135302.90
# 2021-12-23, 当前总资产 136075.22
# 2021-12-24, 当前总资产 135154.73
# 2021-12-27, 当前总资产 135220.86
# 2021-12-28, 当前总资产 135847.75
# 2021-12-29, 当前总资产 133818.29
# 2021-12-30, 当前总资产 135530.88
# 2021-12-31, 当前总资产 136270.44

# %% [markdown]
# ## 2.3 回测结果分析

# %%
strat = result[0]
# print("--------------- AnnualReturn -----------------")
# print(strat.analyzers._AnnualReturn.get_analysis())
# print("--------------- DrawDown -----------------")
# print(strat.analyzers._DrawDown.get_analysis())
# print("--------------- Returns -----------------")
# print(strat.analyzers._Returns.get_analysis())
# print("--------------- SharpeRatio -----------------")
# print(strat.analyzers._SharpeRatio.get_analysis())
# print("--------------- SharpeRatio_A -----------------")
# print(strat.analyzers._SharpeRatio_A.get_analysis())

# 绘制累计收益率
ret = pd.Series(strat.analyzers._TimeReturn.get_analysis())
(ret + 1).cumprod().plot(figsize=(12,6))

ret = [{
        '年度': year,
        '收益率': strat.analyzers._Returns.get_analysis()['rtot'],
        '日均收益率': strat.analyzers._Returns.get_analysis()['ravg'],
        '年化收益率': strat.analyzers._Returns.get_analysis()['rnorm'],
        '最大回撤(%)': strat.analyzers._DrawDown.get_analysis()['max']['drawdown']
        * (-1),
        '夏普比率': strat.analyzers._SharpeRatio.get_analysis()['sharperatio'],
    }]
pd.DataFrame(ret).sort_values(by='年化收益率', ascending=False)
# Out:
#      年度       收益率     日均收益率     年化收益率  最大回撤(%)      夏普比率
# 0  2021  0.309471  0.001274  0.378413 -10.8384  1.639796
